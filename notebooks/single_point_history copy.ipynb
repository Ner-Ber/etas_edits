# %%
from typing import TypedDict
import datetime as dt

import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
import pandas as pd
import pyproj
import scipy
import etas.mc_b_est as mc_b_est
import etas.utility_functions as utility_functions
import etas.simulation as simulation
from etas.inversion import polygon_surface
from matplotlib import colors
from matplotlib.path import Path as MplPath
from scipy.optimize import root_scalar
from shapely.geometry import MultiPoint, MultiPolygon, Point, Polygon
from shapely.ops import transform, voronoi_diagram
from shapely.prepared import prep
from tqdm.auto import tqdm
# Out:
# 2026-06-12 10:16:57.082751: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-06-12 10:16:57.120128: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-06-12 10:16:57.120169: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-06-12 10:16:57.121796: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-06-12 10:16:57.128875: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-06-12 10:16:57.816048: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
EARTH_RADIUS_KM = 6.3781e3


def _hav(theta):
    return np.square(np.sin(theta / 2))


def haversine_km(lat_rad_1, lat_rad_2, lon_rad_1, lon_rad_2, earth_radius=EARTH_RADIUS_KM):
    return (
        2
        * earth_radius
        * np.arcsin(
            np.sqrt(
                _hav(lat_rad_1 - lat_rad_2)
                + np.cos(lat_rad_1) * np.cos(lat_rad_2) * _hav(lon_rad_1 - lon_rad_2)
            )
        )
    )


def km_per_degree_at_latitude(lat_deg, earth_radius=EARTH_RADIUS_KM):
    lat_rad = np.radians(np.asarray(lat_deg, dtype=float))
    km_per_lat = haversine_km(
        lat_rad - np.radians(0.5), lat_rad + np.radians(0.5), 0.0, 0.0, earth_radius
    )
    km_per_lon = haversine_km(lat_rad, lat_rad, 0.0, np.radians(1.0), earth_radius)
    if np.ndim(km_per_lat) == 0:
        return float(km_per_lat), float(km_per_lon)
    return km_per_lat, km_per_lon


def latlon_rectangular_grid_in_polygon(
    polygon,
    grid_point_density_km2,
    *,
    earth_radius=EARTH_RADIUS_KM,
    rtol=0.05,
    max_iterations=40,
):
    if grid_point_density_km2 <= 0:
        raise ValueError("grid_point_density_km2 must be positive")
    area_km2 = float(polygon_surface(polygon))
    target_n = max(1, int(round(area_km2 * grid_point_density_km2)))
    min_lat, min_lon, max_lat, max_lon = polygon.bounds
    lat_c = 0.5 * (min_lat + max_lat)
    km_per_lat, km_per_lon = km_per_degree_at_latitude(lat_c, earth_radius)
    prep_poly = prep(polygon)
    spacing_km = float(np.sqrt(area_km2 / target_n))
    lat_flat = lon_flat = np.empty(0)
    n_lat = n_lon = 0
    for _ in range(max_iterations):
        spacing_lat = spacing_km / km_per_lat
        spacing_lon = spacing_km / km_per_lon
        n_lat = max(2, int(np.ceil((max_lat - min_lat) / spacing_lat)) + 1)
        n_lon = max(2, int(np.ceil((max_lon - min_lon) / spacing_lon)) + 1)
        lats = np.linspace(min_lat, max_lat, n_lat)
        lons = np.linspace(min_lon, max_lon, n_lon)
        lat_mesh, lon_mesh = np.meshgrid(lats, lons)
        lat_cand = lat_mesh.ravel()
        lon_cand = lon_mesh.ravel()
        inside = np.fromiter(
            (prep_poly.contains(Point(lat, lon)) for lat, lon in zip(lat_cand, lon_cand)),
            dtype=bool,
            count=lat_cand.size,
        )
        n_inside = int(inside.sum())
        if n_inside == 0:
            spacing_km *= 0.5
            continue
        lat_flat = lat_cand[inside]
        lon_flat = lon_cand[inside]
        if abs(n_inside - target_n) / target_n <= rtol:
            break
        spacing_km *= np.sqrt(n_inside / target_n)
    if lat_flat.size == 0:
        raise RuntimeError("Could not place any grid nodes inside the polygon")
    info = {
        "area_km2": area_km2,
        "target_n": target_n,
        "n_points": int(lat_flat.size),
        "spacing_km": spacing_km,
        "grid_n_xy": (n_lat, n_lon),
        "grid_point_density_km2": float(grid_point_density_km2),
    }
    return lat_flat, lon_flat, info


def _swap_xy(x, y):
    return y, x


def get_ordered_voronoi_cells(polygon_latlon, lat_flat, lon_flat):
    # Swap bounding polygon to standard (lon, lat)
    polygon_lonlat = transform(_swap_xy, polygon_latlon)

    # Create ordered points
    points = [Point(lon, lat) for lon, lat in zip(lon_flat, lat_flat)]

    # Generate raw Voronoi diagram
    vd = voronoi_diagram(MultiPoint(points), envelope=polygon_lonlat)
    raw_cells = list(vd.geoms)

    # Use spatial join to map the unordered cells back to the exact order of input points
    points_gdf = gpd.GeoDataFrame(geometry=points)
    cells_gdf = gpd.GeoDataFrame(geometry=raw_cells)
    matched = points_gdf.sjoin(cells_gdf, how="left", predicate="intersects")
    matched = matched[~matched.index.duplicated(keep="first")]

    ordered_clipped_cells = []
    for idx in matched["index_right"].values:
        if np.isnan(idx):
            # Point is completely orphaned/outside
            ordered_clipped_cells.append(Polygon())
        else:
            # Extract matched cell and clip it to the overarching polygon boundary
            cell = raw_cells[int(idx)]
            clipped_cell = cell.intersection(polygon_lonlat)
            ordered_clipped_cells.append(clipped_cell)

    return ordered_clipped_cells

# %%
# Grid points per side for A_h spatial quadrature (log_rhs, inverse transform, saved CSV tag).
A_H_RESOLUTION = 400

class History(TypedDict):
    m: float
    x: float
    y: float
    t: float

class EtasParams(TypedDict):
    mu: float
    k0: float
    a: float
    m_c: float
    d: float
    gamma: float
    rho: float
    c: float
    tau: float
    omega: float

def a_h(
    x: float,
    y: float,
    H: History,
    params: EtasParams,
):
    """Spatial triggering kernel at (x, y) = (lon, lat) from history event H."""
    dist_sq_km2 = utility_functions.spatial_distance_squared_km2(
        y, x, H["y"], H["x"]
    )
    K = params["k0"] * np.exp(params["a"] * (H["m"] - params["m_c"]))
    C = params["d"] * np.exp(params["gamma"] * (H["m"] - params["m_c"]))
    return K / (dist_sq_km2 + C) ** (1 + params["rho"])


def A_h(poly: Polygon, H: History, params: EtasParams, resolution: int = 50) -> float:
    """Integrate a_h over poly; poly vertices are (lon, lat)."""
    minx, miny, maxx, maxy = poly.bounds
    if minx == maxx or miny == maxy:
        return 0.0

    x_grid = np.linspace(minx, maxx, resolution)
    y_grid = np.linspace(miny, maxy, resolution)
    X, Y = np.meshgrid(x_grid, y_grid)

    points = np.column_stack((X.ravel(), Y.ravel()))
    path = MplPath(poly.exterior.coords)
    mask = path.contains_points(points).reshape(resolution, resolution)

    K = params["k0"] * np.exp(params["a"] * (H["m"] - params["m_c"]))
    C = params["d"] * np.exp(params["gamma"] * (H["m"] - params["m_c"]))
    rho1 = 1 + params["rho"]

    X_masked = X[mask]
    Y_masked = Y[mask]
    dist_sq_km2 = utility_functions.spatial_distance_squared_km2(
        Y_masked, X_masked, H["y"], H["x"]
    )
    kernel = K / (dist_sq_km2 + C) ** rho1

    dlon_deg = (maxx - minx) / (resolution - 1)
    dlat_deg = (maxy - miny) / (resolution - 1)
    km_per_lat, km_per_lon = utility_functions.km_per_degree_at_latitude(Y_masked)
    dA_km2 = (dlon_deg * km_per_lon) * (dlat_deg * km_per_lat)

    return float(np.sum(kernel * dA_km2))

def polygon_area(polygon: Polygon) -> float:
    geod = pyproj.Geod(ellps="WGS84")
    area_m2, _ = geod.geometry_area_perimeter(polygon)
    return abs(area_m2) / 1e6

def g(
    t: float,
    H : History,
    params: EtasParams,
    ):
    return np.exp(-(t - H['t']) / params['tau']) / (t - H['t'] + params['c'])**(1+params['omega'])

def etas_rate_at_xy(
    x: float,
    y: float,
    t: float,
    H : History,
    params: EtasParams,
    ):
    return params['mu']  + a_h(x, y, H, params) * g(t, H, params)

def unreg_gamma(a, x):
    return scipy.special.gammaincc(a, x) * scipy.special.gamma(a)

# %%
THETA_0 = {
    "log10_mu": -5.8,
    "log10_k0": -2.6,
    "a": 1.8,
    "log10_c": -2.5,
    "omega": -0.02,
    "log10_tau": 3.5,
    "log10_d": -0.85,
    "gamma": 1.3,
    "rho": 0.66,
    "m_c": 3.5,
}

for key in list(THETA_0.keys()):
    if key.startswith('log10_'):
        xx = key.replace('log10_', '')
        if xx not in THETA_0:
            THETA_0[xx] = 10 ** THETA_0[key]


THETA_0
# Out:
# {'log10_mu': -5.8,
#  'log10_k0': -2.6,
#  'a': 1.8,
#  'log10_c': -2.5,
#  'omega': -0.02,
#  'log10_tau': 3.5,
#  'log10_d': -0.85,
#  'gamma': 1.3,
#  'rho': 0.66,
#  'm_c': 3.5,
#  'mu': 1.584893192461114e-06,
#  'k0': 0.0025118864315095794,
#  'c': 0.0031622776601683794,
#  'tau': 3162.2776601683795,
#  'd': 0.14125375446227545}

# %%
history_event_time = "2006-12-29 00:00:00"
history_event_magnitude = 6.5
history_event_x = -116.4
history_event_y = 33.6

history_dict = {
    "m": history_event_magnitude,
    "x": history_event_x,
    "y": history_event_y,
    "t": (pd.to_datetime(history_event_time) - pd.Timestamp("1970-01-01")) / pd.Timedelta("1D"),
}

# %%
# Hardcoded study-region outline (same vertices as input_data/california_shape.npy)
# Each row is [latitude, longitude].
SHAPE_COORDS = [[43.5, -125.7], [43.5, -118.5], [39.7, -118.5], [36.1, -113.6], [34.6, -112.6], [34.3, -112.6], [32.7, -113.1], [31.8, -113.2], [31.2, -114.5], [31.0, -117.1], [31.1, -117.4], [31.5, -118.3], [32.4, -118.8], [33.3, -121.3], [34.0, -122.0], [37.5, -124.3], [40.0, -125.9], [40.5, -125.9], [43.0, -125.7], [43.5, -125.7]]

GRID_POINT_DENSITY_KM2 = 5e-4  # same as grid_recreations_point_process.ipynb

# %%
polygon = Polygon(SHAPE_COORDS)

lat_flat, lon_flat, grid_info = latlon_rectangular_grid_in_polygon(
    polygon, GRID_POINT_DENSITY_KM2
)
ordered_cells = get_ordered_voronoi_cells(polygon, lat_flat, lon_flat)

print(
    f"grid from density {GRID_POINT_DENSITY_KM2:.4g} pts/km²: "
    f"{grid_info['n_points']} nodes (target {grid_info['target_n']}, "
    f"spacing {grid_info['spacing_km']:.3f} km, rectangle {grid_info['grid_n_xy']})"
)
print(f"polygon area: {grid_info['area_km2']:.4g} km²")
print(f"Voronoi cells: {len(ordered_cells)}")

history_point = Point(history_event_x, history_event_y)
for j, cell in enumerate(ordered_cells):
    if cell.contains(history_point):
        print(
            f"history point ({history_event_x}, {history_event_y}) -> cell {j}, "
            f"node ({lon_flat[j]:.6f}, {lat_flat[j]:.6f})"
        )
        break
# Out:
# grid from density 0.0005 pts/km²: 494 nodes (target 480, spacing 44.717 km, rectangle (33, 28))
# polygon area: 9.598e+05 km²
# Voronoi cells: 494
# history point (-116.4, 33.6) -> cell 390, node (-116.540741, 33.734375)

# %%
# %matplotlib inline



def _polygon_parts(geom):
    if geom.is_empty:
        return
    if geom.geom_type == "Polygon":
        yield geom
    elif geom.geom_type == "MultiPolygon":
        yield from geom.geoms
    elif geom.geom_type == "GeometryCollection":
        for g in geom.geoms:
            yield from _polygon_parts(g)


history_cell_idx = None
for j, cell in enumerate(ordered_cells):
    if cell.contains(history_point):
        history_cell_idx = j
        break

fig_grid, ax = plt.subplots(figsize=(12, 10))

for j, cell in enumerate(ordered_cells):
    facecolor = "#ffd966" if j == history_cell_idx else "#d9e8f7"
    alpha = 0.9 if j == history_cell_idx else 0.65
    for part in _polygon_parts(cell):
        xy = np.asarray(part.exterior.coords)  # x=lon, y=lat
        ax.add_patch(
            mpatches.Polygon(
                xy,
                closed=True,
                facecolor=facecolor,
                edgecolor="k",
                alpha=alpha,
                linewidth=0.4,
            )
        )

poly_coords = np.asarray(polygon.exterior.coords)
lat_poly, lon_poly = poly_coords[:, 0], poly_coords[:, 1]
ax.plot(lon_poly, lat_poly, color="black", linewidth=2, label="Study region")

ax.scatter(lon_flat, lat_flat, s=8, c="red", zorder=5, label="Grid nodes")
for j in range(len(lon_flat)):
    ax.annotate(
        str(j),
        (lon_flat[j], lat_flat[j]),
        textcoords="offset points",
        xytext=(2, 2),
        fontsize=5,
        color="darkred",
        ha="left",
        va="bottom",
        zorder=7,
    )
ax.scatter(
    [history_event_x],
    [history_event_y],
    s=80,
    c="magenta",
    marker="*",
    edgecolors="black",
    linewidths=0.5,
    zorder=6,
    label=f"History event (M={history_event_magnitude})",
)

if history_cell_idx is not None:
    ax.scatter(
        [lon_flat[history_cell_idx]],
        [lat_flat[history_cell_idx]],
        s=50,
        c="orange",
        edgecolors="black",
        linewidths=0.5,
        zorder=6,
        label=f"Host node (cell {history_cell_idx})",
    )

ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")
ax.set_title("Voronoi cells and grid nodes")
ax.set_aspect("equal")
ax.set_xlim(np.min(lon_flat) - 0.2, np.max(lon_flat) + 0.2)
ax.set_ylim(np.min(lat_flat) - 0.2, np.max(lat_flat) + 0.2)
ax.legend(loc="upper right")
plt.show()
# Out:
# 2026-06-12 10:16:59,278 - DEBUG - Loaded backend inline version unknown.
# 2026-06-12 10:16:59,283 - DEBUG - findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0.
# 2026-06-12 10:16:59,283 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/cmr10.ttf', name='cmr10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,284 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymReg.ttf', name='STIXSizeOneSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,284 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,284 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymReg.ttf', name='STIXSizeTwoSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,284 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Bold.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 0.33499999999999996
# 2026-06-12 10:16:59,285 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/cmb10.ttf', name='cmb10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,285 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniBolIta.ttf', name='STIXNonUnicode', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:16:59,285 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-BoldOblique.ttf', name='DejaVu Sans Mono', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:16:59,285 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymBol.ttf', name='STIXSizeFourSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:16:59,285 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniBol.ttf', name='STIXNonUnicode', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:16:59,286 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneral.ttf', name='STIXGeneral', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,286 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Bold.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:16:59,286 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymBol.ttf', name='STIXSizeOneSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:16:59,286 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/cmex10.ttf', name='cmex10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,286 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUni.ttf', name='STIXNonUnicode', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,287 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymReg.ttf', name='STIXSizeThreeSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,287 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralBolIta.ttf', name='STIXGeneral', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:16:59,287 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Oblique.ttf', name='DejaVu Sans Mono', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:16:59,288 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,288 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansDisplay.ttf', name='DejaVu Sans Display', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,288 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniIta.ttf', name='STIXNonUnicode', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:16:59,288 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/cmsy10.ttf', name='cmsy10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,289 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/cmtt10.ttf', name='cmtt10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,289 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-BoldItalic.ttf', name='DejaVu Serif', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:16:59,289 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Oblique.ttf', name='DejaVu Sans', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 1.05
# 2026-06-12 10:16:59,290 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Bold.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:16:59,290 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymBol.ttf', name='STIXSizeThreeSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:16:59,290 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralItalic.ttf', name='STIXGeneral', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:16:59,290 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-BoldOblique.ttf', name='DejaVu Sans', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 1.335
# 2026-06-12 10:16:59,290 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Italic.ttf', name='DejaVu Serif', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:16:59,291 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymBol.ttf', name='STIXSizeTwoSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:16:59,291 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 0.05
# 2026-06-12 10:16:59,291 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralBol.ttf', name='STIXGeneral', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:16:59,291 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerifDisplay.ttf', name='DejaVu Serif Display', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,292 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymReg.ttf', name='STIXSizeFourSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,292 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/cmmi10.ttf', name='cmmi10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,292 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/cmss10.ttf', name='cmss10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,292 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFiveSymReg.ttf', name='STIXSizeFiveSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,292 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/croscore/Arimo-Italic.ttf', name='Arimo', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:16:59,293 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansMongolian-Regular.ttf', name='Noto Sans Mongolian', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,293 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/arphic-bsmi00lp/bsmi00lp.ttf', name='AR PL Mingti2L Big5', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,293 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSerifCondensed-Bold.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=700, stretch='condensed', size='scalable')) = 10.535
# 2026-06-12 10:16:59,293 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Norasi-Bold.ttf', name='Norasi', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:16:59,293 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationMono-Regular.ttf', name='Liberation Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,293 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansTifinaghAPT-Regular.ttf', name='Noto Sans Tifinagh APT', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,294 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/magnet_env/fonts/SourceCodePro-ExtraLight.ttf', name='Source Code Pro', style='normal', variant='normal', weight=200, stretch='normal', size='scalable')) = 10.24
# 2026-06-12 10:16:59,294 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansHanifiRohingya-Regular.ttf', name='Noto Sans Hanifi Rohingya', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,295 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusRoman-Italic.otf', name='Nimbus Roman', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:16:59,295 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifBalinese-Regular.ttf', name='Noto Serif Balinese', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,295 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-LightItalic.ttf', name='Lato', style='italic', variant='normal', weight=300, stretch='normal', size='scalable')) = 11.145
# 2026-06-12 10:16:59,295 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Garuda.ttf', name='Garuda', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,296 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifNyiakengPuachueHmong-Regular.ttf', name='Noto Serif Hmong Nyiakeng', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,296 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansCarian-Regular.ttf', name='Noto Sans Carian', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,296 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/open-sans/OpenSans-Italic.ttf', name='Open Sans', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:16:59,296 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/unfonts-core/UnPilgi.ttf', name='UnPilgi', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,296 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/teluguvijayam/RaviPrakash.ttf', name='RaviPrakash', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,297 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/tlwg/Loma-BoldOblique.otf', name='Loma', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:16:59,297 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/Ubuntu-R.ttf', name='Ubuntu', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,297 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/arphic-gbsn00lp/gbsn00lp.ttf', name='AR PL SungtiL GB', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,298 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/adf/AccanthisADFStdNo3-BoldItalic.otf', name='Accanthis ADF Std No3', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:16:59,298 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansLao-Bold.ttf', name='Noto Sans Lao', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:16:59,298 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/magnet_env/fonts/SourceCodePro-ExtraLightIt.ttf', name='Source Code Pro', style='italic', variant='normal', weight=200, stretch='normal', size='scalable')) = 11.24
# 2026-06-12 10:16:59,298 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansArmenian-Bold.ttf', name='Noto Sans Armenian', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:16:59,299 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/unfonts-core/UnGungseo.ttf', name='UnGungseo', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,299 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansChakma-Regular.ttf', name='Noto Sans Chakma', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,299 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/linux-libertine/LinLibertine_RB.otf', name='Linux Libertine O', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:16:59,299 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/open-sans/OpenSans-CondBold.ttf', name='Open Sans Condensed', style='normal', variant='normal', weight=700, stretch='condensed', size='scalable')) = 10.535
# 2026-06-12 10:16:59,299 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/tlwg/TlwgTypewriter-BoldOblique.otf', name='Tlwg Typewriter', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:16:59,299 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/tlwg/TlwgTypist-Bold.otf', name='Tlwg Typist', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:16:59,300 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansBhaiksuki-Regular.ttf', name='Noto Sans Bhaiksuki', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,300 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-Regular.ttf', name='Lato', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,300 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/gentium-basic/GenBkBasR.ttf', name='Gentium Book Basic', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,300 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSansMono-BoldOblique.ttf', name='DejaVu Sans Mono', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:16:59,300 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ebgaramond/EBGaramond08-Regular.ttf', name='EB Garamond', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,301 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationSerif-Italic.ttf', name='Liberation Serif', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:16:59,301 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/neohellenic/GFSNeohellenicBoldIt.otf', name='GFS Neohellenic', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:16:59,301 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/open-sans/OpenSans-CondLight.ttf', name='Open Sans', style='normal', variant='normal', weight=300, stretch='condensed', size='scalable')) = 10.344999999999999
# 2026-06-12 10:16:59,301 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansAdlamUnjoined-Regular.ttf', name='Noto Sans Adlam Unjoined', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,301 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/ebgaramond/EBGaramond12-AllSC.otf', name='EB Garamond 12 All SC', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,302 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/kacst/KacstNaskh.ttf', name='KacstNaskh', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2026-06-12 10:16:59,302 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/UbuntuMono-R.ttf', name='Ubuntu Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,302 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifMyanmar-Regular.ttf', name='Noto Serif Myanmar', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,302 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/teluguvijayam/mallanna.ttf', name='Mallanna', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,302 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSerifCondensed.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=400, stretch='condensed', size='scalable')) = 10.25
# 2026-06-12 10:16:59,303 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/teluguvijayam/Mandali-Regular.ttf', name='Mandali', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,303 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/malayalam/Gayathri-Regular.otf', name='Gayathri', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,304 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansMandaic-Regular.ttf', name='Noto Sans Mandaic', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,304 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansDisplay-Bold.ttf', name='Noto Sans Display', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:16:59,304 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifArmenian-Regular.ttf', name='Noto Serif Armenian', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,304 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/roboto/unhinted/RobotoCondensed-Light.ttf', name='Roboto Condensed', style='normal', variant='normal', weight=300, stretch='condensed', size='scalable')) = 10.344999999999999
# 2026-06-12 10:16:59,304 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/open-sans/OpenSans-Regular.ttf', name='Open Sans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,305 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansDuployan-Regular.ttf', name='Noto Sans Duployan', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,305 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansIndicSiyaqNumbers-Regular.ttf', name='Noto Sans Indic Siyaq Numbers', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,305 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/adf/AccanthisADFStdNo2-BoldItalic.otf', name='Accanthis ADF Std No2', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:16:59,305 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/cantarell/Cantarell-Thin.otf', name='Cantarell', style='normal', variant='normal', weight=100, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:16:59,305 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusSans-Regular.otf', name='Nimbus Sans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,305 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSansNarrow-Bold.ttf', name='Liberation Sans Narrow', style='normal', variant='normal', weight=700, stretch='condensed', size='scalable')) = 10.535
# 2026-06-12 10:16:59,306 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/adf/UniversalisADFStd-BoldCond.otf', name='Universalis ADF Std', style='normal', variant='normal', weight=700, stretch='condensed', size='scalable')) = 10.535
# 2026-06-12 10:16:59,306 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/roboto/unhinted/RobotoTTF/Roboto-Bold.ttf', name='Roboto', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:16:59,306 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSans-Oblique.ttf', name='DejaVu Sans', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 1.05
# 2026-06-12 10:16:59,306 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifAhom-Regular.ttf', name='Noto Serif Ahom', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,306 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansGeorgian-Regular.ttf', name='Noto Sans Georgian', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,306 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansNabataean-Regular.ttf', name='Noto Sans Nabataean', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,307 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansCherokee-Regular.ttf', name='Noto Sans Cherokee', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,307 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/malayalam/Dyuthi-Regular.ttf', name='Dyuthi', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,307 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/theokritos/GFSTheokritos.otf', name='GFS Theokritos', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,307 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-yrsa-rasa/Yrsa-Italic.ttf', name='Yrsa', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:16:59,307 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/abyssinica/AbyssinicaSIL-Regular.ttf', name='Abyssinica SIL', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,308 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-yrsa-rasa/Yrsa-Light.ttf', name='Yrsa', style='normal', variant='normal', weight=300, stretch='normal', size='scalable')) = 10.145
# 2026-06-12 10:16:59,308 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/TlwgTypist-Bold.ttf', name='Tlwg Typist', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:16:59,308 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/charis/CharisSIL-BoldItalic.ttf', name='Charis SIL', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:16:59,308 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/teluguvijayam/TimmanaRegular.ttf', name='Timmana', style='normal', variant='normal', weight=900, stretch='normal', size='scalable')) = 10.525
# 2026-06-12 10:16:59,309 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansPauCinHau-Regular.ttf', name='Noto Sans Pau Cin Hau', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,310 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifTamilSlanted-Regular.ttf', name='Noto Serif Tamil Slanted', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,310 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansMedefaidrin-Regular.ttf', name='Noto Sans Medefaidrin', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,310 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/adf/GilliusADF-BoldCondItalic.otf', name='Gillius ADF', style='italic', variant='normal', weight=700, stretch='condensed', size='scalable')) = 11.535
# 2026-06-12 10:16:59,310 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/ipaexfont-gothic/ipaexg.ttf', name='IPAexGothic', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,310 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationSans-Italic.ttf', name='Liberation Sans', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:16:59,311 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/stix/STIXIntegralsUp-Regular.otf', name='STIXIntegralsUp', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,311 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-yrsa-rasa/Rasa-Medium.ttf', name='Rasa', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2026-06-12 10:16:59,311 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansGujarati-Regular.ttf', name='Noto Sans Gujarati', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,311 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/lobstertwo/LobsterTwo-Regular.otf', name='Lobster Two', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,311 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/stix/STIXIntegralsSm-Bold.otf', name='STIXIntegralsSm', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:16:59,311 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSansNarrow-Regular.ttf', name='Liberation Sans Narrow', style='normal', variant='normal', weight=400, stretch='condensed', size='scalable')) = 10.25
# 2026-06-12 10:16:59,312 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lyx/rsfs10.ttf', name='rsfs10', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:16:59,312 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifBengali-Bold.ttf', name='Noto Serif Bengali', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:16:59,313 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/magnet_env/fonts/DejaVuSans.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 0.05
# 2026-06-12 10:16:59,313 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansDisplay-Italic.ttf', name='Noto Sans Display', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:16:59,313 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSans-Italic.ttf', name='Noto Sans', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:16:59,313 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-beng-extra/Ani.ttf', name='Ani', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,313 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifSinhala-Bold.ttf', name='Noto Serif Sinhala', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:16:59,313 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-orya-extra/utkal.ttf', name='ori1Uni', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2026-06-12 10:16:59,314 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/linux-libertine/LinLibertine_RBI.otf', name='Linux Libertine O', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:16:59,314 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifTamil-Regular.ttf', name='Noto Serif Tamil', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,314 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/fonts-hosny-amiri/Amiri-Bold.ttf', name='Amiri', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:16:59,314 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoTraditionalNushu-Regular.ttf', name='Noto Traditional Nushu', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,314 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/comfortaa/Comfortaa-Regular.ttf', name='Comfortaa', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,315 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/fonts-hosny-amiri/Amiri-BoldSlanted.ttf', name='Amiri', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:16:59,315 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/roboto/unhinted/RobotoTTF/Roboto-BoldItalic.ttf', name='Roboto', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:16:59,315 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-Italic.ttf', name='Lato', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:16:59,316 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansLepcha-Regular.ttf', name='Noto Sans Lepcha', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,316 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/teluguvijayam/dhurjati.ttf', name='Dhurjati', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,316 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/malayalam/Chilanka-Regular.otf', name='Chilanka', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,316 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/malayalam/Suruma.ttf', name='Suruma', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2026-06-12 10:16:59,317 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Waree-Oblique.ttf', name='Waree', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:16:59,317 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoNaskhArabic-Regular.ttf', name='Noto Naskh Arabic', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,317 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/fonts-go/Go-Bold.ttf', name='Go', style='normal', variant='normal', weight=600, stretch='normal', size='scalable')) = 10.24
# 2026-06-12 10:16:59,317 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansCypriot-Regular.ttf', name='Noto Sans Cypriot', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,317 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-BoldItalic.ttf', name='Lato', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:16:59,318 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansZanabazarSquare-Regular.ttf', name='Noto Sans Zanabazar Square', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,318 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansHatran-Regular.ttf', name='Noto Sans Hatran', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,318 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/gentium-basic/GenBasI.ttf', name='Gentium Basic', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:16:59,318 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Sawasdee-Bold.ttf', name='Sawasdee', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:16:59,318 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-deva-extra/samanata.ttf', name='Samanata', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,318 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansSundanese-Regular.ttf', name='Noto Sans Sundanese', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,319 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeSerifItalic.ttf', name='FreeSerif', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:16:59,319 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/freefont/FreeMonoBold.otf', name='FreeMono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:16:59,319 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/Gargi/Gargi.ttf', name='Gargi', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,319 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSans-ExtraLight.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=200, stretch='normal', size='scalable')) = 0.24
# 2026-06-12 10:16:59,319 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifGujarati-Bold.ttf', name='Noto Serif Gujarati', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:16:59,320 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/stix/STIXVariants-Bold.otf', name='STIXVariants', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:16:59,320 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoLoopedLao-Bold.ttf', name='Noto Looped Lao', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:16:59,320 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/StandardSymbolsPS.otf', name='Standard Symbols PS', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,320 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/P052-BoldItalic.otf', name='P052', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:16:59,320 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Garuda-Bold.ttf', name='Garuda', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:16:59,320 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusSansNarrow-Bold.otf', name='Nimbus Sans Narrow', style='normal', variant='normal', weight=700, stretch='condensed', size='scalable')) = 10.535
# 2026-06-12 10:16:59,321 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/Sarai/Sarai.ttf', name='Sarai', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,321 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifTamilSlanted-Bold.ttf', name='Noto Serif Tamil Slanted', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:16:59,321 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/crosextra/Carlito-Regular.ttf', name='Carlito', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,321 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-beng-extra/LikhanNormal.ttf', name='Likhan', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2026-06-12 10:16:59,321 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/stix/STIXSizeFiveSym-Regular.otf', name='STIXSizeFiveSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,321 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/gentium/Gentium-R.ttf', name='Gentium', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,322 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/magnet_env/fonts/Ubuntu-LI.ttf', name='Ubuntu', style='italic', variant='normal', weight=300, stretch='normal', size='scalable')) = 11.145
# 2026-06-12 10:16:59,322 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-MediumItalic.ttf', name='Lato', style='italic', variant='normal', weight=500, stretch='normal', size='scalable')) = 11.145
# 2026-06-12 10:16:59,322 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Loma-Oblique.ttf', name='Loma', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:16:59,322 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/gentiumplus/GentiumBookPlus-Bold.ttf', name='Gentium Book Plus', style='normal', variant='normal', weight=800, stretch='normal', size='scalable')) = 10.43
# 2026-06-12 10:16:59,322 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lohit-punjabi/Lohit-Gurmukhi.ttf', name='Lohit Gurmukhi', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,323 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/adf/GilliusADF-CondItalic.otf', name='Gillius ADF', style='italic', variant='normal', weight=400, stretch='condensed', size='scalable')) = 11.25
# 2026-06-12 10:16:59,324 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifGeorgian-Bold.ttf', name='Noto Serif Georgian', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:16:59,324 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/charis/CharisSIL-Italic.ttf', name='Charis SIL', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:16:59,324 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansNKo-Regular.ttf', name='Noto Sans NKo', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,325 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/URWBookman-Demi.otf', name='URW Bookman', style='normal', variant='normal', weight=600, stretch='normal', size='scalable')) = 10.24
# 2026-06-12 10:16:59,325 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/stix/STIXNonUnicode-Italic.otf', name='STIXNonUnicode', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:16:59,325 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/TlwgTypewriter.ttf', name='Tlwg Typewriter', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:16:59,325 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/roboto/unhinted/RobotoCondensed-Regular.ttf', name='Roboto Condensed', style='normal', variant='normal', weight=400, stretch='condensed', size='scalable')) = 10.25
# ...
# 2026-06-12 10:17:00,161 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/adf/UniversalisADFStd-Regular.otf', name='Universalis ADF Std', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:00,162 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lyx/cmsy10.ttf', name='cmsy10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:00,162 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansArabic-Bold.ttf', name='Noto Sans Arabic', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:00,162 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSans-BoldItalic.ttf', name='Noto Sans', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:17:00,162 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/linux-libertine/LinLibertine_RZI.otf', name='Linux Libertine O', style='italic', variant='normal', weight=600, stretch='normal', size='scalable')) = 11.24
# 2026-06-12 10:17:00,162 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/roboto/unhinted/RobotoTTF/Roboto-Italic.ttf', name='Roboto', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:17:00,163 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/croscore/Tinos-BoldItalic.ttf', name='Tinos', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:17:00,163 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansLycian-Regular.ttf', name='Noto Sans Lycian', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:00,164 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/adf/GilliusADF-BoldCond.otf', name='Gillius ADF', style='normal', variant='normal', weight=700, stretch='condensed', size='scalable')) = 10.535
# 2026-06-12 10:17:00,165 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ttf-khmeros-core/KhmerOS.ttf', name='Khmer OS', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:00,165 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/unfonts-extra/UnTaza.ttf', name='UnTaza', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:00,165 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/fonts-go/Go-Mono-Bold.ttf', name='Go Mono', style='normal', variant='normal', weight=600, stretch='normal', size='scalable')) = 10.24
# 2026-06-12 10:17:00,165 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansDisplay-Regular.ttf', name='Noto Sans Display', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:00,166 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansPalmyrene-Regular.ttf', name='Noto Sans Palmyrene', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:00,166 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/olga/GFSOlga.otf', name='GFS Olga', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:00,166 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Laksaman-BoldItalic.ttf', name='Laksaman', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:17:00,166 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/adf/BerenisADFPro-Regular.otf', name='Berenis ADF Pro', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:00,166 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeSerifBold.ttf', name='FreeSerif', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:00,166 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationSans-BoldItalic.ttf', name='Liberation Sans', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:17:00,167 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerif-Italic.ttf', name='Noto Serif', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:17:00,167 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Kinnari-BoldOblique.ttf', name='Kinnari', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:17:00,167 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/gentiumplus-compact/GentiumPlusCompact-I.ttf', name='Gentium Plus Compact', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:17:00,167 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansOldSogdian-Regular.ttf', name='Noto Sans Old Sogdian', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:00,167 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeSansBoldOblique.ttf', name='FreeSans', style='oblique', variant='normal', weight=600, stretch='normal', size='scalable')) = 11.24
# 2026-06-12 10:17:00,167 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/Ubuntu-B.ttf', name='Ubuntu', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:00,168 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/magnet_env/fonts/SourceCodePro-MediumIt.ttf', name='Source Code Pro', style='italic', variant='normal', weight=500, stretch='normal', size='scalable')) = 11.145
# 2026-06-12 10:17:00,168 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/kacst/KacstBook.ttf', name='KacstBook', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2026-06-12 10:17:00,168 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifNyiakengPuachueHmong-Bold.ttf', name='Noto Serif Hmong Nyiakeng', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:00,168 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansKannada-Regular.ttf', name='Noto Sans Kannada', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:00,168 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/unfonts-extra/UnJamoDotum.ttf', name='UnJamoDotum', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:00,169 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/tlwg/TlwgMono.otf', name='Tlwg Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:00,169 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/unfonts-extra/UnPilgia.ttf', name='UnPilgia', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:00,170 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/stix/STIXGeneral-Italic.otf', name='STIXGeneral', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:17:00,170 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/Ubuntu-RI.ttf', name='Ubuntu', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:17:00,170 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifThai-Regular.ttf', name='Noto Serif Thai', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:00,170 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/fonts-go/Go-Regular.ttf', name='Go', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:00,171 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansBamum-Bold.ttf', name='Noto Sans Bamum', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:00,171 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lyx/stmary10.ttf', name='stmary10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:00,171 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-Medium.ttf', name='Lato', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2026-06-12 10:17:00,172 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifKhojki-Bold.ttf', name='Noto Serif Khojki', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:00,172 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Norasi.ttf', name='Norasi', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:00,172 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansTaiViet-Regular.ttf', name='Noto Sans Tai Viet', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:00,172 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/comfortaa/Comfortaa-Bold.ttf', name='Comfortaa', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:00,173 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusMonoPS-Regular.otf', name='Nimbus Mono PS', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:00,173 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSansNarrow-BoldItalic.ttf', name='Liberation Sans Narrow', style='italic', variant='normal', weight=700, stretch='condensed', size='scalable')) = 11.535
# 2026-06-12 10:17:00,173 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/didot/GFSDidotBold.otf', name='GFS Didot', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:00,173 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/UbuntuMono-B.ttf', name='Ubuntu Mono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:00,173 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansCoptic-Regular.ttf', name='Noto Sans Coptic', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:00,174 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansBuhid-Regular.ttf', name='Noto Sans Buhid', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:00,174 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerif-BoldItalic.ttf', name='Noto Serif', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:17:00,174 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Kinnari-Bold.ttf', name='Kinnari', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:00,174 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansCherokee-Bold.ttf', name='Noto Sans Cherokee', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:00,175 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/freefont/FreeMonoBoldOblique.otf', name='FreeMono', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:17:00,175 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/unfonts-core/UnGraphicBold.ttf', name='UnGraphic', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:00,175 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-Heavy.ttf', name='Lato', style='normal', variant='normal', weight=800, stretch='normal', size='scalable')) = 10.43
# 2026-06-12 10:17:00,175 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-deva-extra/chandas1-2.ttf', name='Chandas', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:00,175 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-beng-extra/MitraMono.ttf', name='Mitra ', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:00,175 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifEthiopic-Regular.ttf', name='Noto Serif Ethiopic', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:00,176 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/adf/GilliusADF-Cond.otf', name='Gillius ADF', style='normal', variant='normal', weight=400, stretch='condensed', size='scalable')) = 10.25
# 2026-06-12 10:17:00,176 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-Black.ttf', name='Lato', style='normal', variant='normal', weight=900, stretch='normal', size='scalable')) = 10.525
# 2026-06-12 10:17:00,176 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationSans-Bold.ttf', name='Liberation Sans', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:00,176 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/fonts-go/Go-Mono-Italic.ttf', name='Go Mono', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:17:00,176 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifDogra-Regular.ttf', name='Noto Serif Dogra', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:00,177 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifHebrew-Bold.ttf', name='Noto Serif Hebrew', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:00,177 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/adf/AccanthisADFStdNo3-Regular.otf', name='Accanthis ADF Std No3', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:00,177 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-telu-extra/Pothana2000.ttf', name='Pothana2000', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:00,177 - DEBUG - findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=5.0 to DejaVu Sans ('/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000.

# %%
# calculate rate for each grid point after history event
epsilon = 1e-4
rates = etas_rate_at_xy(lon_flat, lat_flat, history_dict["t"] + epsilon, history_dict, THETA_0)



def _polygon_parts(geom):
    if geom.is_empty:
        return
    if geom.geom_type == "Polygon":
        yield geom
    elif geom.geom_type == "MultiPolygon":
        yield from geom.geoms
    elif geom.geom_type == "GeometryCollection":
        for g in geom.geoms:
            yield from _polygon_parts(g)


# Same clipped Voronoi cells as grid_recreations_point_process.ipynb (fig_rate cell).
fig, ax = plt.subplots(figsize=(12, 10))
norm = colors.LogNorm(vmin=np.min(rates), vmax=np.max(rates))
cmap = plt.cm.viridis

for j, cell in enumerate(ordered_cells):
    color = cmap(norm(rates[j]))
    for part in _polygon_parts(cell):
        xy = np.asarray(part.exterior.coords)  # x=lon, y=lat
        ax.add_patch(
            mpatches.Polygon(
                xy,
                closed=True,
                facecolor=color,
                edgecolor="k",
                alpha=0.8,
                linewidth=0.4,
            )
        )

poly_coords = np.asarray(polygon.exterior.coords)
lat_poly, lon_poly = poly_coords[:, 0], poly_coords[:, 1]
ax.plot(lon_poly, lat_poly, color="black", linewidth=2, label="Polygon boundary")

ax.scatter(lon_flat, lat_flat, s=8, c="red", zorder=5, label="Grid points")

sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
cbar = plt.colorbar(sm, ax=ax, shrink=0.8, pad=0.03)
cbar.set_label("Rate")

ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")
ax.set_title("Rate of earthquakes after history event")
ax.set_aspect("equal")
ax.set_xlim(np.min(lon_flat) - 0.2, np.max(lon_flat) + 0.2)
ax.set_ylim(np.min(lat_flat) - 0.2, np.max(lat_flat) + 0.2)
ax.legend()
plt.show()
# Out:
# 2026-06-12 10:17:00,908 - DEBUG - locator: <matplotlib.ticker.LogLocator object at 0x761b2ab98650>
# 2026-06-12 10:17:01,142 - DEBUG - vmin 1.5915767684475103e-06 vmax 0.007265277536024621
# 2026-06-12 10:17:01,143 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-12 10:17:01,146 - DEBUG - vmin 1.5915767684475103e-06 vmax 0.007265277536024621
# 2026-06-12 10:17:01,146 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-12 10:17:01,147 - DEBUG - vmin 1.5915767684475103e-06 vmax 0.007265277536024621
# 2026-06-12 10:17:01,147 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-12 10:17:01,168 - DEBUG - findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0.
# 2026-06-12 10:17:01,169 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/cmr10.ttf', name='cmr10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,169 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymReg.ttf', name='STIXSizeOneSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,169 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,169 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymReg.ttf', name='STIXSizeTwoSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,170 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Bold.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 0.33499999999999996
# 2026-06-12 10:17:01,170 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/cmb10.ttf', name='cmb10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,170 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniBolIta.ttf', name='STIXNonUnicode', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:17:01,170 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-BoldOblique.ttf', name='DejaVu Sans Mono', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:17:01,170 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymBol.ttf', name='STIXSizeFourSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:01,171 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniBol.ttf', name='STIXNonUnicode', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:01,171 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneral.ttf', name='STIXGeneral', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,171 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Bold.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:01,172 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymBol.ttf', name='STIXSizeOneSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:01,172 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/cmex10.ttf', name='cmex10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,172 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUni.ttf', name='STIXNonUnicode', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,172 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymReg.ttf', name='STIXSizeThreeSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,172 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralBolIta.ttf', name='STIXGeneral', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:17:01,173 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Oblique.ttf', name='DejaVu Sans Mono', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:17:01,173 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,173 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansDisplay.ttf', name='DejaVu Sans Display', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,173 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniIta.ttf', name='STIXNonUnicode', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:17:01,173 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/cmsy10.ttf', name='cmsy10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,174 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/cmtt10.ttf', name='cmtt10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,174 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-BoldItalic.ttf', name='DejaVu Serif', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:17:01,174 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Oblique.ttf', name='DejaVu Sans', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 1.05
# 2026-06-12 10:17:01,174 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Bold.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:01,174 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymBol.ttf', name='STIXSizeThreeSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:01,174 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralItalic.ttf', name='STIXGeneral', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:17:01,175 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-BoldOblique.ttf', name='DejaVu Sans', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 1.335
# 2026-06-12 10:17:01,175 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Italic.ttf', name='DejaVu Serif', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:17:01,175 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymBol.ttf', name='STIXSizeTwoSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:01,175 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 0.05
# 2026-06-12 10:17:01,175 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralBol.ttf', name='STIXGeneral', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:01,176 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerifDisplay.ttf', name='DejaVu Serif Display', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,176 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymReg.ttf', name='STIXSizeFourSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,176 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/cmmi10.ttf', name='cmmi10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,176 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/cmss10.ttf', name='cmss10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,176 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFiveSymReg.ttf', name='STIXSizeFiveSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,176 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/croscore/Arimo-Italic.ttf', name='Arimo', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:17:01,177 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansMongolian-Regular.ttf', name='Noto Sans Mongolian', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,177 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/arphic-bsmi00lp/bsmi00lp.ttf', name='AR PL Mingti2L Big5', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,177 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSerifCondensed-Bold.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=700, stretch='condensed', size='scalable')) = 10.535
# 2026-06-12 10:17:01,178 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Norasi-Bold.ttf', name='Norasi', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:01,179 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationMono-Regular.ttf', name='Liberation Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,179 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansTifinaghAPT-Regular.ttf', name='Noto Sans Tifinagh APT', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,179 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/magnet_env/fonts/SourceCodePro-ExtraLight.ttf', name='Source Code Pro', style='normal', variant='normal', weight=200, stretch='normal', size='scalable')) = 10.24
# 2026-06-12 10:17:01,179 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansHanifiRohingya-Regular.ttf', name='Noto Sans Hanifi Rohingya', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,179 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusRoman-Italic.otf', name='Nimbus Roman', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:17:01,180 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifBalinese-Regular.ttf', name='Noto Serif Balinese', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,180 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-LightItalic.ttf', name='Lato', style='italic', variant='normal', weight=300, stretch='normal', size='scalable')) = 11.145
# 2026-06-12 10:17:01,180 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Garuda.ttf', name='Garuda', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,180 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifNyiakengPuachueHmong-Regular.ttf', name='Noto Serif Hmong Nyiakeng', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,180 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansCarian-Regular.ttf', name='Noto Sans Carian', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,181 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/open-sans/OpenSans-Italic.ttf', name='Open Sans', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:17:01,181 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/unfonts-core/UnPilgi.ttf', name='UnPilgi', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,181 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/teluguvijayam/RaviPrakash.ttf', name='RaviPrakash', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,181 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/tlwg/Loma-BoldOblique.otf', name='Loma', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:17:01,181 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/Ubuntu-R.ttf', name='Ubuntu', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,181 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/arphic-gbsn00lp/gbsn00lp.ttf', name='AR PL SungtiL GB', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,182 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/adf/AccanthisADFStdNo3-BoldItalic.otf', name='Accanthis ADF Std No3', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:17:01,182 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansLao-Bold.ttf', name='Noto Sans Lao', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:01,182 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/magnet_env/fonts/SourceCodePro-ExtraLightIt.ttf', name='Source Code Pro', style='italic', variant='normal', weight=200, stretch='normal', size='scalable')) = 11.24
# 2026-06-12 10:17:01,182 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansArmenian-Bold.ttf', name='Noto Sans Armenian', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:01,182 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/unfonts-core/UnGungseo.ttf', name='UnGungseo', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,183 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansChakma-Regular.ttf', name='Noto Sans Chakma', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,183 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/linux-libertine/LinLibertine_RB.otf', name='Linux Libertine O', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:01,183 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/open-sans/OpenSans-CondBold.ttf', name='Open Sans Condensed', style='normal', variant='normal', weight=700, stretch='condensed', size='scalable')) = 10.535
# 2026-06-12 10:17:01,184 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/tlwg/TlwgTypewriter-BoldOblique.otf', name='Tlwg Typewriter', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:17:01,184 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/tlwg/TlwgTypist-Bold.otf', name='Tlwg Typist', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:01,185 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansBhaiksuki-Regular.ttf', name='Noto Sans Bhaiksuki', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,185 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-Regular.ttf', name='Lato', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,185 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/gentium-basic/GenBkBasR.ttf', name='Gentium Book Basic', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,185 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSansMono-BoldOblique.ttf', name='DejaVu Sans Mono', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:17:01,185 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ebgaramond/EBGaramond08-Regular.ttf', name='EB Garamond', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,186 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationSerif-Italic.ttf', name='Liberation Serif', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:17:01,186 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/neohellenic/GFSNeohellenicBoldIt.otf', name='GFS Neohellenic', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:17:01,186 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/open-sans/OpenSans-CondLight.ttf', name='Open Sans', style='normal', variant='normal', weight=300, stretch='condensed', size='scalable')) = 10.344999999999999
# 2026-06-12 10:17:01,186 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansAdlamUnjoined-Regular.ttf', name='Noto Sans Adlam Unjoined', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,186 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/ebgaramond/EBGaramond12-AllSC.otf', name='EB Garamond 12 All SC', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,186 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/kacst/KacstNaskh.ttf', name='KacstNaskh', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2026-06-12 10:17:01,187 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/UbuntuMono-R.ttf', name='Ubuntu Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,187 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifMyanmar-Regular.ttf', name='Noto Serif Myanmar', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,188 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/teluguvijayam/mallanna.ttf', name='Mallanna', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,188 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSerifCondensed.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=400, stretch='condensed', size='scalable')) = 10.25
# 2026-06-12 10:17:01,188 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/teluguvijayam/Mandali-Regular.ttf', name='Mandali', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,188 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/malayalam/Gayathri-Regular.otf', name='Gayathri', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,188 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansMandaic-Regular.ttf', name='Noto Sans Mandaic', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,189 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansDisplay-Bold.ttf', name='Noto Sans Display', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:01,189 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifArmenian-Regular.ttf', name='Noto Serif Armenian', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,189 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/roboto/unhinted/RobotoCondensed-Light.ttf', name='Roboto Condensed', style='normal', variant='normal', weight=300, stretch='condensed', size='scalable')) = 10.344999999999999
# 2026-06-12 10:17:01,189 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/open-sans/OpenSans-Regular.ttf', name='Open Sans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,189 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansDuployan-Regular.ttf', name='Noto Sans Duployan', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,189 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansIndicSiyaqNumbers-Regular.ttf', name='Noto Sans Indic Siyaq Numbers', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,190 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/adf/AccanthisADFStdNo2-BoldItalic.otf', name='Accanthis ADF Std No2', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:17:01,190 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/cantarell/Cantarell-Thin.otf', name='Cantarell', style='normal', variant='normal', weight=100, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:01,191 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusSans-Regular.otf', name='Nimbus Sans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,191 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSansNarrow-Bold.ttf', name='Liberation Sans Narrow', style='normal', variant='normal', weight=700, stretch='condensed', size='scalable')) = 10.535
# 2026-06-12 10:17:01,191 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/adf/UniversalisADFStd-BoldCond.otf', name='Universalis ADF Std', style='normal', variant='normal', weight=700, stretch='condensed', size='scalable')) = 10.535
# 2026-06-12 10:17:01,191 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/roboto/unhinted/RobotoTTF/Roboto-Bold.ttf', name='Roboto', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:01,191 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSans-Oblique.ttf', name='DejaVu Sans', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 1.05
# 2026-06-12 10:17:01,192 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifAhom-Regular.ttf', name='Noto Serif Ahom', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,192 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansGeorgian-Regular.ttf', name='Noto Sans Georgian', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,192 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansNabataean-Regular.ttf', name='Noto Sans Nabataean', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,192 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansCherokee-Regular.ttf', name='Noto Sans Cherokee', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,192 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/malayalam/Dyuthi-Regular.ttf', name='Dyuthi', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,193 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/theokritos/GFSTheokritos.otf', name='GFS Theokritos', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,193 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-yrsa-rasa/Yrsa-Italic.ttf', name='Yrsa', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:17:01,193 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/abyssinica/AbyssinicaSIL-Regular.ttf', name='Abyssinica SIL', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,193 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-yrsa-rasa/Yrsa-Light.ttf', name='Yrsa', style='normal', variant='normal', weight=300, stretch='normal', size='scalable')) = 10.145
# 2026-06-12 10:17:01,193 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/TlwgTypist-Bold.ttf', name='Tlwg Typist', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:01,193 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/charis/CharisSIL-BoldItalic.ttf', name='Charis SIL', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:17:01,194 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/teluguvijayam/TimmanaRegular.ttf', name='Timmana', style='normal', variant='normal', weight=900, stretch='normal', size='scalable')) = 10.525
# 2026-06-12 10:17:01,194 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansPauCinHau-Regular.ttf', name='Noto Sans Pau Cin Hau', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,194 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifTamilSlanted-Regular.ttf', name='Noto Serif Tamil Slanted', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,194 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansMedefaidrin-Regular.ttf', name='Noto Sans Medefaidrin', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,194 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/adf/GilliusADF-BoldCondItalic.otf', name='Gillius ADF', style='italic', variant='normal', weight=700, stretch='condensed', size='scalable')) = 11.535
# 2026-06-12 10:17:01,194 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/ipaexfont-gothic/ipaexg.ttf', name='IPAexGothic', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,195 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationSans-Italic.ttf', name='Liberation Sans', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:17:01,195 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/stix/STIXIntegralsUp-Regular.otf', name='STIXIntegralsUp', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,195 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-yrsa-rasa/Rasa-Medium.ttf', name='Rasa', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2026-06-12 10:17:01,195 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansGujarati-Regular.ttf', name='Noto Sans Gujarati', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,195 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/lobstertwo/LobsterTwo-Regular.otf', name='Lobster Two', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,196 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/stix/STIXIntegralsSm-Bold.otf', name='STIXIntegralsSm', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:01,196 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSansNarrow-Regular.ttf', name='Liberation Sans Narrow', style='normal', variant='normal', weight=400, stretch='condensed', size='scalable')) = 10.25
# 2026-06-12 10:17:01,196 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lyx/rsfs10.ttf', name='rsfs10', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:17:01,196 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifBengali-Bold.ttf', name='Noto Serif Bengali', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:01,196 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/magnet_env/fonts/DejaVuSans.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 0.05
# 2026-06-12 10:17:01,196 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansDisplay-Italic.ttf', name='Noto Sans Display', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:17:01,197 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSans-Italic.ttf', name='Noto Sans', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:17:01,197 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-beng-extra/Ani.ttf', name='Ani', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,197 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifSinhala-Bold.ttf', name='Noto Serif Sinhala', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:01,197 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-orya-extra/utkal.ttf', name='ori1Uni', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2026-06-12 10:17:01,197 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/linux-libertine/LinLibertine_RBI.otf', name='Linux Libertine O', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:17:01,198 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifTamil-Regular.ttf', name='Noto Serif Tamil', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,198 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/fonts-hosny-amiri/Amiri-Bold.ttf', name='Amiri', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:01,198 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoTraditionalNushu-Regular.ttf', name='Noto Traditional Nushu', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,198 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/comfortaa/Comfortaa-Regular.ttf', name='Comfortaa', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,200 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/fonts-hosny-amiri/Amiri-BoldSlanted.ttf', name='Amiri', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:17:01,200 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/roboto/unhinted/RobotoTTF/Roboto-BoldItalic.ttf', name='Roboto', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:17:01,200 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-Italic.ttf', name='Lato', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:17:01,200 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansLepcha-Regular.ttf', name='Noto Sans Lepcha', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,201 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/teluguvijayam/dhurjati.ttf', name='Dhurjati', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,201 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/malayalam/Chilanka-Regular.otf', name='Chilanka', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,201 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/malayalam/Suruma.ttf', name='Suruma', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2026-06-12 10:17:01,202 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Waree-Oblique.ttf', name='Waree', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:17:01,202 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoNaskhArabic-Regular.ttf', name='Noto Naskh Arabic', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,202 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/fonts-go/Go-Bold.ttf', name='Go', style='normal', variant='normal', weight=600, stretch='normal', size='scalable')) = 10.24
# 2026-06-12 10:17:01,202 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansCypriot-Regular.ttf', name='Noto Sans Cypriot', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,202 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-BoldItalic.ttf', name='Lato', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:17:01,203 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansZanabazarSquare-Regular.ttf', name='Noto Sans Zanabazar Square', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,203 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansHatran-Regular.ttf', name='Noto Sans Hatran', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,203 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/gentium-basic/GenBasI.ttf', name='Gentium Basic', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:17:01,203 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Sawasdee-Bold.ttf', name='Sawasdee', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:01,204 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-deva-extra/samanata.ttf', name='Samanata', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,204 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansSundanese-Regular.ttf', name='Noto Sans Sundanese', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,204 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeSerifItalic.ttf', name='FreeSerif', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:17:01,204 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/freefont/FreeMonoBold.otf', name='FreeMono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:01,205 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/Gargi/Gargi.ttf', name='Gargi', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,205 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSans-ExtraLight.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=200, stretch='normal', size='scalable')) = 0.24
# 2026-06-12 10:17:01,205 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifGujarati-Bold.ttf', name='Noto Serif Gujarati', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:01,205 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/stix/STIXVariants-Bold.otf', name='STIXVariants', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:01,205 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoLoopedLao-Bold.ttf', name='Noto Looped Lao', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:01,205 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/StandardSymbolsPS.otf', name='Standard Symbols PS', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,206 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/P052-BoldItalic.otf', name='P052', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:17:01,206 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Garuda-Bold.ttf', name='Garuda', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:01,206 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusSansNarrow-Bold.otf', name='Nimbus Sans Narrow', style='normal', variant='normal', weight=700, stretch='condensed', size='scalable')) = 10.535
# 2026-06-12 10:17:01,206 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/Sarai/Sarai.ttf', name='Sarai', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,206 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifTamilSlanted-Bold.ttf', name='Noto Serif Tamil Slanted', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:01,207 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/crosextra/Carlito-Regular.ttf', name='Carlito', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,207 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-beng-extra/LikhanNormal.ttf', name='Likhan', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2026-06-12 10:17:01,207 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/stix/STIXSizeFiveSym-Regular.otf', name='STIXSizeFiveSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,207 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/gentium/Gentium-R.ttf', name='Gentium', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,207 - DEBUG - findfont: score(FontEntry(fname='/a/home/cc/students/csguests/neriberman/anaconda3/envs/magnet_env/fonts/Ubuntu-LI.ttf', name='Ubuntu', style='italic', variant='normal', weight=300, stretch='normal', size='scalable')) = 11.145
# 2026-06-12 10:17:01,207 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-MediumItalic.ttf', name='Lato', style='italic', variant='normal', weight=500, stretch='normal', size='scalable')) = 11.145
# 2026-06-12 10:17:01,208 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Loma-Oblique.ttf', name='Loma', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:17:01,209 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/gentiumplus/GentiumBookPlus-Bold.ttf', name='Gentium Book Plus', style='normal', variant='normal', weight=800, stretch='normal', size='scalable')) = 10.43
# 2026-06-12 10:17:01,209 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lohit-punjabi/Lohit-Gurmukhi.ttf', name='Lohit Gurmukhi', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:01,209 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/adf/GilliusADF-CondItalic.otf', name='Gillius ADF', style='italic', variant='normal', weight=400, stretch='condensed', size='scalable')) = 11.25
# 2026-06-12 10:17:01,209 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifGeorgian-Bold.ttf', name='Noto Serif Georgian', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:01,209 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/charis/CharisSIL-Italic.ttf', name='Charis SIL', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:17:01,210 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansNKo-Regular.ttf', name='Noto Sans NKo', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# ...
# 2026-06-12 10:17:07,379 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifThai-Regular.ttf', name='Noto Serif Thai', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:07,379 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/fonts-go/Go-Regular.ttf', name='Go', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:07,379 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansBamum-Bold.ttf', name='Noto Sans Bamum', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:07,379 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lyx/stmary10.ttf', name='stmary10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:07,380 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-Medium.ttf', name='Lato', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2026-06-12 10:17:07,380 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifKhojki-Bold.ttf', name='Noto Serif Khojki', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:07,380 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Norasi.ttf', name='Norasi', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:07,380 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansTaiViet-Regular.ttf', name='Noto Sans Tai Viet', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:07,381 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/comfortaa/Comfortaa-Bold.ttf', name='Comfortaa', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:07,381 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusMonoPS-Regular.otf', name='Nimbus Mono PS', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:07,381 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSansNarrow-BoldItalic.ttf', name='Liberation Sans Narrow', style='italic', variant='normal', weight=700, stretch='condensed', size='scalable')) = 11.535
# 2026-06-12 10:17:07,381 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/didot/GFSDidotBold.otf', name='GFS Didot', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:07,381 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/UbuntuMono-B.ttf', name='Ubuntu Mono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:07,382 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansCoptic-Regular.ttf', name='Noto Sans Coptic', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:07,382 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansBuhid-Regular.ttf', name='Noto Sans Buhid', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:07,382 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerif-BoldItalic.ttf', name='Noto Serif', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:17:07,382 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Kinnari-Bold.ttf', name='Kinnari', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:07,383 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansCherokee-Bold.ttf', name='Noto Sans Cherokee', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:07,383 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/freefont/FreeMonoBoldOblique.otf', name='FreeMono', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2026-06-12 10:17:07,383 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/unfonts-core/UnGraphicBold.ttf', name='UnGraphic', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:07,383 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-Heavy.ttf', name='Lato', style='normal', variant='normal', weight=800, stretch='normal', size='scalable')) = 10.43
# 2026-06-12 10:17:07,384 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-deva-extra/chandas1-2.ttf', name='Chandas', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:07,384 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-beng-extra/MitraMono.ttf', name='Mitra ', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:07,384 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifEthiopic-Regular.ttf', name='Noto Serif Ethiopic', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:07,384 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/adf/GilliusADF-Cond.otf', name='Gillius ADF', style='normal', variant='normal', weight=400, stretch='condensed', size='scalable')) = 10.25
# 2026-06-12 10:17:07,384 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lato/Lato-Black.ttf', name='Lato', style='normal', variant='normal', weight=900, stretch='normal', size='scalable')) = 10.525
# 2026-06-12 10:17:07,384 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationSans-Bold.ttf', name='Liberation Sans', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:07,385 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/fonts-go/Go-Mono-Italic.ttf', name='Go Mono', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2026-06-12 10:17:07,385 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifDogra-Regular.ttf', name='Noto Serif Dogra', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:07,385 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSerifHebrew-Bold.ttf', name='Noto Serif Hebrew', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2026-06-12 10:17:07,385 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/adf/AccanthisADFStdNo3-Regular.otf', name='Accanthis ADF Std No3', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:07,385 - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-telu-extra/Pothana2000.ttf', name='Pothana2000', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2026-06-12 10:17:07,386 - DEBUG - findfont: Matching DejaVu Sans Display:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0 to DejaVu Sans Display ('/a/home/cc/students/csguests/neriberman/anaconda3/envs/etas_remote/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansDisplay.ttf') with score of 0.050000.
# 2026-06-12 10:17:07,416 - DEBUG - vmin 1.5915767684475103e-06 vmax 0.007265277536024621
# 2026-06-12 10:17:07,417 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-12 10:17:07,418 - DEBUG - vmin 1.5915767684475103e-06 vmax 0.007265277536024621
# 2026-06-12 10:17:07,418 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-12 10:17:07,419 - DEBUG - vmin 1.5915767684475103e-06 vmax 0.007265277536024621
# 2026-06-12 10:17:07,419 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-12 10:17:07,422 - DEBUG - vmin 1.5915767684475103e-06 vmax 0.007265277536024621
# 2026-06-12 10:17:07,422 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-12 10:17:07,422 - DEBUG - vmin 1.5915767684475103e-06 vmax 0.007265277536024621
# 2026-06-12 10:17:07,423 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-12 10:17:07,423 - DEBUG - vmin 1.5915767684475103e-06 vmax 0.007265277536024621
# 2026-06-12 10:17:07,423 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-12 10:17:07,503 - DEBUG - vmin 1.5915767684475103e-06 vmax 0.007265277536024621
# 2026-06-12 10:17:07,504 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-12 10:17:07,504 - DEBUG - vmin 1.5915767684475103e-06 vmax 0.007265277536024621
# 2026-06-12 10:17:07,504 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-12 10:17:07,505 - DEBUG - vmin 1.5915767684475103e-06 vmax 0.007265277536024621
# 2026-06-12 10:17:07,505 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-12 10:17:07,506 - DEBUG - vmin 1.5915767684475103e-06 vmax 0.007265277536024621
# 2026-06-12 10:17:07,507 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-12 10:17:07,507 - DEBUG - vmin 1.5915767684475103e-06 vmax 0.007265277536024621
# 2026-06-12 10:17:07,508 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-12 10:17:07,508 - DEBUG - vmin 1.5915767684475103e-06 vmax 0.007265277536024621
# 2026-06-12 10:17:07,509 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-12 10:17:07,511 - DEBUG - vmin 1.5915767684475103e-06 vmax 0.007265277536024621
# 2026-06-12 10:17:07,511 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-12 10:17:07,511 - DEBUG - vmin 1.5915767684475103e-06 vmax 0.007265277536024621
# 2026-06-12 10:17:07,512 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-12 10:17:07,512 - DEBUG - vmin 1.5915767684475103e-06 vmax 0.007265277536024621
# 2026-06-12 10:17:07,512 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-12 10:17:07,588 - DEBUG - vmin 1.5915767684475103e-06 vmax 0.007265277536024621
# 2026-06-12 10:17:07,588 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-12 10:17:07,589 - DEBUG - vmin 1.5915767684475103e-06 vmax 0.007265277536024621
# 2026-06-12 10:17:07,589 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-12 10:17:07,589 - DEBUG - vmin 1.5915767684475103e-06 vmax 0.007265277536024621
# 2026-06-12 10:17:07,590 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-12 10:17:07,602 - DEBUG - vmin 1.5915767684475103e-06 vmax 0.007265277536024621
# 2026-06-12 10:17:07,603 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-12 10:17:07,603 - DEBUG - vmin 1.5915767684475103e-06 vmax 0.007265277536024621
# 2026-06-12 10:17:07,603 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-12 10:17:07,604 - DEBUG - vmin 1.5915767684475103e-06 vmax 0.007265277536024621
# 2026-06-12 10:17:07,604 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-12 10:17:07,606 - DEBUG - vmin 1.5915767684475103e-06 vmax 0.007265277536024621
# 2026-06-12 10:17:07,607 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-12 10:17:07,607 - DEBUG - vmin 1.5915767684475103e-06 vmax 0.007265277536024621
# 2026-06-12 10:17:07,607 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-12 10:17:07,608 - DEBUG - vmin 1.5915767684475103e-06 vmax 0.007265277536024621
# 2026-06-12 10:17:07,608 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])

# %% [markdown]
# ### time to next event

# %%
t_prime_vec = np.linspace(0, 100, 300) + history_dict['t']

second_gamma = unreg_gamma(-THETA_0['omega'], THETA_0['c'] / THETA_0['tau'])

def log_rhs(t_prime: float, t: float, target_polygon: Polygon, H: History, params: EtasParams, resolution: int = 50):
    """
    Computes the log-space right-hand side for numerical stability.
    """
    t_h = H['t']
    
    # Linear background term
    term1 = -polygon_area(target_polygon) * params['mu'] * (t_prime - t)
    
    # Non-linear triggering term
    gamma_diff = (
        unreg_gamma(-params['omega'], (params['c'] + t_prime - t_h) / params['tau']) - 
        unreg_gamma(-params['omega'], (params['c'] + t - t_h) / params['tau'])
    )
    
    const_multiplier = np.exp(params['c'] / params['tau']) / (params['tau']**(-params['omega']))
    term2 = A_h(target_polygon, H, params, resolution) * const_multiplier * gamma_diff
    
    return term1 + term2

all_P_vecs = []
for cell in ordered_cells:
    rhs_vec = np.exp(log_rhs(t_prime_vec, history_dict['t'], cell, history_dict, THETA_0, A_H_RESOLUTION))
    all_P_vecs.append(rhs_vec)

# %%
f, ax = plt.subplots()
ax.plot(t_prime_vec, 1 - all_P_vecs[250])
ax.set_xlabel("Time since history event")
ax.set_ylabel("Probability")
ax.set_title("Probability of an event in the next t' days")
plt.show()

# %%
# pdf
pdf = np.diff(1 - all_P_vecs[250]) / np.diff(t_prime_vec)

f, ax = plt.subplots()
ax.plot(t_prime_vec[:-1], pdf)
ax.set_xlabel("Time since history event")
ax.set_ylabel("PDF")
ax.set_title("PDF of time to next event")
plt.show()

# %%
t_prime_vec = np.linspace(0, 100, 300) + history_dict['t']

second_gamma = unreg_gamma(-THETA_0['omega'], THETA_0['c'] / THETA_0['tau'])


# Raw SHAPE_COORDS polygon is (lat, lon); swap to (lon, lat) for A_h / history_dict.
california_lonlat = transform(_swap_xy, polygon)

P_vec_california = np.exp(
    log_rhs(t_prime_vec, history_dict['t'], california_lonlat, history_dict, THETA_0, A_H_RESOLUTION)
)

# %%
f, ax = plt.subplots()
ax.plot(t_prime_vec, P_vec_california)
ax.set_xlabel("Time since history event")
ax.set_ylabel("Probability")
ax.set_title("Probability of an event in the next t' days")
plt.show()

# %% [markdown]
# ## Catalog continuation forecast
#
# Run classic ETAS catalog continuation (`simulate_catalog_continuation`) from forecast start time **T**, using only the single history event above as auxiliary catalog. Each recreation keeps the **first forecast event** after **T** (extending the forecast window if needed).

# %%
# --- forecast settings (edit these) ---
FORECAST_START = history_event_time  # time T: forecast window starts here
N_RECREATIONS = 300
N_FORECAST_EVENTS = 1  # keep the first event after T in each recreation
SEED_START = 0

# initial forecast window; extended automatically until N_FORECAST_EVENTS are found
INITIAL_FORECAST_DAYS = 30
MAX_FORECAST_DAYS = 3650
FORECAST_GROWTH_FACTOR = 2.0

# magnitude distribution (Gutenberg–Richter b=1 => beta = ln(10))
BETA_MAIN = np.log(10)
MC = THETA_0["m_c"]

from pathlib import Path
from typing import Optional

REPO_ROOT = Path.cwd().resolve()
if REPO_ROOT.name == "notebooks":
    REPO_ROOT = REPO_ROOT.parent
RECREATIONS_OUTPUT_DIR = REPO_ROOT / "outputs" / "single_point_history"

# --- persistence ---
# Load only when the canonical CSV for current settings exists (n, seed, resolution, …).
# Older files with different tags are ignored; set FORCE_RECREATE_RECREATIONS = True to always re-simulate.
FORCE_RECREATE_RECREATIONS = False
SAVE_RECREATIONS_OUTPUT = True

# Optional explicit paths (str or Path); None = use canonical name under RECREATIONS_OUTPUT_DIR
SAVED_FORECAST_RECREATIONS_PATH = None
SAVED_GRID_RECREATIONS_PATH = None


def forecast_recreations_path(n_recreations=None, seed_start=None) -> Path:
    n = N_RECREATIONS if n_recreations is None else int(n_recreations)
    seed = SEED_START if seed_start is None else int(seed_start)
    return RECREATIONS_OUTPUT_DIR / f"forecast_recreations_n{n}_seed{seed}.csv"


def grid_recreations_epsilon_path(n_recreations=None, resolution=None) -> Path:
    n = N_RECREATIONS if n_recreations is None else int(n_recreations)
    res = A_H_RESOLUTION if resolution is None else int(resolution)
    return RECREATIONS_OUTPUT_DIR / f"grid_recreations_epsilon_n{n}_res{res}.csv"


def _resolve_saved_csv(explicit_path, canonical_path: Path) -> Optional[Path]:
    """Load only when the file matches current settings (canonical name encodes parameters)."""
    if explicit_path is not None:
        path = Path(explicit_path)
        if not path.is_file():
            raise FileNotFoundError(f"Saved recreations not found: {path}")
        if path.resolve() != canonical_path.resolve():
            print(
                f"Explicit path {path.name} does not match current settings "
                f"({canonical_path.name}); re-simulating."
            )
            return None
        return path
    if canonical_path.is_file():
        return canonical_path
    return None


def _note_stale_saved_csvs(glob_pattern: str, canonical_path: Path) -> None:
    """Hint when older CSVs exist but none match the current parameter tag."""
    if not RECREATIONS_OUTPUT_DIR.is_dir():
        return
    stale = sorted(
        RECREATIONS_OUTPUT_DIR.glob(glob_pattern),
        key=lambda p: p.name,
    )
    stale = [p for p in stale if p.resolve() != canonical_path.resolve()]
    if stale:
        names = ", ".join(p.name for p in stale[:5])
        suffix = " ..." if len(stale) > 5 else ""
        print(
            f"Note: found {len(stale)} saved CSV(s) with other parameters "
            f"({names}{suffix}); need {canonical_path.name} for current settings."
        )


def load_recreations_epsilon_csv(path: Path) -> dict[float, pd.DataFrame]:
    df = pd.read_csv(path)
    if "epsilon" not in df.columns:
        raise ValueError(f"Missing epsilon column in {path}")
    out: dict[float, pd.DataFrame] = {}
    for eps, grp in df.groupby("epsilon"):
        out[float(eps)] = grp.drop(columns="epsilon").reset_index(drop=True)
    return out

# %%
# ETAS parameters in the log10 form expected by simulate_catalog_continuation
theta = {
    key: THETA_0[key]
    for key in [
        "log10_mu",
        "log10_k0",
        "a",
        "log10_c",
        "omega",
        "log10_tau",
        "log10_d",
        "gamma",
        "rho",
    ]
}


def _to_naive_utc(ts):
    t = pd.to_datetime(ts, utc=True)
    return t.tz_convert(None)


def simulate_single_event_recreations(
    auxiliary_catalog,
    *,
    auxiliary_start,
    forecast_start,
    polygon,
    theta,
    mc,
    beta_main,
    n_events,
    n_recreations,
    seed_start,
    initial_forecast_days=30,
    max_forecast_days=3650,
    growth_factor=2.0,
):
    """Call simulate_catalog_continuation; keep first n_events after forecast_start."""
    aux_start = _to_naive_utc(auxiliary_start)
    f_start = _to_naive_utc(forecast_start)

    aux = auxiliary_catalog.copy()
    aux["time"] = pd.to_datetime(aux["time"], utc=True).dt.tz_convert(None)

    records = []
    seeds = range(seed_start, seed_start + n_recreations)
    for i, seed in enumerate(
        tqdm(seeds, total=n_recreations, desc="Recreations", unit="run")
    ):
        np.random.seed(int(seed))

        forecast_days = float(initial_forecast_days)
        chosen = None
        while forecast_days <= float(max_forecast_days):
            sim_end = f_start + dt.timedelta(days=forecast_days)

            cont = simulation.simulate_catalog_continuation(
                auxiliary_catalog=aux,
                auxiliary_start=aux_start,
                auxiliary_end=f_start,
                polygon=polygon,
                simulation_end=sim_end,
                parameters=dict(theta),
                mc=float(mc),
                beta_main=beta_main,
                filter_polygon=False,
                magnitude_generator=mc_b_est.simulate_magnitudes,
            )

            cont = cont.copy()
            cont["time"] = pd.to_datetime(cont["time"], utc=True).dt.tz_convert(None)

            forecast_events = cont.loc[cont["time"] > f_start].sort_values("time")
            forecast_events = forecast_events.head(int(n_events))

            if len(forecast_events) >= int(n_events):
                chosen = forecast_events
                break

            forecast_days *= float(growth_factor)

        if chosen is None:
            raise RuntimeError(
                f"Recreation {i} (seed={seed}) did not reach {n_events} event(s) "
                f"within {max_forecast_days} forecast days."
            )

        chosen = chosen[["time", "latitude", "longitude", "magnitude"]].copy()
        chosen["recreation"] = i
        chosen["seed"] = int(seed)
        chosen["event_idx"] = np.arange(len(chosen), dtype=int)
        records.append(chosen)

    if not records:
        return pd.DataFrame(
            columns=[
                "time",
                "latitude",
                "longitude",
                "magnitude",
                "recreation",
                "seed",
                "event_idx",
            ]
        )
    return pd.concat(records, ignore_index=True)


auxiliary_catalog = pd.DataFrame(
    {
        "time": [_to_naive_utc(history_event_time)],
        "latitude": [history_event_y],
        "longitude": [history_event_x],
        "magnitude": [history_event_magnitude],
        "xi_plus_1": [1.0],
    }
)
auxiliary_start = auxiliary_catalog["time"].min()
forecast_start = _to_naive_utc(FORECAST_START)

_forecast_canonical = forecast_recreations_path()
_forecast_load_path = None if FORCE_RECREATE_RECREATIONS else _resolve_saved_csv(
    SAVED_FORECAST_RECREATIONS_PATH,
    _forecast_canonical,
)

_forecast_loaded = False

if not FORCE_RECREATE_RECREATIONS and _forecast_load_path is not None:
    _candidate = pd.read_csv(_forecast_load_path, parse_dates=["time"])
    n_rec_ok = _candidate["recreation"].nunique() == N_RECREATIONS
    n_evt_ok = (
        _candidate.groupby("recreation")["event_idx"].max().add(1) >= N_FORECAST_EVENTS
    ).all()
    if n_rec_ok and n_evt_ok:
        print(f"Loading forecast_recreations from {_forecast_load_path}")
        forecast_recreations = _candidate
        _forecast_loaded = True
    else:
        print(
            f"Saved forecast_recreations shape does not match "
            f"n={N_RECREATIONS}, events={N_FORECAST_EVENTS}; re-simulating."
        )

if not _forecast_loaded:
    if FORCE_RECREATE_RECREATIONS:
        print("FORCE_RECREATE_RECREATIONS=True: simulating classic ETAS recreations...")
    else:
        _note_stale_saved_csvs(
            "forecast_recreations_n*_seed*.csv",
            _forecast_canonical,
        )
        if _forecast_load_path is None:
            print(
                f"No saved forecast_recreations for current settings "
                f"({_forecast_canonical.name}); simulating..."
            )
    forecast_recreations = simulate_single_event_recreations(
        auxiliary_catalog,
        auxiliary_start=auxiliary_start,
        forecast_start=forecast_start,
        polygon=polygon,
        theta=theta,
        mc=MC,
        beta_main=BETA_MAIN,
        n_events=N_FORECAST_EVENTS,
        n_recreations=N_RECREATIONS,
        seed_start=SEED_START,
        initial_forecast_days=INITIAL_FORECAST_DAYS,
        max_forecast_days=MAX_FORECAST_DAYS,
        growth_factor=FORECAST_GROWTH_FACTOR,
    )

print(
    f"Forecast from T={forecast_start}: "
    f"{len(forecast_recreations)} event(s) "
    f"({forecast_recreations['recreation'].nunique()} recreations x {N_FORECAST_EVENTS})"
)

if SAVE_RECREATIONS_OUTPUT and not _forecast_loaded:
    RECREATIONS_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
    forecast_recreations.to_csv(_forecast_canonical, index=False)
    print(f"Saved forecast_recreations -> {_forecast_canonical}")

forecast_recreations
# Out:
# Note: found 1 saved CSV(s) with other parameters (forecast_recreations_n1000_seed0.csv); need forecast_recreations_n300_seed0.csv for current settings.
# No saved forecast_recreations for current settings (forecast_recreations_n300_seed0.csv); simulating...
# Recreations:   0%|          | 0/300 [00:00<?, ?run/s]
# 2026-06-12 14:08:24,137 - INFO -   number of background events needed: 47
# 2026-06-12 14:08:24,138 - INFO -   generating 96 to throw away those outside the polygon
# 2026-06-12 14:08:24,143 - DEBUG - number of induced events: 0
# 2026-06-12 14:08:24,145 - DEBUG - number of background events: 47
# 2026-06-12 14:08:24,146 - DEBUG - number of auxiliary events: 1
# 2026-06-12 14:08:24,146 - DEBUG - generation 0
# 2026-06-12 14:08:24,149 - DEBUG - number of events with aftershocks: 30
# 2026-06-12 14:08:24,157 - DEBUG - number of aftershocks: 37
# 2026-06-12 14:08:24,157 - DEBUG - their number of aftershocks should be:31
# 2026-06-12 14:08:24,159 - DEBUG - generation 1
# 2026-06-12 14:08:24,160 - DEBUG - number of events with aftershocks: 19
# 2026-06-12 14:08:24,168 - DEBUG - number of aftershocks: 19
# 2026-06-12 14:08:24,168 - DEBUG - their number of aftershocks should be:14
# 2026-06-12 14:08:24,169 - DEBUG - generation 2
# 2026-06-12 14:08:24,171 - DEBUG - number of events with aftershocks: 9
# 2026-06-12 14:08:24,178 - DEBUG - number of aftershocks: 9
# 2026-06-12 14:08:24,178 - DEBUG - their number of aftershocks should be:9
# 2026-06-12 14:08:24,179 - DEBUG - generation 3
# 2026-06-12 14:08:24,181 - DEBUG - number of events with aftershocks: 4
# 2026-06-12 14:08:24,188 - DEBUG - number of aftershocks: 7
# 2026-06-12 14:08:24,189 - DEBUG - their number of aftershocks should be:8
# 2026-06-12 14:08:24,190 - DEBUG - generation 4
# 2026-06-12 14:08:24,191 - DEBUG - number of events with aftershocks: 4
# 2026-06-12 14:08:24,198 - DEBUG - number of aftershocks: 5
# 2026-06-12 14:08:24,199 - DEBUG - their number of aftershocks should be:6
# 2026-06-12 14:08:24,200 - DEBUG - generation 5
# 2026-06-12 14:08:24,201 - DEBUG - number of events with aftershocks: 3
# 2026-06-12 14:08:24,209 - DEBUG - number of aftershocks: 4
# 2026-06-12 14:08:24,209 - DEBUG - their number of aftershocks should be:3
# 2026-06-12 14:08:24,210 - DEBUG - generation 6
# 2026-06-12 14:08:24,212 - DEBUG - number of events with aftershocks: 3
# 2026-06-12 14:08:24,219 - DEBUG - number of aftershocks: 2
# 2026-06-12 14:08:24,219 - DEBUG - their number of aftershocks should be:2
# 2026-06-12 14:08:24,220 - DEBUG - generation 7
# 2026-06-12 14:08:24,222 - DEBUG - number of events with aftershocks: 2
# 2026-06-12 14:08:24,229 - DEBUG - number of aftershocks: 1
# 2026-06-12 14:08:24,230 - DEBUG - their number of aftershocks should be:1
# 2026-06-12 14:08:24,230 - DEBUG - generation 8
# 2026-06-12 14:08:24,232 - DEBUG - number of events with aftershocks: 1
# 2026-06-12 14:08:24,239 - DEBUG - number of aftershocks: 1
# 2026-06-12 14:08:24,240 - DEBUG - their number of aftershocks should be:0
# 2026-06-12 14:08:24,240 - DEBUG - generation 9
# 2026-06-12 14:08:24,242 - DEBUG - number of events with aftershocks: 0
# 2026-06-12 14:08:24,246 - INFO -   number of background events needed: 44
# 2026-06-12 14:08:24,246 - INFO -   generating 90 to throw away those outside the polygon
# 2026-06-12 14:08:24,251 - DEBUG - number of induced events: 0
# 2026-06-12 14:08:24,253 - DEBUG - number of background events: 44
# 2026-06-12 14:08:24,253 - DEBUG - number of auxiliary events: 1
# 2026-06-12 14:08:24,253 - DEBUG - generation 0
# 2026-06-12 14:08:24,255 - DEBUG - number of events with aftershocks: 32
# 2026-06-12 14:08:24,262 - DEBUG - number of aftershocks: 37
# 2026-06-12 14:08:24,263 - DEBUG - their number of aftershocks should be:32
# 2026-06-12 14:08:24,264 - DEBUG - generation 1
# 2026-06-12 14:08:24,266 - DEBUG - number of events with aftershocks: 20
# 2026-06-12 14:08:24,273 - DEBUG - number of aftershocks: 16
# 2026-06-12 14:08:24,273 - DEBUG - their number of aftershocks should be:15
# 2026-06-12 14:08:24,274 - DEBUG - generation 2
# 2026-06-12 14:08:24,276 - DEBUG - number of events with aftershocks: 13
# 2026-06-12 14:08:24,283 - DEBUG - number of aftershocks: 8
# 2026-06-12 14:08:24,283 - DEBUG - their number of aftershocks should be:7
# 2026-06-12 14:08:24,284 - DEBUG - generation 3
# 2026-06-12 14:08:24,286 - DEBUG - number of events with aftershocks: 4
# 2026-06-12 14:08:24,293 - DEBUG - number of aftershocks: 6
# 2026-06-12 14:08:24,293 - DEBUG - their number of aftershocks should be:6
# 2026-06-12 14:08:24,294 - DEBUG - generation 4
# 2026-06-12 14:08:24,296 - DEBUG - number of events with aftershocks: 4
# 2026-06-12 14:08:24,303 - DEBUG - number of aftershocks: 4
# 2026-06-12 14:08:24,303 - DEBUG - their number of aftershocks should be:4
# 2026-06-12 14:08:24,304 - DEBUG - generation 5
# 2026-06-12 14:08:24,306 - DEBUG - number of events with aftershocks: 3
# 2026-06-12 14:08:24,313 - DEBUG - number of aftershocks: 3
# 2026-06-12 14:08:24,313 - DEBUG - their number of aftershocks should be:2
# 2026-06-12 14:08:24,314 - DEBUG - generation 6
# 2026-06-12 14:08:24,316 - DEBUG - number of events with aftershocks: 1
# 2026-06-12 14:08:24,323 - DEBUG - number of aftershocks: 0
# 2026-06-12 14:08:24,323 - DEBUG - their number of aftershocks should be:0
# 2026-06-12 14:08:24,324 - DEBUG - generation 7
# 2026-06-12 14:08:24,326 - DEBUG - number of events with aftershocks: 0
# 2026-06-12 14:08:24,329 - INFO -   number of background events needed: 44
# 2026-06-12 14:08:24,330 - INFO -   generating 90 to throw away those outside the polygon
# 2026-06-12 14:08:24,334 - DEBUG - number of induced events: 0
# 2026-06-12 14:08:24,336 - DEBUG - number of background events: 44
# 2026-06-12 14:08:24,337 - DEBUG - number of auxiliary events: 1
# 2026-06-12 14:08:24,337 - DEBUG - generation 0
# 2026-06-12 14:08:24,338 - DEBUG - number of events with aftershocks: 22
# 2026-06-12 14:08:24,346 - DEBUG - number of aftershocks: 31
# 2026-06-12 14:08:24,346 - DEBUG - their number of aftershocks should be:32
# 2026-06-12 14:08:24,347 - DEBUG - generation 1
# 2026-06-12 14:08:24,349 - DEBUG - number of events with aftershocks: 18
# 2026-06-12 14:08:24,356 - DEBUG - number of aftershocks: 18
# 2026-06-12 14:08:24,356 - DEBUG - their number of aftershocks should be:15
# 2026-06-12 14:08:24,357 - DEBUG - generation 2
# 2026-06-12 14:08:24,359 - DEBUG - number of events with aftershocks: 12
# 2026-06-12 14:08:24,366 - DEBUG - number of aftershocks: 9
# 2026-06-12 14:08:24,367 - DEBUG - their number of aftershocks should be:8
# 2026-06-12 14:08:24,367 - DEBUG - generation 3
# 2026-06-12 14:08:24,369 - DEBUG - number of events with aftershocks: 5
# 2026-06-12 14:08:24,376 - DEBUG - number of aftershocks: 5
# 2026-06-12 14:08:24,376 - DEBUG - their number of aftershocks should be:6
# 2026-06-12 14:08:24,377 - DEBUG - generation 4
# 2026-06-12 14:08:24,379 - DEBUG - number of events with aftershocks: 3
# 2026-06-12 14:08:24,386 - DEBUG - number of aftershocks: 1
# 2026-06-12 14:08:24,386 - DEBUG - their number of aftershocks should be:2
# 2026-06-12 14:08:24,387 - DEBUG - generation 5
# 2026-06-12 14:08:24,389 - DEBUG - number of events with aftershocks: 1
# 2026-06-12 14:08:24,396 - DEBUG - number of aftershocks: 1
# 2026-06-12 14:08:24,396 - DEBUG - their number of aftershocks should be:0
# 2026-06-12 14:08:24,397 - DEBUG - generation 6
# 2026-06-12 14:08:24,399 - DEBUG - number of events with aftershocks: 0
# 2026-06-12 14:08:24,403 - INFO -   number of background events needed: 47
# 2026-06-12 14:08:24,403 - INFO -   generating 96 to throw away those outside the polygon
# 2026-06-12 14:08:24,407 - DEBUG - number of induced events: 0
# 2026-06-12 14:08:24,409 - DEBUG - number of background events: 47
# 2026-06-12 14:08:24,410 - DEBUG - number of auxiliary events: 1
# 2026-06-12 14:08:24,410 - DEBUG - generation 0
# 2026-06-12 14:08:24,411 - DEBUG - number of events with aftershocks: 27
# 2026-06-12 14:08:24,419 - DEBUG - number of aftershocks: 30
# 2026-06-12 14:08:24,419 - DEBUG - their number of aftershocks should be:32
# 2026-06-12 14:08:24,420 - DEBUG - generation 1
# 2026-06-12 14:08:24,422 - DEBUG - number of events with aftershocks: 21
# 2026-06-12 14:08:24,429 - DEBUG - number of aftershocks: 21
# 2026-06-12 14:08:24,430 - DEBUG - their number of aftershocks should be:14
# 2026-06-12 14:08:24,431 - DEBUG - generation 2
# 2026-06-12 14:08:24,432 - DEBUG - number of events with aftershocks: 10
# 2026-06-12 14:08:24,440 - DEBUG - number of aftershocks: 8
# 2026-06-12 14:08:24,440 - DEBUG - their number of aftershocks should be:13
# 2026-06-12 14:08:24,441 - DEBUG - generation 3
# 2026-06-12 14:08:24,442 - DEBUG - number of events with aftershocks: 7
# 2026-06-12 14:08:24,450 - DEBUG - number of aftershocks: 4
# 2026-06-12 14:08:24,450 - DEBUG - their number of aftershocks should be:4
# 2026-06-12 14:08:24,451 - DEBUG - generation 4
# 2026-06-12 14:08:24,453 - DEBUG - number of events with aftershocks: 2
# 2026-06-12 14:08:24,460 - DEBUG - number of aftershocks: 0
# 2026-06-12 14:08:24,460 - DEBUG - their number of aftershocks should be:0
# 2026-06-12 14:08:24,461 - DEBUG - generation 5
# 2026-06-12 14:08:24,463 - DEBUG - number of events with aftershocks: 0
# 2026-06-12 14:08:24,466 - INFO -   number of background events needed: 50
# 2026-06-12 14:08:24,466 - INFO -   generating 102 to throw away those outside the polygon
# 2026-06-12 14:08:24,470 - DEBUG - number of induced events: 0
# 2026-06-12 14:08:24,473 - DEBUG - number of background events: 50
# 2026-06-12 14:08:24,473 - DEBUG - number of auxiliary events: 1
# 2026-06-12 14:08:24,473 - DEBUG - generation 0
# 2026-06-12 14:08:24,474 - DEBUG - number of events with aftershocks: 32
# 2026-06-12 14:08:24,482 - DEBUG - number of aftershocks: 34
# 2026-06-12 14:08:24,482 - DEBUG - their number of aftershocks should be:26
# 2026-06-12 14:08:24,484 - DEBUG - generation 1
# 2026-06-12 14:08:24,485 - DEBUG - number of events with aftershocks: 16
# 2026-06-12 14:08:24,493 - DEBUG - number of aftershocks: 14
# 2026-06-12 14:08:24,493 - DEBUG - their number of aftershocks should be:15
# 2026-06-12 14:08:24,494 - DEBUG - generation 2
# 2026-06-12 14:08:24,495 - DEBUG - number of events with aftershocks: 9
# 2026-06-12 14:08:24,503 - DEBUG - number of aftershocks: 9
# 2026-06-12 14:08:24,503 - DEBUG - their number of aftershocks should be:9
# 2026-06-12 14:08:24,504 - DEBUG - generation 3
# 2026-06-12 14:08:24,506 - DEBUG - number of events with aftershocks: 6
# 2026-06-12 14:08:24,513 - DEBUG - number of aftershocks: 5
# 2026-06-12 14:08:24,513 - DEBUG - their number of aftershocks should be:4
# 2026-06-12 14:08:24,514 - DEBUG - generation 4
# 2026-06-12 14:08:24,516 - DEBUG - number of events with aftershocks: 3
# 2026-06-12 14:08:24,523 - DEBUG - number of aftershocks: 2
# 2026-06-12 14:08:24,523 - DEBUG - their number of aftershocks should be:3
# 2026-06-12 14:08:24,524 - DEBUG - generation 5
# 2026-06-12 14:08:24,525 - DEBUG - number of events with aftershocks: 2
# 2026-06-12 14:08:24,532 - DEBUG - number of aftershocks: 3
# 2026-06-12 14:08:24,533 - DEBUG - their number of aftershocks should be:2
# 2026-06-12 14:08:24,533 - DEBUG - generation 6
# 2026-06-12 14:08:24,535 - DEBUG - number of events with aftershocks: 2
# 2026-06-12 14:08:24,542 - DEBUG - number of aftershocks: 2
# 2026-06-12 14:08:24,542 - DEBUG - their number of aftershocks should be:3
# 2026-06-12 14:08:24,543 - DEBUG - generation 7
# 2026-06-12 14:08:24,545 - DEBUG - number of events with aftershocks: 2
# 2026-06-12 14:08:24,552 - DEBUG - number of aftershocks: 0
# 2026-06-12 14:08:24,552 - DEBUG - their number of aftershocks should be:0
# 2026-06-12 14:08:24,553 - DEBUG - generation 8
# 2026-06-12 14:08:24,555 - DEBUG - number of events with aftershocks: 0
# 2026-06-12 14:08:24,559 - INFO -   number of background events needed: 40
# 2026-06-12 14:08:24,559 - INFO -   generating 81 to throw away those outside the polygon
# 2026-06-12 14:08:24,563 - DEBUG - number of induced events: 0
# 2026-06-12 14:08:24,565 - DEBUG - number of background events: 40
# 2026-06-12 14:08:24,566 - DEBUG - number of auxiliary events: 1
# 2026-06-12 14:08:24,566 - DEBUG - generation 0
# 2026-06-12 14:08:24,567 - DEBUG - number of events with aftershocks: 18
# 2026-06-12 14:08:24,575 - DEBUG - number of aftershocks: 25
# 2026-06-12 14:08:24,575 - DEBUG - their number of aftershocks should be:15
# 2026-06-12 14:08:24,576 - DEBUG - generation 1
# 2026-06-12 14:08:24,578 - DEBUG - number of events with aftershocks: 11
# 2026-06-12 14:08:24,585 - DEBUG - number of aftershocks: 7
# 2026-06-12 14:08:24,586 - DEBUG - their number of aftershocks should be:5
# 2026-06-12 14:08:24,586 - DEBUG - generation 2
# 2026-06-12 14:08:24,588 - DEBUG - number of events with aftershocks: 4
# 2026-06-12 14:08:24,595 - DEBUG - number of aftershocks: 5
# 2026-06-12 14:08:24,595 - DEBUG - their number of aftershocks should be:1
# 2026-06-12 14:08:24,596 - DEBUG - generation 3
# 2026-06-12 14:08:24,598 - DEBUG - number of events with aftershocks: 1
# 2026-06-12 14:08:24,605 - DEBUG - number of aftershocks: 0
# 2026-06-12 14:08:24,605 - DEBUG - their number of aftershocks should be:0
# 2026-06-12 14:08:24,606 - DEBUG - generation 4
# 2026-06-12 14:08:24,608 - DEBUG - number of events with aftershocks: 0
# 2026-06-12 14:08:24,611 - INFO -   number of background events needed: 55
# 2026-06-12 14:08:24,611 - INFO -   generating 112 to throw away those outside the polygon
# 2026-06-12 14:08:24,616 - DEBUG - number of induced events: 0
# 2026-06-12 14:08:24,618 - DEBUG - number of background events: 55
# 2026-06-12 14:08:24,618 - DEBUG - number of auxiliary events: 1
# 2026-06-12 14:08:24,618 - DEBUG - generation 0
# 2026-06-12 14:08:24,620 - DEBUG - number of events with aftershocks: 34
# 2026-06-12 14:08:24,628 - DEBUG - number of aftershocks: 51
# 2026-06-12 14:08:24,628 - DEBUG - their number of aftershocks should be:60
# 2026-06-12 14:08:24,629 - DEBUG - generation 1
# 2026-06-12 14:08:24,631 - DEBUG - number of events with aftershocks: 35
# 2026-06-12 14:08:24,639 - DEBUG - number of aftershocks: 37
# 2026-06-12 14:08:24,639 - DEBUG - their number of aftershocks should be:36
# 2026-06-12 14:08:24,640 - DEBUG - generation 2
# 2026-06-12 14:08:24,641 - DEBUG - number of events with aftershocks: 22
# 2026-06-12 14:08:24,649 - DEBUG - number of aftershocks: 20
# 2026-06-12 14:08:24,649 - DEBUG - their number of aftershocks should be:14
# 2026-06-12 14:08:24,650 - DEBUG - generation 3
# 2026-06-12 14:08:24,652 - DEBUG - number of events with aftershocks: 12
# 2026-06-12 14:08:24,659 - DEBUG - number of aftershocks: 8
# 2026-06-12 14:08:24,659 - DEBUG - their number of aftershocks should be:6
# 2026-06-12 14:08:24,660 - DEBUG - generation 4
# 2026-06-12 14:08:24,662 - DEBUG - number of events with aftershocks: 4
# 2026-06-12 14:08:24,669 - DEBUG - number of aftershocks: 0
# 2026-06-12 14:08:24,669 - DEBUG - their number of aftershocks should be:0
# 2026-06-12 14:08:24,670 - DEBUG - generation 5
# 2026-06-12 14:08:24,672 - DEBUG - number of events with aftershocks: 0
# 2026-06-12 14:08:24,676 - INFO -   number of background events needed: 34
# 2026-06-12 14:08:24,676 - INFO -   generating 69 to throw away those outside the polygon
# 2026-06-12 14:08:24,680 - DEBUG - number of induced events: 0
# 2026-06-12 14:08:24,682 - DEBUG - number of background events: 34
# 2026-06-12 14:08:24,683 - DEBUG - number of auxiliary events: 1
# 2026-06-12 14:08:24,683 - DEBUG - generation 0
# 2026-06-12 14:08:24,684 - DEBUG - number of events with aftershocks: 24
# 2026-06-12 14:08:24,692 - DEBUG - number of aftershocks: 30
# 2026-06-12 14:08:24,692 - DEBUG - their number of aftershocks should be:35
# 2026-06-12 14:08:24,693 - DEBUG - generation 1
# 2026-06-12 14:08:24,695 - DEBUG - number of events with aftershocks: 21
# 2026-06-12 14:08:24,702 - DEBUG - number of aftershocks: 24
# 2026-06-12 14:08:24,702 - DEBUG - their number of aftershocks should be:21
# 2026-06-12 14:08:24,703 - DEBUG - generation 2
# 2026-06-12 14:08:24,705 - DEBUG - number of events with aftershocks: 15
# 2026-06-12 14:08:24,712 - DEBUG - number of aftershocks: 14
# 2026-06-12 14:08:24,713 - DEBUG - their number of aftershocks should be:10
# 2026-06-12 14:08:24,713 - DEBUG - generation 3
# 2026-06-12 14:08:24,715 - DEBUG - number of events with aftershocks: 8
# 2026-06-12 14:08:24,722 - DEBUG - number of aftershocks: 7
# 2026-06-12 14:08:24,723 - DEBUG - their number of aftershocks should be:5
# 2026-06-12 14:08:24,723 - DEBUG - generation 4
# 2026-06-12 14:08:24,725 - DEBUG - number of events with aftershocks: 4
# 2026-06-12 14:08:24,732 - DEBUG - number of aftershocks: 2
# 2026-06-12 14:08:24,733 - DEBUG - their number of aftershocks should be:5
# 2026-06-12 14:08:24,733 - DEBUG - generation 5
# 2026-06-12 14:08:24,735 - DEBUG - number of events with aftershocks: 2
# 2026-06-12 14:08:24,742 - DEBUG - number of aftershocks: 3
# 2026-06-12 14:08:24,742 - DEBUG - their number of aftershocks should be:4
# 2026-06-12 14:08:24,743 - DEBUG - generation 6
# 2026-06-12 14:08:24,745 - DEBUG - number of events with aftershocks: 2
# 2026-06-12 14:08:24,752 - DEBUG - number of aftershocks: 3
# 2026-06-12 14:08:24,752 - DEBUG - their number of aftershocks should be:3
# 2026-06-12 14:08:24,753 - DEBUG - generation 7
# 2026-06-12 14:08:24,755 - DEBUG - number of events with aftershocks: 2
# 2026-06-12 14:08:24,762 - DEBUG - number of aftershocks: 1
# 2026-06-12 14:08:24,762 - DEBUG - their number of aftershocks should be:1
# 2026-06-12 14:08:24,763 - DEBUG - generation 8
# 2026-06-12 14:08:24,765 - DEBUG - number of events with aftershocks: 1
# 2026-06-12 14:08:24,772 - DEBUG - number of aftershocks: 1
# 2026-06-12 14:08:24,772 - DEBUG - their number of aftershocks should be:3
# 2026-06-12 14:08:24,773 - DEBUG - generation 9
# 2026-06-12 14:08:24,775 - DEBUG - number of events with aftershocks: 1
# 2026-06-12 14:08:24,782 - DEBUG - number of aftershocks: 1
# 2026-06-12 14:08:24,782 - DEBUG - their number of aftershocks should be:0
# 2026-06-12 14:08:24,783 - DEBUG - generation 10
# 2026-06-12 14:08:24,785 - DEBUG - number of events with aftershocks: 0
# 2026-06-12 14:08:24,788 - INFO -   number of background events needed: 54
# 2026-06-12 14:08:24,788 - INFO -   generating 110 to throw away those outside the polygon
# 2026-06-12 14:08:24,793 - DEBUG - number of induced events: 0
# 2026-06-12 14:08:24,795 - DEBUG - number of background events: 54
# 2026-06-12 14:08:24,795 - DEBUG - number of auxiliary events: 1
# 2026-06-12 14:08:24,795 - DEBUG - generation 0
# 2026-06-12 14:08:24,797 - DEBUG - number of events with aftershocks: 28
# 2026-06-12 14:08:24,805 - DEBUG - number of aftershocks: 31
# 2026-06-12 14:08:24,805 - DEBUG - their number of aftershocks should be:30
# 2026-06-12 14:08:24,806 - DEBUG - generation 1
# 2026-06-12 14:08:24,808 - DEBUG - number of events with aftershocks: 15
# 2026-06-12 14:08:24,815 - DEBUG - number of aftershocks: 16
# 2026-06-12 14:08:24,815 - DEBUG - their number of aftershocks should be:13
# 2026-06-12 14:08:24,816 - DEBUG - generation 2
# 2026-06-12 14:08:24,818 - DEBUG - number of events with aftershocks: 8
# 2026-06-12 14:08:24,825 - DEBUG - number of aftershocks: 11
# 2026-06-12 14:08:24,825 - DEBUG - their number of aftershocks should be:10
# 2026-06-12 14:08:24,826 - DEBUG - generation 3
# 2026-06-12 14:08:24,828 - DEBUG - number of events with aftershocks: 8
# 2026-06-12 14:08:24,835 - DEBUG - number of aftershocks: 5
# 2026-06-12 14:08:24,836 - DEBUG - their number of aftershocks should be:8
# 2026-06-12 14:08:24,837 - DEBUG - generation 4
# 2026-06-12 14:08:24,838 - DEBUG - number of events with aftershocks: 5
# 2026-06-12 14:08:24,845 - DEBUG - number of aftershocks: 4
# 2026-06-12 14:08:24,846 - DEBUG - their number of aftershocks should be:6
# 2026-06-12 14:08:24,847 - DEBUG - generation 5
# 2026-06-12 14:08:24,848 - DEBUG - number of events with aftershocks: 3
# 2026-06-12 14:08:24,855 - DEBUG - number of aftershocks: 3
# 2026-06-12 14:08:24,856 - DEBUG - their number of aftershocks should be:3
# 2026-06-12 14:08:24,856 - DEBUG - generation 6
# 2026-06-12 14:08:24,858 - DEBUG - number of events with aftershocks: 2
# 2026-06-12 14:08:24,865 - DEBUG - number of aftershocks: 1
# 2026-06-12 14:08:24,866 - DEBUG - their number of aftershocks should be:1
# 2026-06-12 14:08:24,866 - DEBUG - generation 7
# 2026-06-12 14:08:24,868 - DEBUG - number of events with aftershocks: 1
# 2026-06-12 14:08:24,875 - DEBUG - number of aftershocks: 1
# 2026-06-12 14:08:24,875 - DEBUG - their number of aftershocks should be:0
# 2026-06-12 14:08:24,876 - DEBUG - generation 8
# 2026-06-12 14:08:24,878 - DEBUG - number of events with aftershocks: 0
# 2026-06-12 14:08:24,882 - INFO -   number of background events needed: 45
# 2026-06-12 14:08:24,882 - INFO -   generating 92 to throw away those outside the polygon
# 2026-06-12 14:08:24,886 - DEBUG - number of induced events: 0
# 2026-06-12 14:08:24,888 - DEBUG - number of background events: 45
# 2026-06-12 14:08:24,889 - DEBUG - number of auxiliary events: 1
# 2026-06-12 14:08:24,889 - DEBUG - generation 0
# 2026-06-12 14:08:24,890 - DEBUG - number of events with aftershocks: 33
# 2026-06-12 14:08:24,898 - DEBUG - number of aftershocks: 35
# 2026-06-12 14:08:24,898 - DEBUG - their number of aftershocks should be:27
# 2026-06-12 14:08:24,899 - DEBUG - generation 1
# 2026-06-12 14:08:24,901 - DEBUG - number of events with aftershocks: 19
# 2026-06-12 14:08:24,909 - DEBUG - number of aftershocks: 17
# 2026-06-12 14:08:24,909 - DEBUG - their number of aftershocks should be:16
# 2026-06-12 14:08:24,910 - DEBUG - generation 2
# 2026-06-12 14:08:24,911 - DEBUG - number of events with aftershocks: 8
# 2026-06-12 14:08:24,919 - DEBUG - number of aftershocks: 8
# 2026-06-12 14:08:24,919 - DEBUG - their number of aftershocks should be:14
# 2026-06-12 14:08:24,920 - DEBUG - generation 3
# 2026-06-12 14:08:24,922 - DEBUG - number of events with aftershocks: 7
# 2026-06-12 14:08:24,929 - DEBUG - number of aftershocks: 12
# 2026-06-12 14:08:24,929 - DEBUG - their number of aftershocks should be:11
# 2026-06-12 14:08:24,930 - DEBUG - generation 4
# 2026-06-12 14:08:24,932 - DEBUG - number of events with aftershocks: 8
# 2026-06-12 14:08:24,939 - DEBUG - number of aftershocks: 6
# 2026-06-12 14:08:24,939 - DEBUG - their number of aftershocks should be:11
# 2026-06-12 14:08:24,940 - DEBUG - generation 5
# 2026-06-12 14:08:24,942 - DEBUG - number of events with aftershocks: 5
# 2026-06-12 14:08:24,949 - DEBUG - number of aftershocks: 6
# 2026-06-12 14:08:24,950 - DEBUG - their number of aftershocks should be:7
# 2026-06-12 14:08:24,950 - DEBUG - generation 6
# 2026-06-12 14:08:24,952 - DEBUG - number of events with aftershocks: 5
# 2026-06-12 14:08:24,959 - DEBUG - number of aftershocks: 4
# 2026-06-12 14:08:24,960 - DEBUG - their number of aftershocks should be:1
# 2026-06-12 14:08:24,960 - DEBUG - generation 7
# 2026-06-12 14:08:24,962 - DEBUG - number of events with aftershocks: 1
# 2026-06-12 14:08:24,969 - DEBUG - number of aftershocks: 0
# 2026-06-12 14:08:24,969 - DEBUG - their number of aftershocks should be:0
# 2026-06-12 14:08:24,970 - DEBUG - generation 8
# 2026-06-12 14:08:24,972 - DEBUG - number of events with aftershocks: 0
# 2026-06-12 14:08:24,975 - INFO -   number of background events needed: 51
# 2026-06-12 14:08:24,976 - INFO -   generating 104 to throw away those outside the polygon
# 2026-06-12 14:08:24,980 - DEBUG - number of induced events: 0
# 2026-06-12 14:08:24,982 - DEBUG - number of background events: 51
# 2026-06-12 14:08:24,983 - DEBUG - number of auxiliary events: 1
# 2026-06-12 14:08:24,983 - DEBUG - generation 0
# 2026-06-12 14:08:24,984 - DEBUG - number of events with aftershocks: 35
# 2026-06-12 14:08:24,992 - DEBUG - number of aftershocks: 30
# 2026-06-12 14:08:24,992 - DEBUG - their number of aftershocks should be:27
# 2026-06-12 14:08:24,993 - DEBUG - generation 1
# 2026-06-12 14:08:24,995 - DEBUG - number of events with aftershocks: 18
# 2026-06-12 14:08:25,002 - DEBUG - number of aftershocks: 15
# 2026-06-12 14:08:25,002 - DEBUG - their number of aftershocks should be:28
# 2026-06-12 14:08:25,003 - DEBUG - generation 2
# 2026-06-12 14:08:25,005 - DEBUG - number of events with aftershocks: 12
# 2026-06-12 14:08:25,012 - DEBUG - number of aftershocks: 13
# 2026-06-12 14:08:25,013 - DEBUG - their number of aftershocks should be:20
# 2026-06-12 14:08:25,014 - DEBUG - generation 3
# 2026-06-12 14:08:25,015 - DEBUG - number of events with aftershocks: 7
# 2026-06-12 14:08:25,023 - DEBUG - number of aftershocks: 10
# 2026-06-12 14:08:25,023 - DEBUG - their number of aftershocks should be:11
# 2026-06-12 14:08:25,024 - DEBUG - generation 4
# 2026-06-12 14:08:25,026 - DEBUG - number of events with aftershocks: 6
# 2026-06-12 14:08:25,033 - DEBUG - number of aftershocks: 5
# 2026-06-12 14:08:25,033 - DEBUG - their number of aftershocks should be:5
# 2026-06-12 14:08:25,034 - DEBUG - generation 5
# 2026-06-12 14:08:25,036 - DEBUG - number of events with aftershocks: 3
# 2026-06-12 14:08:25,043 - DEBUG - number of aftershocks: 3
# 2026-06-12 14:08:25,043 - DEBUG - their number of aftershocks should be:1
# 2026-06-12 14:08:25,044 - DEBUG - generation 6
# 2026-06-12 14:08:25,046 - DEBUG - number of events with aftershocks: 1
# 2026-06-12 14:08:25,052 - DEBUG - number of aftershocks: 1
# 2026-06-12 14:08:25,053 - DEBUG - their number of aftershocks should be:2
# 2026-06-12 14:08:25,054 - DEBUG - generation 7
# 2026-06-12 14:08:25,055 - DEBUG - number of events with aftershocks: 1
# 2026-06-12 14:08:25,062 - DEBUG - number of aftershocks: 2
# 2026-06-12 14:08:25,062 - DEBUG - their number of aftershocks should be:0
# 2026-06-12 14:08:25,063 - DEBUG - generation 8
# 2026-06-12 14:08:25,065 - DEBUG - number of events with aftershocks: 0
# 2026-06-12 14:08:25,069 - INFO -   number of background events needed: 38
# 2026-06-12 14:08:25,069 - INFO -   generating 77 to throw away those outside the polygon
# 2026-06-12 14:08:25,073 - DEBUG - number of induced events: 0
# 2026-06-12 14:08:25,076 - DEBUG - number of background events: 38
# 2026-06-12 14:08:25,076 - DEBUG - number of auxiliary events: 1
# 2026-06-12 14:08:25,076 - DEBUG - generation 0
# 2026-06-12 14:08:25,077 - DEBUG - number of events with aftershocks: 21
# 2026-06-12 14:08:25,085 - DEBUG - number of aftershocks: 20
# 2026-06-12 14:08:25,085 - DEBUG - their number of aftershocks should be:23
# 2026-06-12 14:08:25,086 - DEBUG - generation 1
# 2026-06-12 14:08:25,088 - DEBUG - number of events with aftershocks: 12
# 2026-06-12 14:08:25,095 - DEBUG - number of aftershocks: 13
# 2026-06-12 14:08:25,096 - DEBUG - their number of aftershocks should be:11
# 2026-06-12 14:08:25,097 - DEBUG - generation 2
# 2026-06-12 14:08:25,098 - DEBUG - number of events with aftershocks: 8
# 2026-06-12 14:08:25,105 - DEBUG - number of aftershocks: 8
# 2026-06-12 14:08:25,106 - DEBUG - their number of aftershocks should be:16
# 2026-06-12 14:08:25,107 - DEBUG - generation 3
# 2026-06-12 14:08:25,108 - DEBUG - number of events with aftershocks: 5
# 2026-06-12 14:08:25,116 - DEBUG - number of aftershocks: 9
# 2026-06-12 14:08:25,116 - DEBUG - their number of aftershocks should be:7
# 2026-06-12 14:08:25,117 - DEBUG - generation 4
# 2026-06-12 14:08:25,118 - DEBUG - number of events with aftershocks: 5
# 2026-06-12 14:08:25,126 - DEBUG - number of aftershocks: 3
# 2026-06-12 14:08:25,126 - DEBUG - their number of aftershocks should be:2
# 2026-06-12 14:08:25,127 - DEBUG - generation 5
# 2026-06-12 14:08:25,128 - DEBUG - number of events with aftershocks: 2
# 2026-06-12 14:08:25,135 - DEBUG - number of aftershocks: 2
# 2026-06-12 14:08:25,136 - DEBUG - their number of aftershocks should be:1
# 2026-06-12 14:08:25,137 - DEBUG - generation 6
# 2026-06-12 14:08:25,138 - DEBUG - number of events with aftershocks: 1
# 2026-06-12 14:08:25,145 - DEBUG - number of aftershocks: 0
# 2026-06-12 14:08:25,146 - DEBUG - their number of aftershocks should be:0
# 2026-06-12 14:08:25,146 - DEBUG - generation 7
# 2026-06-12 14:08:25,148 - DEBUG - number of events with aftershocks: 0
# 2026-06-12 14:08:25,151 - INFO -   number of background events needed: 38
# 2026-06-12 14:08:25,152 - INFO -   generating 77 to throw away those outside the polygon
# 2026-06-12 14:08:25,156 - DEBUG - number of induced events: 0
# 2026-06-12 14:08:25,158 - DEBUG - number of background events: 38
# 2026-06-12 14:08:25,158 - DEBUG - number of auxiliary events: 1
# 2026-06-12 14:08:25,158 - DEBUG - generation 0
# 2026-06-12 14:08:25,160 - DEBUG - number of events with aftershocks: 21
# 2026-06-12 14:08:25,167 - DEBUG - number of aftershocks: 28
# 2026-06-12 14:08:25,168 - DEBUG - their number of aftershocks should be:26
# 2026-06-12 14:08:25,169 - DEBUG - generation 1
# 2026-06-12 14:08:25,170 - DEBUG - number of events with aftershocks: 15
# 2026-06-12 14:08:25,178 - DEBUG - number of aftershocks: 16
# 2026-06-12 14:08:25,178 - DEBUG - their number of aftershocks should be:17
# 2026-06-12 14:08:25,179 - DEBUG - generation 2
# 2026-06-12 14:08:25,181 - DEBUG - number of events with aftershocks: 11
# 2026-06-12 14:08:25,188 - DEBUG - number of aftershocks: 9
# 2026-06-12 14:08:25,188 - DEBUG - their number of aftershocks should be:9
# 2026-06-12 14:08:25,189 - DEBUG - generation 3
# 2026-06-12 14:08:25,191 - DEBUG - number of events with aftershocks: 4
# 2026-06-12 14:08:25,198 - DEBUG - number of aftershocks: 4
# 2026-06-12 14:08:25,198 - DEBUG - their number of aftershocks should be:4
# 2026-06-12 14:08:25,199 - DEBUG - generation 4
# 2026-06-12 14:08:25,201 - DEBUG - number of events with aftershocks: 3
# 2026-06-12 14:08:25,216 - DEBUG - number of aftershocks: 2
# 2026-06-12 14:08:25,218 - DEBUG - their number of aftershocks should be:2
# 2026-06-12 14:08:25,219 - DEBUG - generation 5
# 2026-06-12 14:08:25,221 - DEBUG - number of events with aftershocks: 2
# 2026-06-12 14:08:25,229 - DEBUG - number of aftershocks: 2
# 2026-06-12 14:08:25,229 - DEBUG - their number of aftershocks should be:2
# 2026-06-12 14:08:25,230 - DEBUG - generation 6
# 2026-06-12 14:08:25,232 - DEBUG - number of events with aftershocks: 2
# 2026-06-12 14:08:25,239 - DEBUG - number of aftershocks: 0
# 2026-06-12 14:08:25,239 - DEBUG - their number of aftershocks should be:0
# 2026-06-12 14:08:25,240 - DEBUG - generation 7
# 2026-06-12 14:08:25,242 - DEBUG - number of events with aftershocks: 0
# 2026-06-12 14:08:25,246 - INFO -   number of background events needed: 52
# 2026-06-12 14:08:25,247 - INFO -   generating 106 to throw away those outside the polygon
# 2026-06-12 14:08:25,251 - DEBUG - number of induced events: 0
# 2026-06-12 14:08:25,254 - DEBUG - number of background events: 52
# 2026-06-12 14:08:25,254 - DEBUG - number of auxiliary events: 1
# 2026-06-12 14:08:25,254 - DEBUG - generation 0
# 2026-06-12 14:08:25,255 - DEBUG - number of events with aftershocks: 31
# 2026-06-12 14:08:25,263 - DEBUG - number of aftershocks: 31
# 2026-06-12 14:08:25,263 - DEBUG - their number of aftershocks should be:30
# 2026-06-12 14:08:25,265 - DEBUG - generation 1
# 2026-06-12 14:08:25,266 - DEBUG - number of events with aftershocks: 16
# 2026-06-12 14:08:25,274 - DEBUG - number of aftershocks: 15
# 2026-06-12 14:08:25,274 - DEBUG - their number of aftershocks should be:12
# 2026-06-12 14:08:25,275 - DEBUG - generation 2
# 2026-06-12 14:08:25,277 - DEBUG - number of events with aftershocks: 9
# 2026-06-12 14:08:25,284 - DEBUG - number of aftershocks: 4
# 2026-06-12 14:08:25,284 - DEBUG - their number of aftershocks should be:3
# 2026-06-12 14:08:25,285 - DEBUG - generation 3
# 2026-06-12 14:08:25,287 - DEBUG - number of events with aftershocks: 3
# 2026-06-12 14:08:25,294 - DEBUG - number of aftershocks: 2
# 2026-06-12 14:08:25,294 - DEBUG - their number of aftershocks should be:2
# 2026-06-12 14:08:25,295 - DEBUG - generation 4
# 2026-06-12 14:08:25,297 - DEBUG - number of events with aftershocks: 2
# 2026-06-12 14:08:25,304 - DEBUG - number of aftershocks: 0
# 2026-06-12 14:08:25,304 - DEBUG - their number of aftershocks should be:0
# 2026-06-12 14:08:25,305 - DEBUG - generation 5
# 2026-06-12 14:08:25,307 - DEBUG - number of events with aftershocks: 0
# 2026-06-12 14:08:25,310 - INFO -   number of background events needed: 46
# 2026-06-12 14:08:25,310 - INFO -   generating 94 to throw away those outside the polygon
# 2026-06-12 14:08:25,314 - DEBUG - number of induced events: 0
# 2026-06-12 14:08:25,317 - DEBUG - number of background events: 46
# 2026-06-12 14:08:25,317 - DEBUG - number of auxiliary events: 1
# 2026-06-12 14:08:25,317 - DEBUG - generation 0
# 2026-06-12 14:08:25,319 - DEBUG - number of events with aftershocks: 33
# 2026-06-12 14:08:25,326 - DEBUG - number of aftershocks: 48
# 2026-06-12 14:08:25,327 - DEBUG - their number of aftershocks should be:46
# 2026-06-12 14:08:25,328 - DEBUG - generation 1
# 2026-06-12 14:08:25,329 - DEBUG - number of events with aftershocks: 26
# 2026-06-12 14:08:25,337 - DEBUG - number of aftershocks: 24
# 2026-06-12 14:08:25,337 - DEBUG - their number of aftershocks should be:25
# 2026-06-12 14:08:25,338 - DEBUG - generation 2
# 2026-06-12 14:08:25,340 - DEBUG - number of events with aftershocks: 14
# 2026-06-12 14:08:25,347 - DEBUG - number of aftershocks: 19
# 2026-06-12 14:08:25,348 - DEBUG - their number of aftershocks should be:9
# 2026-06-12 14:08:25,348 - DEBUG - generation 3
# 2026-06-12 14:08:25,350 - DEBUG - number of events with aftershocks: 9
# 2026-06-12 14:08:25,357 - DEBUG - number of aftershocks: 5
# 2026-06-12 14:08:25,358 - DEBUG - their number of aftershocks should be:7
# 2026-06-12 14:08:25,358 - DEBUG - generation 4
# 2026-06-12 14:08:25,360 - DEBUG - number of events with aftershocks: 4
# 2026-06-12 14:08:25,367 - DEBUG - number of aftershocks: 4
# 2026-06-12 14:08:25,368 - DEBUG - their number of aftershocks should be:3
# 2026-06-12 14:08:25,368 - DEBUG - generation 5
# 2026-06-12 14:08:25,370 - DEBUG - number of events with aftershocks: 3
# 2026-06-12 14:08:25,377 - DEBUG - number of aftershocks: 1
# 2026-06-12 14:08:25,377 - DEBUG - their number of aftershocks should be:0
# 2026-06-12 14:08:25,378 - DEBUG - generation 6
# 2026-06-12 14:08:25,380 - DEBUG - number of events with aftershocks: 0
# 2026-06-12 14:08:25,384 - INFO -   number of background events needed: 54
# 2026-06-12 14:08:25,384 - INFO -   generating 110 to throw away those outside the polygon
# 2026-06-12 14:08:25,388 - DEBUG - number of induced events: 0
# 2026-06-12 14:08:25,390 - DEBUG - number of background events: 54
# 2026-06-12 14:08:25,391 - DEBUG - number of auxiliary events: 1
# 2026-06-12 14:08:25,391 - DEBUG - generation 0
# 2026-06-12 14:08:25,392 - DEBUG - number of events with aftershocks: 35
# 2026-06-12 14:08:25,400 - DEBUG - number of aftershocks: 42
# 2026-06-12 14:08:25,400 - DEBUG - their number of aftershocks should be:37
# 2026-06-12 14:08:25,401 - DEBUG - generation 1
# 2026-06-12 14:08:25,403 - DEBUG - number of events with aftershocks: 23
# 2026-06-12 14:08:25,410 - DEBUG - number of aftershocks: 27
# 2026-06-12 14:08:25,411 - DEBUG - their number of aftershocks should be:24
# 2026-06-12 14:08:25,411 - DEBUG - generation 2
# 2026-06-12 14:08:25,413 - DEBUG - number of events with aftershocks: 17
# 2026-06-12 14:08:25,420 - DEBUG - number of aftershocks: 17
# 2026-06-12 14:08:25,421 - DEBUG - their number of aftershocks should be:28
# 2026-06-12 14:08:25,422 - DEBUG - generation 3
# 2026-06-12 14:08:25,423 - DEBUG - number of events with aftershocks: 13
# 2026-06-12 14:08:25,431 - DEBUG - number of aftershocks: 13
# 2026-06-12 14:08:25,431 - DEBUG - their number of aftershocks should be:15
# 2026-06-12 14:08:25,432 - DEBUG - generation 4
# 2026-06-12 14:08:25,434 - DEBUG - number of events with aftershocks: 9
# 2026-06-12 14:08:25,441 - DEBUG - number of aftershocks: 9
# 2026-06-12 14:08:25,441 - DEBUG - their number of aftershocks should be:12
# 2026-06-12 14:08:25,442 - DEBUG - generation 5
# 2026-06-12 14:08:25,444 - DEBUG - number of events with aftershocks: 6
# 2026-06-12 14:08:25,451 - DEBUG - number of aftershocks: 6
# 2026-06-12 14:08:25,451 - DEBUG - their number of aftershocks should be:4
# 2026-06-12 14:08:25,452 - DEBUG - generation 6
# 2026-06-12 14:08:25,454 - DEBUG - number of events with aftershocks: 2
# 2026-06-12 14:08:25,461 - DEBUG - number of aftershocks: 1
# 2026-06-12 14:08:25,461 - DEBUG - their number of aftershocks should be:1
# 2026-06-12 14:08:25,462 - DEBUG - generation 7
# 2026-06-12 14:08:25,464 - DEBUG - number of events with aftershocks: 1
# 2026-06-12 14:08:25,471 - DEBUG - number of aftershocks: 0
# 2026-06-12 14:08:25,471 - DEBUG - their number of aftershocks should be:0
# 2026-06-12 14:08:25,472 - DEBUG - generation 8
# 2026-06-12 14:08:25,474 - DEBUG - number of events with aftershocks: 0
# 2026-06-12 14:08:25,477 - INFO -   number of background events needed: 40
# 2026-06-12 14:08:25,477 - INFO -   generating 81 to throw away those outside the polygon
# 2026-06-12 14:08:25,482 - DEBUG - number of induced events: 0
# 2026-06-12 14:08:25,484 - DEBUG - number of background events: 40
# 2026-06-12 14:08:25,484 - DEBUG - number of auxiliary events: 1
# 2026-06-12 14:08:25,484 - DEBUG - generation 0
# 2026-06-12 14:08:25,486 - DEBUG - number of events with aftershocks: 20
# 2026-06-12 14:08:25,493 - DEBUG - number of aftershocks: 24
# 2026-06-12 14:08:25,494 - DEBUG - their number of aftershocks should be:24
# 2026-06-12 14:08:25,495 - DEBUG - generation 1
# 2026-06-12 14:08:25,496 - DEBUG - number of events with aftershocks: 13
# 2026-06-12 14:08:25,504 - DEBUG - number of aftershocks: 15
# 2026-06-12 14:08:25,504 - DEBUG - their number of aftershocks should be:14
# 2026-06-12 14:08:25,505 - DEBUG - generation 2
# 2026-06-12 14:08:25,506 - DEBUG - number of events with aftershocks: 8
# 2026-06-12 14:08:25,514 - DEBUG - number of aftershocks: 5
# 2026-06-12 14:08:25,514 - DEBUG - their number of aftershocks should be:2
# 2026-06-12 14:08:25,515 - DEBUG - generation 3
# 2026-06-12 14:08:25,516 - DEBUG - number of events with aftershocks: 2
# 2026-06-12 14:08:25,524 - DEBUG - number of aftershocks: 0
# 2026-06-12 14:08:25,524 - DEBUG - their number of aftershocks should be:0
# 2026-06-12 14:08:25,525 - DEBUG - generation 4
# 2026-06-12 14:08:25,526 - DEBUG - number of events with aftershocks: 0
# 2026-06-12 14:08:25,530 - INFO -   number of background events needed: 41
# 2026-06-12 14:08:25,530 - INFO -   generating 83 to throw away those outside the polygon
# 2026-06-12 14:08:25,534 - DEBUG - number of induced events: 0
# 2026-06-12 14:08:25,537 - DEBUG - number of background events: 41
# 2026-06-12 14:08:25,537 - DEBUG - number of auxiliary events: 1
# 2026-06-12 14:08:25,537 - DEBUG - generation 0
# 2026-06-12 14:08:25,538 - DEBUG - number of events with aftershocks: 27
# 2026-06-12 14:08:25,546 - DEBUG - number of aftershocks: 54
# 2026-06-12 14:08:25,547 - DEBUG - their number of aftershocks should be:66
# 2026-06-12 14:08:25,548 - DEBUG - generation 1
# 2026-06-12 14:08:25,549 - DEBUG - number of events with aftershocks: 38
# 2026-06-12 14:08:25,557 - DEBUG - number of aftershocks: 37
# 2026-06-12 14:08:25,557 - DEBUG - their number of aftershocks should be:33
# 2026-06-12 14:08:25,558 - DEBUG - generation 2
# 2026-06-12 14:08:25,560 - DEBUG - number of events with aftershocks: 19
# 2026-06-12 14:08:25,567 - DEBUG - number of aftershocks: 23
# 2026-06-12 14:08:25,567 - DEBUG - their number of aftershocks should be:19
# 2026-06-12 14:08:25,568 - DEBUG - generation 3
# 2026-06-12 14:08:25,570 - DEBUG - number of events with aftershocks: 11
# 2026-06-12 14:08:25,577 - DEBUG - number of aftershocks: 15
# 2026-06-12 14:08:25,577 - DEBUG - their number of aftershocks should be:11
# 2026-06-12 14:08:25,578 - DEBUG - generation 4
# 2026-06-12 14:08:25,580 - DEBUG - number of events with aftershocks: 6
# 2026-06-12 14:08:25,587 - DEBUG - number of aftershocks: 8
# 2026-06-12 14:08:25,587 - DEBUG - their number of aftershocks should be:7
# 2026-06-12 14:08:25,588 - DEBUG - generation 5
# 2026-06-12 14:08:25,590 - DEBUG - number of events with aftershocks: 5
# 2026-06-12 14:08:25,597 - DEBUG - number of aftershocks: 6
# 2026-06-12 14:08:25,597 - DEBUG - their number of aftershocks should be:4
# 2026-06-12 14:08:25,598 - DEBUG - generation 6
# 2026-06-12 14:08:25,600 - DEBUG - number of events with aftershocks: 3
# 2026-06-12 14:08:25,607 - DEBUG - number of aftershocks: 1
# 2026-06-12 14:08:25,607 - DEBUG - their number of aftershocks should be:1
# 2026-06-12 14:08:25,608 - DEBUG - generation 7
# 2026-06-12 14:08:25,610 - DEBUG - number of events with aftershocks: 1
# 2026-06-12 14:08:25,617 - DEBUG - number of aftershocks: 1
# 2026-06-12 14:08:25,617 - DEBUG - their number of aftershocks should be:0
# 2026-06-12 14:08:25,618 - DEBUG - generation 8
# 2026-06-12 14:08:25,620 - DEBUG - number of events with aftershocks: 0
# 2026-06-12 14:08:25,623 - INFO -   number of background events needed: 49
# 2026-06-12 14:08:25,623 - INFO -   generating 100 to throw away those outside the polygon
# 2026-06-12 14:08:25,627 - DEBUG - number of induced events: 0
# 2026-06-12 14:08:25,630 - DEBUG - number of background events: 49
# 2026-06-12 14:08:25,630 - DEBUG - number of auxiliary events: 1
# 2026-06-12 14:08:25,630 - DEBUG - generation 0
# 2026-06-12 14:08:25,632 - DEBUG - number of events with aftershocks: 30
# 2026-06-12 14:08:25,639 - DEBUG - number of aftershocks: 33
# 2026-06-12 14:08:25,640 - DEBUG - their number of aftershocks should be:27
# 2026-06-12 14:08:25,641 - DEBUG - generation 1
# 2026-06-12 14:08:25,642 - DEBUG - number of events with aftershocks: 19
# 2026-06-12 14:08:25,650 - DEBUG - number of aftershocks: 15
# 2026-06-12 14:08:25,650 - DEBUG - their number of aftershocks should be:23
# 2026-06-12 14:08:25,651 - DEBUG - generation 2
# 2026-06-12 14:08:25,652 - DEBUG - number of events with aftershocks: 13
# 2026-06-12 14:08:25,660 - DEBUG - number of aftershocks: 16
# 2026-06-12 14:08:25,660 - DEBUG - their number of aftershocks should be:12
# 2026-06-12 14:08:25,661 - DEBUG - generation 3
# 2026-06-12 14:08:25,663 - DEBUG - number of events with aftershocks: 8
# 2026-06-12 14:08:25,670 - DEBUG - number of aftershocks: 6
# 2026-06-12 14:08:25,670 - DEBUG - their number of aftershocks should be:4
# 2026-06-12 14:08:25,671 - DEBUG - generation 4
# 2026-06-12 14:08:25,673 - DEBUG - number of events with aftershocks: 3
# 2026-06-12 14:08:25,680 - DEBUG - number of aftershocks: 2
# 2026-06-12 14:08:25,680 - DEBUG - their number of aftershocks should be:0
# 2026-06-12 14:08:25,681 - DEBUG - generation 5
# 2026-06-12 14:08:25,683 - DEBUG - number of events with aftershocks: 0
# 2026-06-12 14:08:25,686 - INFO -   number of background events needed: 35
# 2026-06-12 14:08:25,686 - INFO -   generating 71 to throw away those outside the polygon
# 2026-06-12 14:08:25,691 - DEBUG - number of induced events: 0
# 2026-06-12 14:08:25,693 - DEBUG - number of background events: 35
# 2026-06-12 14:08:25,693 - DEBUG - number of auxiliary events: 1
# 2026-06-12 14:08:25,693 - DEBUG - generation 0
# 2026-06-12 14:08:25,695 - DEBUG - number of events with aftershocks: 20
# 2026-06-12 14:08:25,702 - DEBUG - number of aftershocks: 24
# 2026-06-12 14:08:25,702 - DEBUG - their number of aftershocks should be:20
# 2026-06-12 14:08:25,704 - DEBUG - generation 1
# 2026-06-12 14:08:25,705 - DEBUG - number of events with aftershocks: 12
# 2026-06-12 14:08:25,713 - DEBUG - number of aftershocks: 15
# 2026-06-12 14:08:25,713 - DEBUG - their number of aftershocks should be:12
# 2026-06-12 14:08:25,714 - DEBUG - generation 2
# 2026-06-12 14:08:25,715 - DEBUG - number of events with aftershocks: 8
# 2026-06-12 14:08:25,723 - DEBUG - number of aftershocks: 6
# 2026-06-12 14:08:25,723 - DEBUG - their number of aftershocks should be:4
# 2026-06-12 14:08:25,724 - DEBUG - generation 3
# 2026-06-12 14:08:25,725 - DEBUG - number of events with aftershocks: 4
# 2026-06-12 14:08:25,733 - DEBUG - number of aftershocks: 4
# 2026-06-12 14:08:25,733 - DEBUG - their number of aftershocks should be:2
# 2026-06-12 14:08:25,734 - DEBUG - generation 4
# 2026-06-12 14:08:25,735 - DEBUG - number of events with aftershocks: 1
# 2026-06-12 14:08:25,742 - DEBUG - number of aftershocks: 2
# 2026-06-12 14:08:25,743 - DEBUG - their number of aftershocks should be:1
# 2026-06-12 14:08:25,744 - DEBUG - generation 5
# 2026-06-12 14:08:25,745 - DEBUG - number of events with aftershocks: 1
# 2026-06-12 14:08:25,752 - DEBUG - number of aftershocks: 0
# 2026-06-12 14:08:25,753 - DEBUG - their number of aftershocks should be:0
# 2026-06-12 14:08:25,753 - DEBUG - generation 6
# 2026-06-12 14:08:25,755 - DEBUG - number of events with aftershocks: 0
# 2026-06-12 14:08:25,758 - INFO -   number of background events needed: 47
# 2026-06-12 14:08:25,759 - INFO -   generating 96 to throw away those outside the polygon
# 2026-06-12 14:08:25,763 - DEBUG - number of induced events: 0
# 2026-06-12 14:08:25,765 - DEBUG - number of background events: 47
# 2026-06-12 14:08:25,765 - DEBUG - number of auxiliary events: 1
# 2026-06-12 14:08:25,766 - DEBUG - generation 0
# 2026-06-12 14:08:25,767 - DEBUG - number of events with aftershocks: 29
# 2026-06-12 14:08:25,775 - DEBUG - number of aftershocks: 27
# 2026-06-12 14:08:25,775 - DEBUG - their number of aftershocks should be:22
# 2026-06-12 14:08:25,776 - DEBUG - generation 1
# 2026-06-12 14:08:25,778 - DEBUG - number of events with aftershocks: 15
# 2026-06-12 14:08:25,785 - DEBUG - number of aftershocks: 13
# 2026-06-12 14:08:25,785 - DEBUG - their number of aftershocks should be:12
# 2026-06-12 14:08:25,786 - DEBUG - generation 2
# 2026-06-12 14:08:25,788 - DEBUG - number of events with aftershocks: 8
# 2026-06-12 14:08:25,795 - DEBUG - number of aftershocks: 5
# 2026-06-12 14:08:25,795 - DEBUG - their number of aftershocks should be:6
# 2026-06-12 14:08:25,796 - DEBUG - generation 3
# 2026-06-12 14:08:25,798 - DEBUG - number of events with aftershocks: 3
# 2026-06-12 14:08:25,805 - DEBUG - number of aftershocks: 5
# 2026-06-12 14:08:25,805 - DEBUG - their number of aftershocks should be:5
# 2026-06-12 14:08:25,806 - DEBUG - generation 4
# 2026-06-12 14:08:25,808 - DEBUG - number of events with aftershocks: 4
# 2026-06-12 14:08:25,815 - DEBUG - number of aftershocks: 4
# 2026-06-12 14:08:25,815 - DEBUG - their number of aftershocks should be:6
# 2026-06-12 14:08:25,816 - DEBUG - generation 5
# 2026-06-12 14:08:25,818 - DEBUG - number of events with aftershocks: 4
# 2026-06-12 14:08:25,825 - DEBUG - number of aftershocks: 2
# 2026-06-12 14:08:25,825 - DEBUG - their number of aftershocks should be:1
# 2026-06-12 14:08:25,826 - DEBUG - generation 6
# 2026-06-12 14:08:25,828 - DEBUG - number of events with aftershocks: 1
# 2026-06-12 14:08:25,835 - DEBUG - number of aftershocks: 1
# 2026-06-12 14:08:25,835 - DEBUG - their number of aftershocks should be:1
# 2026-06-12 14:08:25,836 - DEBUG - generation 7
# 2026-06-12 14:08:25,837 - DEBUG - number of events with aftershocks: 1
# 2026-06-12 14:08:25,845 - DEBUG - number of aftershocks: 0
# 2026-06-12 14:08:25,845 - DEBUG - their number of aftershocks should be:0
# 2026-06-12 14:08:25,846 - DEBUG - generation 8
# 2026-06-12 14:08:25,848 - DEBUG - number of events with aftershocks: 0
# 2026-06-12 14:08:25,851 - INFO -   number of background events needed: 30
# 2026-06-12 14:08:25,851 - INFO -   generating 61 to throw away those outside the polygon
# 2026-06-12 14:08:25,856 - DEBUG - number of induced events: 0
# 2026-06-12 14:08:25,858 - DEBUG - number of background events: 30
# 2026-06-12 14:08:25,858 - DEBUG - number of auxiliary events: 1
# 2026-06-12 14:08:25,858 - DEBUG - generation 0
# 2026-06-12 14:08:25,860 - DEBUG - number of events with aftershocks: 21
# 2026-06-12 14:08:25,868 - DEBUG - number of aftershocks: 26
# 2026-06-12 14:08:25,868 - DEBUG - their number of aftershocks should be:41
# 2026-06-12 14:08:25,869 - DEBUG - generation 1
# 2026-06-12 14:08:25,871 - DEBUG - number of events with aftershocks: 16
# 2026-06-12 14:08:25,878 - DEBUG - number of aftershocks: 26
# 2026-06-12 14:08:25,878 - DEBUG - their number of aftershocks should be:26
# 2026-06-12 14:08:25,879 - DEBUG - generation 2
# 2026-06-12 14:08:25,881 - DEBUG - number of events with aftershocks: 12
# 2026-06-12 14:08:25,888 - DEBUG - number of aftershocks: 18
# 2026-06-12 14:08:25,889 - DEBUG - their number of aftershocks should be:19
# 2026-06-12 14:08:25,889 - DEBUG - generation 3
# 2026-06-12 14:08:25,891 - DEBUG - number of events with aftershocks: 10
# 2026-06-12 14:08:25,898 - DEBUG - number of aftershocks: 16
# 2026-06-12 14:08:25,899 - DEBUG - their number of aftershocks should be:11
# 2026-06-12 14:08:25,899 - DEBUG - generation 4
# 2026-06-12 14:08:25,901 - DEBUG - number of events with aftershocks: 7
# 2026-06-12 14:08:25,908 - DEBUG - number of aftershocks: 6
# 2026-06-12 14:08:25,909 - DEBUG - their number of aftershocks should be:5
# 2026-06-12 14:08:25,910 - DEBUG - generation 5
# 2026-06-12 14:08:25,911 - DEBUG - number of events with aftershocks: 3
# 2026-06-12 14:08:25,918 - DEBUG - number of aftershocks: 4
# 2026-06-12 14:08:25,919 - DEBUG - their number of aftershocks should be:3
# 2026-06-12 14:08:25,919 - DEBUG - generation 6
# ...
# 2026-06-12 14:08:48,306 - DEBUG - number of events with aftershocks: 2
# 2026-06-12 14:08:48,313 - DEBUG - number of aftershocks: 1
# 2026-06-12 14:08:48,314 - DEBUG - their number of aftershocks should be:1
# 2026-06-12 14:08:48,315 - DEBUG - generation 5
# 2026-06-12 14:08:48,316 - DEBUG - number of events with aftershocks: 1
# 2026-06-12 14:08:48,323 - DEBUG - number of aftershocks: 1
# 2026-06-12 14:08:48,323 - DEBUG - their number of aftershocks should be:4
# 2026-06-12 14:08:48,324 - DEBUG - generation 6
# 2026-06-12 14:08:48,326 - DEBUG - number of events with aftershocks: 1
# 2026-06-12 14:08:48,333 - DEBUG - number of aftershocks: 4
# 2026-06-12 14:08:48,333 - DEBUG - their number of aftershocks should be:2
# 2026-06-12 14:08:48,334 - DEBUG - generation 7
# 2026-06-12 14:08:48,336 - DEBUG - number of events with aftershocks: 1
# 2026-06-12 14:08:48,343 - DEBUG - number of aftershocks: 0
# 2026-06-12 14:08:48,343 - DEBUG - their number of aftershocks should be:0
# 2026-06-12 14:08:48,344 - DEBUG - generation 8
# 2026-06-12 14:08:48,346 - DEBUG - number of events with aftershocks: 0
# 2026-06-12 14:08:48,350 - INFO -   number of background events needed: 49
# 2026-06-12 14:08:48,350 - INFO -   generating 100 to throw away those outside the polygon
# 2026-06-12 14:08:48,354 - DEBUG - number of induced events: 0
# 2026-06-12 14:08:48,356 - DEBUG - number of background events: 49
# 2026-06-12 14:08:48,357 - DEBUG - number of auxiliary events: 1
# 2026-06-12 14:08:48,357 - DEBUG - generation 0
# 2026-06-12 14:08:48,358 - DEBUG - number of events with aftershocks: 29
# 2026-06-12 14:08:48,366 - DEBUG - number of aftershocks: 35
# 2026-06-12 14:08:48,366 - DEBUG - their number of aftershocks should be:41
# 2026-06-12 14:08:48,367 - DEBUG - generation 1
# 2026-06-12 14:08:48,369 - DEBUG - number of events with aftershocks: 23
# 2026-06-12 14:08:48,377 - DEBUG - number of aftershocks: 23
# 2026-06-12 14:08:48,377 - DEBUG - their number of aftershocks should be:44
# 2026-06-12 14:08:48,378 - DEBUG - generation 2
# 2026-06-12 14:08:48,379 - DEBUG - number of events with aftershocks: 18
# 2026-06-12 14:08:48,387 - DEBUG - number of aftershocks: 30
# 2026-06-12 14:08:48,387 - DEBUG - their number of aftershocks should be:35
# 2026-06-12 14:08:48,388 - DEBUG - generation 3
# 2026-06-12 14:08:48,390 - DEBUG - number of events with aftershocks: 18
# 2026-06-12 14:08:48,397 - DEBUG - number of aftershocks: 25
# 2026-06-12 14:08:48,397 - DEBUG - their number of aftershocks should be:19
# 2026-06-12 14:08:48,398 - DEBUG - generation 4
# 2026-06-12 14:08:48,400 - DEBUG - number of events with aftershocks: 14
# 2026-06-12 14:08:48,407 - DEBUG - number of aftershocks: 9
# 2026-06-12 14:08:48,407 - DEBUG - their number of aftershocks should be:8
# 2026-06-12 14:08:48,408 - DEBUG - generation 5
# 2026-06-12 14:08:48,410 - DEBUG - number of events with aftershocks: 6
# 2026-06-12 14:08:48,417 - DEBUG - number of aftershocks: 6
# 2026-06-12 14:08:48,417 - DEBUG - their number of aftershocks should be:7
# 2026-06-12 14:08:48,418 - DEBUG - generation 6
# 2026-06-12 14:08:48,420 - DEBUG - number of events with aftershocks: 4
# 2026-06-12 14:08:48,427 - DEBUG - number of aftershocks: 5
# 2026-06-12 14:08:48,427 - DEBUG - their number of aftershocks should be:4
# 2026-06-12 14:08:48,428 - DEBUG - generation 7
# 2026-06-12 14:08:48,430 - DEBUG - number of events with aftershocks: 3
# 2026-06-12 14:08:48,437 - DEBUG - number of aftershocks: 4
# 2026-06-12 14:08:48,437 - DEBUG - their number of aftershocks should be:3
# 2026-06-12 14:08:48,438 - DEBUG - generation 8
# 2026-06-12 14:08:48,440 - DEBUG - number of events with aftershocks: 3
# 2026-06-12 14:08:48,447 - DEBUG - number of aftershocks: 1
# 2026-06-12 14:08:48,447 - DEBUG - their number of aftershocks should be:1
# 2026-06-12 14:08:48,448 - DEBUG - generation 9
# 2026-06-12 14:08:48,450 - DEBUG - number of events with aftershocks: 1
# 2026-06-12 14:08:48,457 - DEBUG - number of aftershocks: 0
# 2026-06-12 14:08:48,457 - DEBUG - their number of aftershocks should be:0
# 2026-06-12 14:08:48,458 - DEBUG - generation 10
# 2026-06-12 14:08:48,460 - DEBUG - number of events with aftershocks: 0
# 2026-06-12 14:08:48,463 - INFO -   number of background events needed: 48
# 2026-06-12 14:08:48,463 - INFO -   generating 98 to throw away those outside the polygon
# 2026-06-12 14:08:48,468 - DEBUG - number of induced events: 0
# 2026-06-12 14:08:48,470 - DEBUG - number of background events: 48
# 2026-06-12 14:08:48,470 - DEBUG - number of auxiliary events: 1
# 2026-06-12 14:08:48,470 - DEBUG - generation 0
# 2026-06-12 14:08:48,472 - DEBUG - number of events with aftershocks: 23
# 2026-06-12 14:08:48,480 - DEBUG - number of aftershocks: 32
# 2026-06-12 14:08:48,480 - DEBUG - their number of aftershocks should be:24
# 2026-06-12 14:08:48,481 - DEBUG - generation 1
# 2026-06-12 14:08:48,483 - DEBUG - number of events with aftershocks: 15
# 2026-06-12 14:08:48,490 - DEBUG - number of aftershocks: 10
# 2026-06-12 14:08:48,490 - DEBUG - their number of aftershocks should be:11
# 2026-06-12 14:08:48,491 - DEBUG - generation 2
# 2026-06-12 14:08:48,493 - DEBUG - number of events with aftershocks: 6
# 2026-06-12 14:08:48,500 - DEBUG - number of aftershocks: 6
# 2026-06-12 14:08:48,500 - DEBUG - their number of aftershocks should be:4
# 2026-06-12 14:08:48,501 - DEBUG - generation 3
# 2026-06-12 14:08:48,503 - DEBUG - number of events with aftershocks: 3
# 2026-06-12 14:08:48,510 - DEBUG - number of aftershocks: 4
# 2026-06-12 14:08:48,510 - DEBUG - their number of aftershocks should be:9
# 2026-06-12 14:08:48,511 - DEBUG - generation 4
# 2026-06-12 14:08:48,513 - DEBUG - number of events with aftershocks: 4
# 2026-06-12 14:08:48,520 - DEBUG - number of aftershocks: 8
# 2026-06-12 14:08:48,520 - DEBUG - their number of aftershocks should be:8
# 2026-06-12 14:08:48,521 - DEBUG - generation 5
# 2026-06-12 14:08:48,523 - DEBUG - number of events with aftershocks: 4
# 2026-06-12 14:08:48,530 - DEBUG - number of aftershocks: 7
# 2026-06-12 14:08:48,530 - DEBUG - their number of aftershocks should be:4
# 2026-06-12 14:08:48,531 - DEBUG - generation 6
# 2026-06-12 14:08:48,533 - DEBUG - number of events with aftershocks: 3
# 2026-06-12 14:08:48,540 - DEBUG - number of aftershocks: 3
# 2026-06-12 14:08:48,540 - DEBUG - their number of aftershocks should be:2
# 2026-06-12 14:08:48,541 - DEBUG - generation 7
# 2026-06-12 14:08:48,543 - DEBUG - number of events with aftershocks: 1
# 2026-06-12 14:08:48,550 - DEBUG - number of aftershocks: 0
# 2026-06-12 14:08:48,550 - DEBUG - their number of aftershocks should be:0
# 2026-06-12 14:08:48,551 - DEBUG - generation 8
# 2026-06-12 14:08:48,553 - DEBUG - number of events with aftershocks: 0
# 2026-06-12 14:08:48,556 - INFO -   number of background events needed: 42
# 2026-06-12 14:08:48,557 - INFO -   generating 86 to throw away those outside the polygon
# 2026-06-12 14:08:48,561 - DEBUG - number of induced events: 0
# 2026-06-12 14:08:48,563 - DEBUG - number of background events: 42
# 2026-06-12 14:08:48,563 - DEBUG - number of auxiliary events: 1
# 2026-06-12 14:08:48,564 - DEBUG - generation 0
# 2026-06-12 14:08:48,565 - DEBUG - number of events with aftershocks: 21
# 2026-06-12 14:08:48,573 - DEBUG - number of aftershocks: 19
# 2026-06-12 14:08:48,573 - DEBUG - their number of aftershocks should be:11
# 2026-06-12 14:08:48,574 - DEBUG - generation 1
# 2026-06-12 14:08:48,576 - DEBUG - number of events with aftershocks: 7
# 2026-06-12 14:08:48,583 - DEBUG - number of aftershocks: 7
# 2026-06-12 14:08:48,583 - DEBUG - their number of aftershocks should be:5
# 2026-06-12 14:08:48,584 - DEBUG - generation 2
# 2026-06-12 14:08:48,586 - DEBUG - number of events with aftershocks: 3
# 2026-06-12 14:08:48,593 - DEBUG - number of aftershocks: 3
# 2026-06-12 14:08:48,593 - DEBUG - their number of aftershocks should be:7
# 2026-06-12 14:08:48,594 - DEBUG - generation 3
# 2026-06-12 14:08:48,596 - DEBUG - number of events with aftershocks: 3
# 2026-06-12 14:08:48,603 - DEBUG - number of aftershocks: 4
# 2026-06-12 14:08:48,603 - DEBUG - their number of aftershocks should be:6
# 2026-06-12 14:08:48,604 - DEBUG - generation 4
# 2026-06-12 14:08:48,606 - DEBUG - number of events with aftershocks: 3
# 2026-06-12 14:08:48,613 - DEBUG - number of aftershocks: 3
# 2026-06-12 14:08:48,613 - DEBUG - their number of aftershocks should be:2
# 2026-06-12 14:08:48,614 - DEBUG - generation 5
# 2026-06-12 14:08:48,616 - DEBUG - number of events with aftershocks: 1
# 2026-06-12 14:08:48,623 - DEBUG - number of aftershocks: 0
# 2026-06-12 14:08:48,623 - DEBUG - their number of aftershocks should be:0
# 2026-06-12 14:08:48,624 - DEBUG - generation 6
# 2026-06-12 14:08:48,626 - DEBUG - number of events with aftershocks: 0
# 2026-06-12 14:08:48,629 - INFO -   number of background events needed: 61
# 2026-06-12 14:08:48,630 - INFO -   generating 124 to throw away those outside the polygon
# 2026-06-12 14:08:48,634 - DEBUG - number of induced events: 0
# 2026-06-12 14:08:48,636 - DEBUG - number of background events: 61
# 2026-06-12 14:08:48,636 - DEBUG - number of auxiliary events: 1
# 2026-06-12 14:08:48,636 - DEBUG - generation 0
# 2026-06-12 14:08:48,638 - DEBUG - number of events with aftershocks: 37
# 2026-06-12 14:08:48,646 - DEBUG - number of aftershocks: 42
# 2026-06-12 14:08:48,646 - DEBUG - their number of aftershocks should be:42
# 2026-06-12 14:08:48,647 - DEBUG - generation 1
# 2026-06-12 14:08:48,649 - DEBUG - number of events with aftershocks: 20
# 2026-06-12 14:08:48,656 - DEBUG - number of aftershocks: 22
# 2026-06-12 14:08:48,657 - DEBUG - their number of aftershocks should be:25
# 2026-06-12 14:08:48,657 - DEBUG - generation 2
# 2026-06-12 14:08:48,659 - DEBUG - number of events with aftershocks: 14
# 2026-06-12 14:08:48,667 - DEBUG - number of aftershocks: 15
# 2026-06-12 14:08:48,667 - DEBUG - their number of aftershocks should be:12
# 2026-06-12 14:08:48,668 - DEBUG - generation 3
# 2026-06-12 14:08:48,669 - DEBUG - number of events with aftershocks: 7
# 2026-06-12 14:08:48,677 - DEBUG - number of aftershocks: 7
# 2026-06-12 14:08:48,677 - DEBUG - their number of aftershocks should be:9
# 2026-06-12 14:08:48,678 - DEBUG - generation 4
# 2026-06-12 14:08:48,679 - DEBUG - number of events with aftershocks: 6
# 2026-06-12 14:08:48,687 - DEBUG - number of aftershocks: 3
# 2026-06-12 14:08:48,687 - DEBUG - their number of aftershocks should be:3
# 2026-06-12 14:08:48,688 - DEBUG - generation 5
# 2026-06-12 14:08:48,690 - DEBUG - number of events with aftershocks: 3
# 2026-06-12 14:08:48,697 - DEBUG - number of aftershocks: 2
# 2026-06-12 14:08:48,697 - DEBUG - their number of aftershocks should be:1
# 2026-06-12 14:08:48,698 - DEBUG - generation 6
# 2026-06-12 14:08:48,700 - DEBUG - number of events with aftershocks: 1
# 2026-06-12 14:08:48,707 - DEBUG - number of aftershocks: 0
# 2026-06-12 14:08:48,707 - DEBUG - their number of aftershocks should be:0
# 2026-06-12 14:08:48,708 - DEBUG - generation 7
# 2026-06-12 14:08:48,710 - DEBUG - number of events with aftershocks: 0
# 2026-06-12 14:08:48,713 - INFO -   number of background events needed: 49
# 2026-06-12 14:08:48,713 - INFO -   generating 100 to throw away those outside the polygon
# 2026-06-12 14:08:48,718 - DEBUG - number of induced events: 0
# 2026-06-12 14:08:48,720 - DEBUG - number of background events: 49
# 2026-06-12 14:08:48,720 - DEBUG - number of auxiliary events: 1
# 2026-06-12 14:08:48,720 - DEBUG - generation 0
# 2026-06-12 14:08:48,722 - DEBUG - number of events with aftershocks: 28
# 2026-06-12 14:08:48,730 - DEBUG - number of aftershocks: 31
# 2026-06-12 14:08:48,730 - DEBUG - their number of aftershocks should be:25
# 2026-06-12 14:08:48,731 - DEBUG - generation 1
# 2026-06-12 14:08:48,733 - DEBUG - number of events with aftershocks: 14
# 2026-06-12 14:08:48,740 - DEBUG - number of aftershocks: 17
# 2026-06-12 14:08:48,740 - DEBUG - their number of aftershocks should be:14
# 2026-06-12 14:08:48,741 - DEBUG - generation 2
# 2026-06-12 14:08:48,743 - DEBUG - number of events with aftershocks: 9
# 2026-06-12 14:08:48,750 - DEBUG - number of aftershocks: 9
# 2026-06-12 14:08:48,751 - DEBUG - their number of aftershocks should be:9
# 2026-06-12 14:08:48,751 - DEBUG - generation 3
# 2026-06-12 14:08:48,753 - DEBUG - number of events with aftershocks: 5
# 2026-06-12 14:08:48,760 - DEBUG - number of aftershocks: 8
# 2026-06-12 14:08:48,760 - DEBUG - their number of aftershocks should be:3
# 2026-06-12 14:08:48,761 - DEBUG - generation 4
# 2026-06-12 14:08:48,763 - DEBUG - number of events with aftershocks: 2
# 2026-06-12 14:08:48,770 - DEBUG - number of aftershocks: 1
# 2026-06-12 14:08:48,770 - DEBUG - their number of aftershocks should be:0
# 2026-06-12 14:08:48,771 - DEBUG - generation 5
# 2026-06-12 14:08:48,773 - DEBUG - number of events with aftershocks: 0
# 2026-06-12 14:08:48,776 - INFO -   number of background events needed: 41
# 2026-06-12 14:08:48,776 - INFO -   generating 83 to throw away those outside the polygon
# 2026-06-12 14:08:48,781 - DEBUG - number of induced events: 0
# 2026-06-12 14:08:48,783 - DEBUG - number of background events: 41
# 2026-06-12 14:08:48,783 - DEBUG - number of auxiliary events: 1
# 2026-06-12 14:08:48,783 - DEBUG - generation 0
# 2026-06-12 14:08:48,785 - DEBUG - number of events with aftershocks: 23
# 2026-06-12 14:08:48,792 - DEBUG - number of aftershocks: 24
# 2026-06-12 14:08:48,793 - DEBUG - their number of aftershocks should be:22
# 2026-06-12 14:08:48,794 - DEBUG - generation 1
# 2026-06-12 14:08:48,795 - DEBUG - number of events with aftershocks: 14
# 2026-06-12 14:08:48,803 - DEBUG - number of aftershocks: 14
# 2026-06-12 14:08:48,803 - DEBUG - their number of aftershocks should be:10
# 2026-06-12 14:08:48,804 - DEBUG - generation 2
# 2026-06-12 14:08:48,805 - DEBUG - number of events with aftershocks: 6
# 2026-06-12 14:08:48,813 - DEBUG - number of aftershocks: 3
# 2026-06-12 14:08:48,813 - DEBUG - their number of aftershocks should be:3
# 2026-06-12 14:08:48,814 - DEBUG - generation 3
# 2026-06-12 14:08:48,816 - DEBUG - number of events with aftershocks: 2
# 2026-06-12 14:08:48,823 - DEBUG - number of aftershocks: 2
# 2026-06-12 14:08:48,823 - DEBUG - their number of aftershocks should be:2
# 2026-06-12 14:08:48,824 - DEBUG - generation 4
# 2026-06-12 14:08:48,826 - DEBUG - number of events with aftershocks: 1
# 2026-06-12 14:08:48,833 - DEBUG - number of aftershocks: 1
# 2026-06-12 14:08:48,833 - DEBUG - their number of aftershocks should be:1
# 2026-06-12 14:08:48,834 - DEBUG - generation 5
# 2026-06-12 14:08:48,836 - DEBUG - number of events with aftershocks: 1
# 2026-06-12 14:08:48,843 - DEBUG - number of aftershocks: 0
# 2026-06-12 14:08:48,843 - DEBUG - their number of aftershocks should be:0
# 2026-06-12 14:08:48,844 - DEBUG - generation 6
# 2026-06-12 14:08:48,846 - DEBUG - number of events with aftershocks: 0
# Forecast from T=2006-12-29 00:00:00: 300 event(s) (300 recreations x 1)
# Saved forecast_recreations -> /home/neriberman/Repos/etas/outputs/single_point_history/forecast_recreations_n300_seed0.csv
#                              time   latitude   longitude  magnitude  \
# 0   2006-12-29 00:04:33.384782147  33.640841 -116.390571   4.446771
# 1   2006-12-29 00:01:27.373472342  33.606112 -116.410896   4.255075
# 2   2006-12-29 00:01:29.696643390  33.609112 -116.404300   4.140123
# 3   2006-12-29 00:02:25.783504304  33.614555 -116.365436   4.030258
# 4   2006-12-29 01:14:22.885729140  33.598656 -116.409180   3.517818
# ..                            ...        ...         ...        ...
# 295 2006-12-29 00:10:25.340096216  33.600474 -116.421650   3.822083
# 296 2006-12-29 00:02:15.993792533  33.581503 -116.383013   3.602714
# 297 2006-12-29 00:10:11.941070000  33.155218 -120.421250   4.735953
# 298 2006-12-29 00:05:17.068677685  33.611568 -116.388911   3.559736
# 299 2006-12-29 00:05:10.413012229  33.588980 -116.404720   3.822635
#
#      recreation  seed  event_idx
# 0             0     0          0
# 1             1     1          0
# 2             2     2          0
# 3             3     3          0
# 4             4     4          0
# ..          ...   ...        ...
# 295         295   295          0
# 296         296   296          0
# 297         297   297          0
# 298         298   298          0
# 299         299   299          0
#
# [300 rows x 7 columns]

# %%
fig_forecast, ax = plt.subplots(figsize=(12, 10))

poly_coords = np.asarray(polygon.exterior.coords)
lat_poly, lon_poly = poly_coords[:, 0], poly_coords[:, 1]
ax.plot(lon_poly, lat_poly, color="black", linewidth=2, label="Study region")

ax.scatter(
    [history_event_x],
    [history_event_y],
    s=120,
    c="magenta",
    marker="*",
    edgecolors="black",
    linewidths=0.5,
    zorder=6,
    label=f"History event (M={history_event_magnitude})",
)

ax.scatter(
    forecast_recreations["longitude"],
    forecast_recreations["latitude"],
    s=60,
    c=forecast_recreations["recreation"],
    cmap="tab20",
    edgecolors="black",
    linewidths=0.4,
    zorder=5,
    label="Forecast events",
)

for _, row in forecast_recreations.iterrows():
    ax.annotate(
        str(int(row["recreation"])),
        (row["longitude"], row["latitude"]),
        textcoords="offset points",
        xytext=(4, 4),
        fontsize=8,
    )

ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")
ax.set_title(f"First forecast event after T={FORECAST_START} ({N_RECREATIONS} recreations)")
ax.set_aspect("equal")
ax.set_xlim(np.min(lon_flat) - 0.2, np.max(lon_flat) + 0.2)
ax.set_ylim(np.min(lat_flat) - 0.2, np.max(lat_flat) + 0.2)
ax.legend(loc="upper right")
plt.show()

# %%
# Empirical rate per Voronoi cell from catalog-continuation recreations


def _polygon_parts(geom):
    if geom.is_empty:
        return
    if geom.geom_type == "Polygon":
        yield geom
    elif geom.geom_type == "MultiPolygon":
        yield from geom.geoms
    elif geom.geom_type == "GeometryCollection":
        for g in geom.geoms:
            yield from _polygon_parts(g)


def calculate_areas_km2(polygons):
    geod = pyproj.Geod(ellps="WGS84")
    areas = []
    for poly in polygons:
        if poly.is_empty:
            areas.append(0.0)
        else:
            area_m2, _ = geod.geometry_area_perimeter(poly)
            areas.append(abs(area_m2) / 1e6)
    return areas


sim_events = (
    forecast_recreations.sort_values(["recreation", "time"])
    .groupby("recreation", as_index=False)
    .head(N_FORECAST_EVENTS)
)

counts_per_cell = np.zeros(len(ordered_cells), dtype=int)
for lon, lat in zip(sim_events["longitude"].to_numpy(), sim_events["latitude"].to_numpy()):
    p = Point(lon, lat)
    for j, cell in enumerate(ordered_cells):
        if cell.contains(p):
            counts_per_cell[j] += 1
            break

cell_areas_km2 = np.array(calculate_areas_km2(ordered_cells), dtype=float)
forecast_days = float(INITIAL_FORECAST_DAYS)
n_realizations = int(sim_events["recreation"].nunique())

# events / km² / day
sim_rate_per_cell = np.zeros(len(ordered_cells), dtype=float)
valid = cell_areas_km2 > 0
sim_rate_per_cell[valid] = counts_per_cell[valid] / (
    # n_realizations * forecast_days * cell_areas_km2[valid]
    n_realizations * cell_areas_km2[valid]
)

print(
    f"Binned {len(sim_events)} simulated event(s) from {n_realizations} recreations "
    f"over {forecast_days:.0f} day forecast window."
)
print(
    f"Non-zero cells: {(counts_per_cell > 0).sum()} / {len(ordered_cells)}; "
    f"max count in one cell: {counts_per_cell.max()}"
)

fig_sim_rate, ax = plt.subplots(figsize=(12, 10))
positive_rates = sim_rate_per_cell[sim_rate_per_cell > 0]
rate_vmin = float(positive_rates.min()) if positive_rates.size else 1e-20
rate_vmax = float(max(sim_rate_per_cell.max(), rate_vmin * 10))
plot_rate = np.maximum(sim_rate_per_cell, rate_vmin)
norm = colors.LogNorm(vmin=rate_vmin, vmax=rate_vmax)
cmap = plt.cm.viridis

for j, cell in enumerate(ordered_cells):
    color = cmap(norm(plot_rate[j]))
    for part in _polygon_parts(cell):
        xy = np.asarray(part.exterior.coords)
        ax.add_patch(
            mpatches.Polygon(
                xy,
                closed=True,
                facecolor=color,
                edgecolor="k",
                alpha=0.8,
                linewidth=0.4,
            )
        )

poly_coords = np.asarray(polygon.exterior.coords)
lat_poly, lon_poly = poly_coords[:, 0], poly_coords[:, 1]
ax.plot(lon_poly, lat_poly, color="black", linewidth=2, label="Study region")
ax.scatter(lon_flat, lat_flat, s=8, c="red", zorder=5, label="Grid nodes")
ax.scatter(
    [history_event_x],
    [history_event_y],
    s=120,
    c="magenta",
    marker="*",
    edgecolors="black",
    linewidths=0.5,
    zorder=6,
    label=f"History event (M={history_event_magnitude})",
)

sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
cbar = plt.colorbar(sm, ax=ax, shrink=0.8, pad=0.03)
cbar.set_label("Simulated rate (events / km² / day)")

ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")
ax.set_title(
    f"Simulated rate by Voronoi cell "
    f"({n_realizations} recreations, {forecast_days:.0f} day window)"
)
ax.set_aspect("equal")
ax.set_xlim(np.min(lon_flat) - 0.2, np.max(lon_flat) + 0.2)
ax.set_ylim(np.min(lat_flat) - 0.2, np.max(lat_flat) + 0.2)
ax.legend(loc="upper right")
plt.show()
# Out:
# Binned 300 simulated event(s) from 300 recreations over 30 day forecast window.
# Non-zero cells: 28 / 494; max count in one cell: 253
# 2026-06-12 14:08:53,190 - DEBUG - locator: <matplotlib.ticker.LogLocator object at 0x761b1fde7e90>
# 2026-06-12 14:08:53,565 - DEBUG - vmin 1.298910456750252e-06 vmax 0.00042638905670247903
# 2026-06-12 14:08:53,565 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-12 14:08:53,568 - DEBUG - vmin 1.298910456750252e-06 vmax 0.00042638905670247903
# 2026-06-12 14:08:53,568 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02])
# 2026-06-12 14:08:53,569 - DEBUG - vmin 1.298910456750252e-06 vmax 0.00042638905670247903
# 2026-06-12 14:08:53,569 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-12 14:08:53,593 - DEBUG - vmin 1.298910456750252e-06 vmax 0.00042638905670247903
# 2026-06-12 14:08:53,594 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-12 14:08:53,594 - DEBUG - vmin 1.298910456750252e-06 vmax 0.00042638905670247903
# 2026-06-12 14:08:53,594 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02])
# 2026-06-12 14:08:53,595 - DEBUG - vmin 1.298910456750252e-06 vmax 0.00042638905670247903
# 2026-06-12 14:08:53,595 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-12 14:08:53,597 - DEBUG - vmin 1.298910456750252e-06 vmax 0.00042638905670247903
# 2026-06-12 14:08:53,597 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-12 14:08:53,597 - DEBUG - vmin 1.298910456750252e-06 vmax 0.00042638905670247903
# 2026-06-12 14:08:53,597 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02])
# 2026-06-12 14:08:53,598 - DEBUG - vmin 1.298910456750252e-06 vmax 0.00042638905670247903
# 2026-06-12 14:08:53,598 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-12 14:08:53,660 - DEBUG - vmin 1.298910456750252e-06 vmax 0.00042638905670247903
# 2026-06-12 14:08:53,661 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-12 14:08:53,661 - DEBUG - vmin 1.298910456750252e-06 vmax 0.00042638905670247903
# 2026-06-12 14:08:53,661 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02])
# 2026-06-12 14:08:53,662 - DEBUG - vmin 1.298910456750252e-06 vmax 0.00042638905670247903
# 2026-06-12 14:08:53,662 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-12 14:08:53,663 - DEBUG - vmin 1.298910456750252e-06 vmax 0.00042638905670247903
# 2026-06-12 14:08:53,663 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-12 14:08:53,663 - DEBUG - vmin 1.298910456750252e-06 vmax 0.00042638905670247903
# 2026-06-12 14:08:53,664 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02])
# 2026-06-12 14:08:53,664 - DEBUG - vmin 1.298910456750252e-06 vmax 0.00042638905670247903
# 2026-06-12 14:08:53,664 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-12 14:08:53,666 - DEBUG - vmin 1.298910456750252e-06 vmax 0.00042638905670247903
# 2026-06-12 14:08:53,667 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-12 14:08:53,667 - DEBUG - vmin 1.298910456750252e-06 vmax 0.00042638905670247903
# 2026-06-12 14:08:53,667 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02])
# 2026-06-12 14:08:53,667 - DEBUG - vmin 1.298910456750252e-06 vmax 0.00042638905670247903
# 2026-06-12 14:08:53,668 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-12 14:08:53,716 - DEBUG - vmin 1.298910456750252e-06 vmax 0.00042638905670247903
# 2026-06-12 14:08:53,717 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-12 14:08:53,717 - DEBUG - vmin 1.298910456750252e-06 vmax 0.00042638905670247903
# 2026-06-12 14:08:53,717 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02])
# 2026-06-12 14:08:53,718 - DEBUG - vmin 1.298910456750252e-06 vmax 0.00042638905670247903
# 2026-06-12 14:08:53,718 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-12 14:08:53,726 - DEBUG - vmin 1.298910456750252e-06 vmax 0.00042638905670247903
# 2026-06-12 14:08:53,727 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-12 14:08:53,727 - DEBUG - vmin 1.298910456750252e-06 vmax 0.00042638905670247903
# 2026-06-12 14:08:53,727 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02])
# 2026-06-12 14:08:53,728 - DEBUG - vmin 1.298910456750252e-06 vmax 0.00042638905670247903
# 2026-06-12 14:08:53,728 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-12 14:08:53,730 - DEBUG - vmin 1.298910456750252e-06 vmax 0.00042638905670247903
# 2026-06-12 14:08:53,730 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-12 14:08:53,730 - DEBUG - vmin 1.298910456750252e-06 vmax 0.00042638905670247903
# 2026-06-12 14:08:53,731 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02])
# 2026-06-12 14:08:53,731 - DEBUG - vmin 1.298910456750252e-06 vmax 0.00042638905670247903
# 2026-06-12 14:08:53,731 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])

# %%
# Time to first forecast event — same style as grid_recreations_point_process.ipynb Step 5
FIRST_EVENT_IDX = 0
SECONDS_PER_DAY = 86400.0

t0 = pd.to_datetime(FORECAST_START, utc=True)

df_rec = forecast_recreations.loc[
    forecast_recreations["event_idx"] == FIRST_EVENT_IDX
].copy()
df_rec["time"] = pd.to_datetime(df_rec["time"], utc=True)
df_rec = df_rec.sort_values(["recreation", "time"]).reset_index(drop=True)
df_rec["t_from_start_days"] = (df_rec["time"] - t0).dt.total_seconds() / SECONDS_PER_DAY

dt_to_first = df_rec.loc[df_rec["t_from_start_days"] > 0, "t_from_start_days"].to_numpy()

print(
    f"Recreations: {df_rec['recreation'].nunique()}, "
    f"first events (event_idx={FIRST_EVENT_IDX}): {len(df_rec)}"
)
if np.any(dt_to_first > 0):
    q = np.quantile(dt_to_first, [0.05, 0.5, 0.95])
    print(f"Time to first event (days): median={q[1]:.3f}, 5-95%={q[0]:.3f}-{q[2]:.3f}")

fig_delta_t, ax = plt.subplots(figsize=(6, 4.5))
if len(dt_to_first):
    bins_dt = np.logspace(
        np.log10(dt_to_first.min()),
        np.log10(dt_to_first.max() * 1.01),
        40,
    )
    ax.hist(
        dt_to_first,
        bins=bins_dt,
        color="tab:orange",
        alpha=0.85,
        edgecolor="white",
        linewidth=0.4,
    )
    ax.set_xscale("log")
ax.set_xlabel("Time since forecast start (days, log)")
ax.set_ylabel("Count")
ax.set_title("Time to first event (log-spaced bins)")
ax.grid(True, alpha=0.25)

fig_delta_t.tight_layout()
plt.show()

pd.Series(dt_to_first).describe()
# Out:
# Recreations: 300, first events (event_idx=0): 300
# Time to first event (days): median=0.006, 5-95%=0.000-0.201
# 2026-06-12 14:08:53,875 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,875 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-12 14:08:53,879 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,879 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-12 14:08:53,880 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,880 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-12 14:08:53,910 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,910 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-12 14:08:53,911 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,911 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-12 14:08:53,911 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,912 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-12 14:08:53,931 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,931 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-12 14:08:53,932 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,932 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-12 14:08:53,933 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,933 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-12 14:08:53,947 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,947 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-12 14:08:53,948 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,948 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-12 14:08:53,948 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,949 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-12 14:08:53,951 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,951 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-12 14:08:53,951 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,951 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-12 14:08:53,952 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,952 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-12 14:08:53,959 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,960 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-12 14:08:53,960 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,960 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-12 14:08:53,961 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,961 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-12 14:08:53,968 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,968 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-12 14:08:53,968 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,969 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-12 14:08:53,969 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,969 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-12 14:08:53,972 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,973 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-12 14:08:53,973 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,973 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-12 14:08:53,974 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,974 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-12 14:08:53,980 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,980 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-12 14:08:53,981 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,981 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-12 14:08:53,982 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,982 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-12 14:08:53,983 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,984 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-12 14:08:53,984 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,984 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-12 14:08:53,985 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,985 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-12 14:08:53,988 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,988 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-12 14:08:53,988 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,989 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-12 14:08:53,989 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,989 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-12 14:08:53,999 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:53,999 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-12 14:08:54,000 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:54,000 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-12 14:08:54,001 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:54,001 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-12 14:08:54,003 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:54,003 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-12 14:08:54,003 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:54,003 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-12 14:08:54,004 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:54,004 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-12 14:08:54,015 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:54,015 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-12 14:08:54,015 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:54,016 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-12 14:08:54,016 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:54,017 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-12 14:08:54,040 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:54,040 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-12 14:08:54,041 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:54,041 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-12 14:08:54,042 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:54,042 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-12 14:08:54,045 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:54,045 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-12 14:08:54,046 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:54,046 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-12 14:08:54,047 - DEBUG - vmin 8.852170305655223e-06 vmax 3.1067772182548787
# 2026-06-12 14:08:54,047 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# count    300.000000
# mean       0.041075
# std        0.133879
# min        0.000016
# 25%        0.001472
# 50%        0.005623
# 75%        0.020616
# max        1.721597
# dtype: float64

# %%
bins_dt = np.linspace(
        dt_to_first.min(),
        dt_to_first.max() * 1.01,
        40,
    )
    
hist, bins = np.histogram(
    dt_to_first,
    bins=bins_dt,
)

# CDF
cdf = np.cumsum(hist)
cdf = cdf / cdf[-1]

fig_cdf, ax = plt.subplots(figsize=(6, 4.5))
ax.plot(bins[:-1], cdf, color="tab:orange", linewidth=2)
ax.set_xlabel("Time since forecast start (days)")
ax.set_ylabel("CDF")
ax.set_title("CDF of time to first event")
# Out:
# Text(0.5, 1.0, 'CDF of time to first event')

# %% [markdown]
# # Simulate times on the grid

# %%
# def rhs(t_prime, t, H, params):
#     t_h = H['t']
#     rhs = np.exp(-params['mu'] * (t_prime - t)) * np.exp(
#         A_h(H['x'], H['y'], H, params) * (
#             np.exp(params["c"]/params["tau"]) / params['tau']**(-params['omega'])
#             ) * (
#                 unreg_gamma(-params['omega'], (params['c'] + t_prime - t_h) / params['tau']) -
#                 unreg_gamma(-params['omega'], (params['c'] + t - t_h) / params['tau'])
#                 )
#         )
#     return rhs

def solve_next_event_time_per_cell(U: float, t: float, target_polygon: Polygon, H: History, params: EtasParams, resolution: int = 50):
    """
    Solves for t_prime using the log-space RHS and Brent's method.
    """
    target_val = np.log(U)
    
    def residual(t_prime):
        return log_rhs(t_prime, t, target_polygon, H, params, resolution) - target_val

    # Dynamic bracketing
    upper_bound = t + 1.0
    while residual(upper_bound) > 0:
        upper_bound = t + (upper_bound - t) * 2.0
        
    sol = root_scalar(residual, bracket=[t, upper_bound], method='brentq')
    return sol.root

# %%
## create a single realization of the point process
def create_single_realization(
    rng: np.random.RandomState,
    history_dict: History,
    ordered_cells: list[Polygon],
    lon_flat: np.ndarray,
    lat_flat: np.ndarray,
    epsilon: float,
    resolution: int = 50,
) -> dict:
    ordered_event_times = []
    for cell in ordered_cells:
        U = rng.uniform()
        t_prime = solve_next_event_time_per_cell(
            U, history_dict["t"] + epsilon, cell, history_dict, THETA_0, resolution
        )
        ordered_event_times.append(t_prime)

    min_index = int(np.argmin(ordered_event_times))
    min_event_time = ordered_event_times[min_index]
    magnitude = mc_b_est.simulate_magnitudes(1, BETA_MAIN, MC)[0]

    return {
        "time": min_event_time,
        "magnitude": magnitude,
        "longitude": float(lon_flat[min_index]),
        "latitude": float(lat_flat[min_index]),
        "cell_idx": min_index,
    }

# %%
# n_recreations = N_RECREATIONS
# # n_recreations = 20
# RESOLUTION = 50
# rngseed = 1905
# recreations_df = pd.DataFrame()
# rng = np.random.RandomState(rngseed)
# for i in tqdm(range(n_recreations)):
#     # U = rng.uniform()
#     event_dict = create_single_realization(rng, history_dict, ordered_cells, lon_flat, lat_flat, RESOLUTION)
#     recreations_df = pd.concat([recreations_df, pd.DataFrame([event_dict])], ignore_index=True)
#     rngseed += 1
#     rng = np.random.RandomState(rngseed)
# recreations_df

# %%
# epsilon_vec = np.concatenate([np.array([0]), 10**np.arange(-4, 4, 2, dtype=float)])
epsilon_vec = np.array([0])
n_recreations = N_RECREATIONS
# n_recreations = 100

_grid_canonical = grid_recreations_epsilon_path(n_recreations, A_H_RESOLUTION)
_grid_load_path = None if FORCE_RECREATE_RECREATIONS else _resolve_saved_csv(
    SAVED_GRID_RECREATIONS_PATH,
    _grid_canonical,
)

_grid_loaded = False
recreations_epsilon = {}
wanted_eps = [float(e) for e in epsilon_vec]

if not FORCE_RECREATE_RECREATIONS and _grid_load_path is not None:
    _candidate = load_recreations_epsilon_csv(_grid_load_path)
    loaded_eps = sorted(_candidate.keys())
    nrow_ok = all(len(_candidate[e]) == n_recreations for e in _candidate)
    if loaded_eps == wanted_eps and nrow_ok:
        print(f"Loading recreations_epsilon from {_grid_load_path}")
        recreations_epsilon = _candidate
        _grid_loaded = True
    elif loaded_eps != wanted_eps:
        print(
            f"Saved epsilons {loaded_eps} != epsilon_vec {wanted_eps}; re-simulating."
        )
    else:
        print(
            f"Saved row count != n_recreations={n_recreations}; re-simulating."
        )

if not _grid_loaded:
    if FORCE_RECREATE_RECREATIONS:
        print("FORCE_RECREATE_RECREATIONS=True: simulating grid point-process recreations...")
    else:
        _note_stale_saved_csvs(
            "grid_recreations_epsilon_n*_res*.csv",
            _grid_canonical,
        )
        if _grid_load_path is None:
            print(
                f"No saved recreations_epsilon for current settings "
                f"({_grid_canonical.name}); simulating..."
            )

    epsilon_pbar = tqdm(
        epsilon_vec,
        desc="Epsilon",
        position=0,
        unit="eps",
        dynamic_ncols=True,
    )

    for epsilon in epsilon_pbar:
        epsilon_pbar.set_postfix_str(f"ε={epsilon:g}")

        rngseed = 1905
        records = []
        rng = np.random.RandomState(rngseed)

        for i in tqdm(
            range(n_recreations),
            desc="Recreations",
            position=1,
            leave=False,
            unit="run",
            dynamic_ncols=True,
        ):
            event_dict = create_single_realization(
                rng,
                history_dict,
                ordered_cells,
                lon_flat,
                lat_flat,
                epsilon,
                A_H_RESOLUTION,
            )
            records.append(event_dict)
            rngseed += 1
            rng = np.random.RandomState(rngseed)

        recreations_epsilon[epsilon] = pd.DataFrame.from_records(records)

if SAVE_RECREATIONS_OUTPUT and not _grid_loaded:
    RECREATIONS_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
    recreations_epsilon_df = pd.concat(
        [df.assign(epsilon=float(eps)) for eps, df in recreations_epsilon.items()],
        ignore_index=True,
    )
    recreations_epsilon_df.to_csv(_grid_canonical, index=False)
    print(f"Saved recreations_epsilon -> {_grid_canonical}")

recreations_epsilon
# Out:
# Note: found 3 saved CSV(s) with other parameters (grid_recreations_epsilon_n1000_res120.csv, grid_recreations_epsilon_n1000_res40.csv, grid_recreations_epsilon_n1000_res80.csv); need grid_recreations_epsilon_n300_res400.csv for current settings.
# No saved recreations_epsilon for current settings (grid_recreations_epsilon_n300_res400.csv); simulating...
# Epsilon:   0%|          | 0/1 [00:00<?, ?eps/s]
# Recreations:   0%|          | 0/300 [00:00<?, ?run/s]

# %%
# Re-run this cell to write CSVs from in-memory results (no re-simulation).
if "RECREATIONS_OUTPUT_DIR" not in globals():
    from pathlib import Path

    REPO_ROOT = Path.cwd().resolve()
    if REPO_ROOT.name == "notebooks":
        REPO_ROOT = REPO_ROOT.parent
    RECREATIONS_OUTPUT_DIR = REPO_ROOT / "outputs" / "single_point_history"
    SAVE_RECREATIONS_OUTPUT = True

if not SAVE_RECREATIONS_OUTPUT:
    print("SAVE_RECREATIONS_OUTPUT is False; nothing written.")
else:
    RECREATIONS_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
    saved = []

    if "forecast_recreations" in globals() and len(forecast_recreations):
        path = forecast_recreations_path()
        forecast_recreations.to_csv(path, index=False)
        saved.append(str(path))

    if "recreations_epsilon" in globals() and recreations_epsilon:
        n_rec = len(next(iter(recreations_epsilon.values())))
        path = grid_recreations_epsilon_path(n_rec, A_H_RESOLUTION)
        recreations_epsilon_df = pd.concat(
            [df.assign(epsilon=float(eps)) for eps, df in recreations_epsilon.items()],
            ignore_index=True,
        )
        recreations_epsilon_df.to_csv(path, index=False)
        saved.append(str(path))

    if saved:
        print("Saved:")
        for path in saved:
            print(f"  {path}")
    else:
        print("No forecast_recreations or recreations_epsilon in memory.")
# Out:
# Saved:
#   /home/neriberman/Repos/etas/outputs/single_point_history/forecast_recreations_n1000_seed0.csv
#   /home/neriberman/Repos/etas/outputs/single_point_history/grid_recreations_epsilon_n1000_res120.csv

# %%
# Empirical rate per Voronoi cell for each epsilon in recreations_epsilon

if "_polygon_parts" not in globals():
    def _polygon_parts(geom):
        if geom.is_empty:
            return
        if geom.geom_type == "Polygon":
            yield geom
        elif geom.geom_type == "MultiPolygon":
            yield from geom.geoms
        elif geom.geom_type == "GeometryCollection":
            for g in geom.geoms:
                yield from _polygon_parts(g)

if "calculate_areas_km2" not in globals():
    def calculate_areas_km2(polygons):
        geod = pyproj.Geod(ellps="WGS84")
        areas = []
        for poly in polygons:
            if poly.is_empty:
                areas.append(0.0)
            else:
                area_m2, _ = geod.geometry_area_perimeter(poly)
                areas.append(abs(area_m2) / 1e6)
        return areas

if "cell_areas_km2" not in globals():
    cell_areas_km2 = np.array(calculate_areas_km2(ordered_cells), dtype=float)

poly_coords = np.asarray(polygon.exterior.coords)
lat_poly, lon_poly = poly_coords[:, 0], poly_coords[:, 1]
xlim = (np.min(lon_flat) - 0.2, np.max(lon_flat) + 0.2)
ylim = (np.min(lat_flat) - 0.2, np.max(lat_flat) + 0.2)


def _bin_events_to_cells(pp_events):
    counts = np.zeros(len(ordered_cells), dtype=int)
    if "cell_idx" in pp_events.columns:
        for idx in pp_events["cell_idx"].astype(int).to_numpy():
            counts[idx] += 1
    else:
        for lon, lat in zip(pp_events["longitude"].to_numpy(), pp_events["latitude"].to_numpy()):
            j = int(np.argmin((lon_flat - lon) ** 2 + (lat_flat - lat) ** 2))
            counts[j] += 1
    return counts


def _counts_to_rate(counts, n_realizations):
    rate = np.zeros(len(ordered_cells), dtype=float)
    valid = cell_areas_km2 > 0
    rate[valid] = counts[valid] / (n_realizations * cell_areas_km2[valid])
    return rate


def _draw_rate_map(ax, pp_events, counts, rate, *, title):
    occupied = counts > 0
    if not occupied.any():
        ax.text(0.5, 0.5, "No events binned", ha="center", va="center", transform=ax.transAxes)
        ax.set_title(title)
        return

    plot_rate = np.maximum(rate, rate_vmin)
    for j, cell in enumerate(ordered_cells):
        if occupied[j]:
            facecolor = cmap(norm(plot_rate[j]))
            edge_lw = 0.4
            alpha = 0.8
        else:
            facecolor = "#f0f0f0"
            edge_lw = 0.2
            alpha = 0.5
        for part in _polygon_parts(cell):
            xy = np.asarray(part.exterior.coords)
            ax.add_patch(
                mpatches.Polygon(
                    xy,
                    closed=True,
                    facecolor=facecolor,
                    edgecolor="k",
                    alpha=alpha,
                    linewidth=edge_lw,
                )
            )

    ax.plot(lon_poly, lat_poly, color="black", linewidth=1.5)
    ax.scatter(
        pp_events["longitude"],
        pp_events["latitude"],
        s=18,
        c="white",
        edgecolors="black",
        linewidths=0.4,
        alpha=0.9,
        zorder=7,
    )
    ax.scatter(
        [history_event_x],
        [history_event_y],
        s=80,
        c="magenta",
        marker="*",
        edgecolors="black",
        linewidths=0.5,
        zorder=8,
    )
    ax.set_title(title)
    ax.set_aspect("equal")
    ax.set_xlim(*xlim)
    ax.set_ylim(*ylim)


epsilons = list(epsilon_vec) if "epsilon_vec" in globals() else sorted(recreations_epsilon.keys(), key=float)
epsilons = [eps for eps in epsilons if eps in recreations_epsilon]
if not epsilons:
    epsilons = sorted(recreations_epsilon.keys(), key=float)

rates_by_eps = {}
all_positive = []
for eps in epsilons:
    pp_events = recreations_epsilon[eps]
    counts = _bin_events_to_cells(pp_events)
    n_realizations_pp = len(pp_events)
    rate_per_cell = _counts_to_rate(counts, n_realizations_pp)
    rates_by_eps[eps] = (pp_events, counts, rate_per_cell, n_realizations_pp)
    positive = rate_per_cell[counts > 0]
    if positive.size:
        all_positive.append(positive)

if not all_positive:
    raise ValueError("No events were assigned to any Voronoi cell.")

rate_vmin = float(np.min(np.concatenate(all_positive)))
rate_vmax = float(np.max(np.concatenate(all_positive)))
if rate_vmin == rate_vmax:
    rate_vmax = rate_vmin * 10.0
norm = colors.LogNorm(vmin=rate_vmin, vmax=rate_vmax)
cmap = plt.cm.viridis

n_eps = len(epsilons)
ncols = min(3, n_eps)
nrows = int(np.ceil(n_eps / ncols))
fig, axes = plt.subplots(nrows, ncols, figsize=(5.5 * ncols, 5 * nrows), squeeze=False)

for idx, eps in enumerate(epsilons):
    ax = axes[idx // ncols, idx % ncols]
    pp_events, counts, rate_per_cell, n_realizations_pp = rates_by_eps[eps]
    _draw_rate_map(
        ax,
        pp_events,
        counts,
        rate_per_cell,
        title=f"ε = {eps:g} ({n_realizations_pp} recreations)",
    )
    print(
        f"ε={eps:g}: binned {len(pp_events)} events; "
        f"non-zero cells {(counts > 0).sum()}/{len(ordered_cells)}; "
        f"max count {counts.max()}"
    )

for idx in range(n_eps, nrows * ncols):
    axes[idx // ncols, idx % ncols].axis("off")

fig.subplots_adjust(right=0.9, hspace=0.25, wspace=0.15)
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
cbar = fig.colorbar(sm, ax=axes.ravel().tolist(), shrink=0.85, pad=0.02)
cbar.set_label("Empirical rate (events / km²)")
fig.suptitle("Point-process empirical rate by Voronoi cell", y=1.02)
plt.show()
# Out:
# ε=0: binned 1000 events; non-zero cells 99/494; max count 790
# 2026-06-11 19:45:36,643 - DEBUG - locator: <matplotlib.ticker.LogLocator object at 0x74e32051aad0>
# 2026-06-11 19:45:36,670 - DEBUG - vmin 3.389111106479038e-07 vmax 0.00039942374086358715
# 2026-06-11 19:45:36,670 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-11 19:45:36,673 - DEBUG - vmin 3.389111106479038e-07 vmax 0.00039942374086358715
# 2026-06-11 19:45:36,673 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02])
# 2026-06-11 19:45:36,674 - DEBUG - vmin 3.389111106479038e-07 vmax 0.00039942374086358715
# 2026-06-11 19:45:36,674 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-11 19:45:36,707 - DEBUG - vmin 3.389111106479038e-07 vmax 0.00039942374086358715
# 2026-06-11 19:45:36,708 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-11 19:45:36,708 - DEBUG - vmin 3.389111106479038e-07 vmax 0.00039942374086358715
# 2026-06-11 19:45:36,708 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02])
# 2026-06-11 19:45:36,709 - DEBUG - vmin 3.389111106479038e-07 vmax 0.00039942374086358715
# 2026-06-11 19:45:36,709 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-11 19:45:36,711 - DEBUG - vmin 3.389111106479038e-07 vmax 0.00039942374086358715
# 2026-06-11 19:45:36,711 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-11 19:45:36,712 - DEBUG - vmin 3.389111106479038e-07 vmax 0.00039942374086358715
# 2026-06-11 19:45:36,712 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02])
# 2026-06-11 19:45:36,713 - DEBUG - vmin 3.389111106479038e-07 vmax 0.00039942374086358715
# 2026-06-11 19:45:36,713 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-11 19:45:36,735 - DEBUG - vmin 3.389111106479038e-07 vmax 0.00039942374086358715
# 2026-06-11 19:45:36,735 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-11 19:45:36,735 - DEBUG - vmin 3.389111106479038e-07 vmax 0.00039942374086358715
# 2026-06-11 19:45:36,735 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02])
# 2026-06-11 19:45:36,736 - DEBUG - vmin 3.389111106479038e-07 vmax 0.00039942374086358715
# 2026-06-11 19:45:36,736 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-11 19:45:36,737 - DEBUG - vmin 3.389111106479038e-07 vmax 0.00039942374086358715
# 2026-06-11 19:45:36,738 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-11 19:45:36,738 - DEBUG - vmin 3.389111106479038e-07 vmax 0.00039942374086358715
# 2026-06-11 19:45:36,738 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02])
# 2026-06-11 19:45:36,739 - DEBUG - vmin 3.389111106479038e-07 vmax 0.00039942374086358715
# 2026-06-11 19:45:36,739 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-11 19:45:36,741 - DEBUG - vmin 3.389111106479038e-07 vmax 0.00039942374086358715
# 2026-06-11 19:45:36,741 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-11 19:45:36,741 - DEBUG - vmin 3.389111106479038e-07 vmax 0.00039942374086358715
# 2026-06-11 19:45:36,742 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02])
# 2026-06-11 19:45:36,742 - DEBUG - vmin 3.389111106479038e-07 vmax 0.00039942374086358715
# 2026-06-11 19:45:36,742 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-11 19:45:36,780 - DEBUG - vmin 3.389111106479038e-07 vmax 0.00039942374086358715
# 2026-06-11 19:45:36,781 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-11 19:45:36,781 - DEBUG - vmin 3.389111106479038e-07 vmax 0.00039942374086358715
# 2026-06-11 19:45:36,781 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02])
# 2026-06-11 19:45:36,782 - DEBUG - vmin 3.389111106479038e-07 vmax 0.00039942374086358715
# 2026-06-11 19:45:36,782 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-11 19:45:36,794 - DEBUG - vmin 3.389111106479038e-07 vmax 0.00039942374086358715
# 2026-06-11 19:45:36,794 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-11 19:45:36,795 - DEBUG - vmin 3.389111106479038e-07 vmax 0.00039942374086358715
# 2026-06-11 19:45:36,795 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02])
# 2026-06-11 19:45:36,796 - DEBUG - vmin 3.389111106479038e-07 vmax 0.00039942374086358715
# 2026-06-11 19:45:36,796 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-11 19:45:36,798 - DEBUG - vmin 3.389111106479038e-07 vmax 0.00039942374086358715
# 2026-06-11 19:45:36,798 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])
# 2026-06-11 19:45:36,798 - DEBUG - vmin 3.389111106479038e-07 vmax 0.00039942374086358715
# 2026-06-11 19:45:36,799 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02])
# 2026-06-11 19:45:36,799 - DEBUG - vmin 3.389111106479038e-07 vmax 0.00039942374086358715
# 2026-06-11 19:45:36,799 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02])

# %% [markdown]
# ### Spatial rate comparison by Voronoi cell
#
# Side-by-side maps at \(T_h + \varepsilon\) (default: first value in `epsilon_vec`):
#
# - **Classic ETAS (C)**: empirical density of first simulated event per recreation
# - **Grid point process (B)**: empirical density from `recreations_epsilon`
# - **Analytical (A)**: \(\lambda(x,y,t)=\mu + a_h(x,y)\,g(t)\) at each grid node / cell

# %%
# Side-by-side: classic sim vs grid PP vs analytical rate by Voronoi cell
if "_polygon_parts" not in globals():
    def _polygon_parts(geom):
        if geom.is_empty:
            return
        if geom.geom_type == "Polygon":
            yield geom
        elif geom.geom_type == "MultiPolygon":
            yield from geom.geoms
        elif geom.geom_type == "GeometryCollection":
            for g in geom.geoms:
                yield from _polygon_parts(g)

if "calculate_areas_km2" not in globals():
    def calculate_areas_km2(polygons):
        geod = pyproj.Geod(ellps="WGS84")
        areas = []
        for poly in polygons:
            if poly.is_empty:
                areas.append(0.0)
            else:
                area_m2, _ = geod.geometry_area_perimeter(poly)
                areas.append(abs(area_m2) / 1e6)
        return areas

if "cell_areas_km2" not in globals():
    cell_areas_km2 = np.array(calculate_areas_km2(ordered_cells), dtype=float)

poly_coords = np.asarray(polygon.exterior.coords)
lat_poly, lon_poly = poly_coords[:, 0], poly_coords[:, 1]
xlim = (np.min(lon_flat) - 0.2, np.max(lon_flat) + 0.2)
ylim = (np.min(lat_flat) - 0.2, np.max(lat_flat) + 0.2)

eps_compare = float(epsilon_vec[0]) if "epsilon_vec" in globals() else 0.0
history_t_days = float(history_dict["t"])
t_eval_rate = history_t_days + eps_compare


def _bin_lonlat_to_cells(lons, lats):
    counts = np.zeros(len(ordered_cells), dtype=int)
    for lon, lat in zip(np.asarray(lons, dtype=float), np.asarray(lats, dtype=float)):
        p = Point(lon, lat)
        for j, cell in enumerate(ordered_cells):
            if cell.contains(p):
                counts[j] += 1
                break
    return counts


def _empirical_rate_from_counts(counts, n_realizations):
    rate = np.zeros(len(ordered_cells), dtype=float)
    valid = cell_areas_km2 > 0
    rate[valid] = counts[valid] / (float(n_realizations) * cell_areas_km2[valid])
    return rate


# --- C: classic ETAS first-event locations ---
sim_events = (
    forecast_recreations.sort_values(["recreation", "time"])
    .groupby("recreation", as_index=False)
    .head(N_FORECAST_EVENTS)
)
sim_counts = _bin_lonlat_to_cells(
    sim_events["longitude"].to_numpy(), sim_events["latitude"].to_numpy()
)
n_sim = int(sim_events["recreation"].nunique())
sim_rate_per_cell = _empirical_rate_from_counts(sim_counts, n_sim)

# --- B: grid point-process recreations ---
if eps_compare not in recreations_epsilon:
    raise KeyError(f"epsilon {eps_compare} not in recreations_epsilon; run grid recreations first.")
pp_events = recreations_epsilon[eps_compare]
if "cell_idx" in pp_events.columns:
    pp_counts = np.zeros(len(ordered_cells), dtype=int)
    for idx in pp_events["cell_idx"].astype(int).to_numpy():
        pp_counts[idx] += 1
else:
    pp_counts = _bin_lonlat_to_cells(
        pp_events["longitude"].to_numpy(), pp_events["latitude"].to_numpy()
    )
n_pp = len(pp_events)
pp_rate_per_cell = _empirical_rate_from_counts(pp_counts, n_pp)

# --- A: analytical intensity at grid nodes (one per Voronoi cell) ---
analytical_rate_per_cell = etas_rate_at_xy(
    lon_flat, lat_flat, t_eval_rate, history_dict, THETA_0
)
analytical_rate_per_cell = np.asarray(analytical_rate_per_cell, dtype=float)


def _draw_rate_panel(ax, rate_per_cell, *, title, counts=None):
    """Fill Voronoi cells with log-scaled rate; optional counts mask for empirical maps."""
    if counts is None:
        occupied = rate_per_cell > 0
    else:
        occupied = counts > 0

    plot_vals = np.maximum(rate_per_cell, rate_vmin)
    for j, cell in enumerate(ordered_cells):
        if occupied[j]:
            facecolor = cmap(norm(plot_vals[j]))
            alpha = 0.85
            lw = 0.4
        else:
            facecolor = "#f0f0f0"
            alpha = 0.45
            lw = 0.2
        for part in _polygon_parts(cell):
            xy = np.asarray(part.exterior.coords)
            ax.add_patch(
                mpatches.Polygon(
                    xy,
                    closed=True,
                    facecolor=facecolor,
                    edgecolor="k",
                    alpha=alpha,
                    linewidth=lw,
                )
            )

    ax.plot(lon_poly, lat_poly, color="black", linewidth=1.5)
    ax.scatter(
        [history_event_x],
        [history_event_y],
        s=90,
        c="magenta",
        marker="*",
        edgecolors="black",
        linewidths=0.5,
        zorder=8,
    )
    ax.set_title(title)
    ax.set_aspect("equal")
    ax.set_xlim(*xlim)
    ax.set_ylim(*ylim)
    ax.set_xlabel("Longitude")
    ax.set_ylabel("Latitude")


positive_all = np.concatenate(
    [
        sim_rate_per_cell[sim_rate_per_cell > 0],
        pp_rate_per_cell[pp_rate_per_cell > 0],
        analytical_rate_per_cell[analytical_rate_per_cell > 0],
    ]
)
if positive_all.size == 0:
    raise ValueError("All rate maps are zero; check upstream recreations.")
rate_vmin = float(positive_all.min())
rate_vmax = float(positive_all.max())
if rate_vmin == rate_vmax:
    rate_vmax = rate_vmin * 10.0
norm = colors.LogNorm(vmin=rate_vmin, vmax=rate_vmax)
cmap = plt.cm.viridis

fig, axes = plt.subplots(1, 3, figsize=(18, 6), constrained_layout=True)

_draw_rate_panel(
    axes[0],
    sim_rate_per_cell,
    title=f"C: classic ETAS\n({n_sim} recreations)",
    counts=sim_counts,
)
_draw_rate_panel(
    axes[1],
    pp_rate_per_cell,
    title=f"B: grid point process (ε={eps_compare:g})\n({n_pp} recreations)",
    counts=pp_counts,
)
_draw_rate_panel(
    axes[2],
    analytical_rate_per_cell,
    title=f"A: analytical λ at T_h+ε\n(events / km² / day)",
)

sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
cbar = fig.colorbar(sm, ax=axes, shrink=0.9, pad=0.02)
cbar.set_label("Rate (events / km²) — shared log scale")

fig.suptitle(
    f"Spatial rate by Voronoi cell at t = T_h + {eps_compare:g} days",
    y=1.04,
    fontsize=13,
)
plt.show()

pd.DataFrame(
    {
        "method": ["classic ETAS", "grid point process", "analytical"],
        "n_recreations": [n_sim, n_pp, np.nan],
        "nonzero_cells": [
            int((sim_counts > 0).sum()),
            int((pp_counts > 0).sum()),
            int((analytical_rate_per_cell > 0).sum()),
        ],
        "max_rate": [
            float(sim_rate_per_cell.max()),
            float(pp_rate_per_cell.max()),
            float(analytical_rate_per_cell.max()),
        ],
    }
)
# Out:
# 2026-06-11 19:45:39,445 - DEBUG - locator: <matplotlib.ticker.LogLocator object at 0x74e35ddcee90>
# 2026-06-11 19:45:39,477 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,478 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:39,481 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,481 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:39,482 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,482 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:39,894 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,894 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:39,895 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,895 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:39,895 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,896 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:39,908 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,908 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:39,909 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,909 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:39,909 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,910 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:39,939 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,939 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:39,939 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,940 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:39,940 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,941 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:39,942 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,942 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:39,942 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,943 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:39,943 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,943 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:39,946 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,946 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:39,946 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,947 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:39,947 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,947 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:39,976 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,976 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:39,976 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,977 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:39,977 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,977 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:39,979 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,979 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:39,979 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,980 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:39,980 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,980 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:39,982 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,983 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:39,983 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,983 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:39,985 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,985 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:39,990 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,990 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:39,990 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,991 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:39,991 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,991 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:39,992 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,993 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:39,993 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,993 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:39,994 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,994 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:39,996 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,997 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:39,997 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,997 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:39,998 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:39,998 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,020 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,020 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,020 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,021 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:40,021 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,021 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,023 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,023 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,023 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,023 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:40,024 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,024 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,027 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,027 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,027 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,027 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:40,028 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,028 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,049 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,049 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,049 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,050 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:40,050 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,050 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,052 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,052 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,052 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,052 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:40,053 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,053 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,055 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,056 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,056 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,056 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:40,057 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,057 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,077 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,078 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,078 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,078 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:40,079 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,079 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,080 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,080 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,081 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,081 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:40,081 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,082 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,084 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,084 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,085 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,085 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:40,085 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,085 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,090 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,090 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,091 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,091 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:40,092 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,092 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,093 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,093 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,094 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,094 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:40,094 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,094 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,097 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,097 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,097 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,098 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:40,098 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,098 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,146 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,146 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,147 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,147 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:40,148 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,148 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,153 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,153 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,154 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,154 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:40,154 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,155 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,157 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,157 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,157 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,158 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:40,158 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,158 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,212 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,212 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,212 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,213 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:40,213 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,213 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,215 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,215 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,215 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,215 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:40,216 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,216 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,219 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,219 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,219 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,219 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:40,220 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,220 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,326 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,327 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,327 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,327 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:40,328 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,328 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,344 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,344 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,345 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,345 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:40,345 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,346 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,348 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,348 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
# 2026-06-11 19:45:40,349 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,349 - DEBUG - ticklocs array([2.e-08, 3.e-08, 4.e-08, 5.e-08, 6.e-08, 7.e-08, 8.e-08, 9.e-08,
#        2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01])
# 2026-06-11 19:45:40,349 - DEBUG - vmin 3.389111106479038e-07 vmax 0.0074903115075731245
# 2026-06-11 19:45:40,350 - DEBUG - ticklocs array([1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01])
#                method  n_recreations  nonzero_cells  max_rate
# 0        classic ETAS         1000.0             58  0.000432
# 1  grid point process         1000.0             99  0.000399
# 2          analytical            NaN            494  0.007490

# %%
# Waiting-time histograms for each epsilon in recreations_epsilon
history_t_days = float(history_dict["t"])

epsilons = list(epsilon_vec) if "epsilon_vec" in globals() else sorted(recreations_epsilon.keys(), key=float)
epsilons = [eps for eps in epsilons if eps in recreations_epsilon]
if not epsilons:
    epsilons = sorted(recreations_epsilon.keys(), key=float)

delta_t_by_eps = {}
for eps in epsilons:
    pp_events = recreations_epsilon[eps]
    delta_t_by_eps[eps] = pp_events["time"].to_numpy() - history_t_days

all_delta_t = np.concatenate(list(delta_t_by_eps.values()))
positive_all = all_delta_t[all_delta_t > 0]
if positive_all.size == 0:
    raise ValueError("No positive waiting times to plot.")

xmax = max(1e-3, float(np.percentile(positive_all, 99.5)) * 1.1)
xmin = max(1e-6, float(np.min(positive_all)) * 0.5)
n_log_bins = 40
shared_bins = np.geomspace(xmin, xmax, n_log_bins)
t_plot = np.geomspace(xmin, xmax, 500)
g_vals = g(t_plot + history_t_days, history_dict, THETA_0)

max_count = 1
for eps in epsilons:
    positive = delta_t_by_eps[eps][delta_t_by_eps[eps] > 0]
    if positive.size:
        counts, _ = np.histogram(positive, bins=shared_bins)
        max_count = max(max_count, int(counts.max()))

g_scaled = g_vals * (max_count / max(g_vals.max(), 1e-30))
ymin = 0.8
ymax = max(max_count, float(g_scaled.max())) * 1.15

n_eps = len(epsilons)
ncols = min(3, n_eps)
nrows = int(np.ceil(n_eps / ncols))
fig, axes = plt.subplots(
    nrows,
    ncols,
    figsize=(5.5 * ncols, 4.2 * nrows),
    squeeze=False,
    sharex=True,
    sharey=True,
)

for idx, eps in enumerate(epsilons):
    ax = axes[idx // ncols, idx % ncols]
    delta_t_days = delta_t_by_eps[eps]
    positive = delta_t_days[delta_t_days > 0]
    if positive.size == 0:
        ax.text(0.5, 0.5, "No positive waiting times", ha="center", va="center", transform=ax.transAxes)
        ax.set_title(f"ε = {eps:g}")
        continue

    ax.hist(
        positive,
        bins=shared_bins,
        color="#4c78a8",
        edgecolor="black",
        linewidth=0.35,
        alpha=0.85,
    )
    ax.plot(
        t_plot,
        g_scaled,
        color="darkorange",
        linewidth=1.5,
        label="g(t) (scaled)",
    )

    if eps > 0:
        ax.axvline(eps, color="crimson", linestyle="--", linewidth=1.2, label=f"ε={eps:g}")

    ax.set_title(
        f"Forecast event waiting times\n"
        f"({len(delta_t_days)} recreations, ε={eps:g})"
    )
    ax.grid(which="both", axis="both", alpha=0.25, linewidth=0.4)
    ax.legend(loc="upper right", fontsize=8)

for idx in range(n_eps, nrows * ncols):
    axes[idx // ncols, idx % ncols].axis("off")

for ax in axes.ravel():
    if not ax.axison:
        continue
    ax.set_xscale("log")
    ax.set_yscale("log")
    ax.set_autoscalex_on(False)
    ax.set_autoscaley_on(False)
    ax.set_xlim(xmin, xmax)
    ax.set_ylim(ymin, ymax)

for ax in axes[-1, :]:
    if ax.axison:
        ax.set_xlabel("Time since history event (days, log scale)")
for ax in axes[:, 0]:
    if ax.axison:
        ax.set_ylabel("Count")

fig.suptitle(
    f"Waiting times since history event by ε (history at {history_event_time})",
    y=1.02,
)
fig.tight_layout()
plt.show()
# Out:
# 2026-06-11 19:45:40,687 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,687 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,692 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,692 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:40,693 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,693 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,722 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,722 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,723 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,724 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:40,724 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,724 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,744 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,744 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,745 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,745 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:40,745 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,746 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,751 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,751 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,754 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,754 - DEBUG - ticklocs array([2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03])
# 2026-06-11 19:45:40,754 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,755 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,772 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,773 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,773 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,773 - DEBUG - ticklocs array([2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03])
# 2026-06-11 19:45:40,774 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,774 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,779 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,779 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,780 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,780 - DEBUG - ticklocs array([2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03])
# 2026-06-11 19:45:40,780 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,780 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,783 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,783 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,783 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,784 - DEBUG - ticklocs array([2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03])
# 2026-06-11 19:45:40,784 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,784 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,785 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,785 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,786 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,786 - DEBUG - ticklocs array([2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03])
# 2026-06-11 19:45:40,786 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,786 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,789 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,789 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,789 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,789 - DEBUG - ticklocs array([2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03])
# 2026-06-11 19:45:40,790 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,790 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,795 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,795 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,795 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,795 - DEBUG - ticklocs array([2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03])
# 2026-06-11 19:45:40,796 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,796 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,797 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,797 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,798 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,798 - DEBUG - ticklocs array([2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03])
# 2026-06-11 19:45:40,798 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,799 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,800 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,800 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,801 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,801 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:40,801 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,802 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,804 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,804 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,804 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,804 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:40,805 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,805 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,810 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,810 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,810 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,811 - DEBUG - ticklocs array([2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03])
# 2026-06-11 19:45:40,811 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,811 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,812 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,812 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,813 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,813 - DEBUG - ticklocs array([2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03])
# 2026-06-11 19:45:40,813 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,813 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,816 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,816 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,816 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,816 - DEBUG - ticklocs array([2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03])
# 2026-06-11 19:45:40,817 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,817 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,822 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,822 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,822 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,823 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:40,823 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,823 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,835 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,835 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,835 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,836 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:40,836 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,836 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,840 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,840 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,840 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,841 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:40,841 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,841 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,844 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,844 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,845 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,845 - DEBUG - ticklocs array([2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03])
# 2026-06-11 19:45:40,845 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,845 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,850 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,851 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,851 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,851 - DEBUG - ticklocs array([2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03])
# 2026-06-11 19:45:40,852 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,852 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,854 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,854 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,854 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,855 - DEBUG - ticklocs array([2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03])
# 2026-06-11 19:45:40,855 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,855 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,858 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,859 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,859 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,859 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:40,860 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,860 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,862 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,862 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,862 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,863 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:40,863 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,863 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,867 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,867 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,867 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,867 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:40,868 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,868 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,873 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,873 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,873 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,874 - DEBUG - ticklocs array([2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03])
# 2026-06-11 19:45:40,874 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,874 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,875 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,875 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,876 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,876 - DEBUG - ticklocs array([2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03])
# 2026-06-11 19:45:40,876 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,876 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,879 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,879 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,879 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,879 - DEBUG - ticklocs array([2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03])
# 2026-06-11 19:45:40,880 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,880 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,882 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,883 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,883 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,883 - DEBUG - ticklocs array([2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03])
# 2026-06-11 19:45:40,884 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,884 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,885 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,885 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,885 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,885 - DEBUG - ticklocs array([2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03])
# 2026-06-11 19:45:40,886 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,886 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,888 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,888 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,889 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,889 - DEBUG - ticklocs array([2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03])
# 2026-06-11 19:45:40,889 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,890 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,893 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,893 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,893 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,894 - DEBUG - ticklocs array([2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03])
# 2026-06-11 19:45:40,894 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,894 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,896 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,896 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,896 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,896 - DEBUG - ticklocs array([2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03])
# 2026-06-11 19:45:40,897 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,897 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,898 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,898 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,899 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,899 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:40,900 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,900 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,902 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,902 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,902 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,902 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:40,903 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,903 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,906 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,907 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,907 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,907 - DEBUG - ticklocs array([2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03])
# 2026-06-11 19:45:40,908 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,908 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,909 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,909 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,909 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,909 - DEBUG - ticklocs array([2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03])
# 2026-06-11 19:45:40,910 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,910 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,917 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,917 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,917 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,917 - DEBUG - ticklocs array([2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03])
# 2026-06-11 19:45:40,918 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,918 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,927 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,927 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,927 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,927 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:40,928 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,928 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,955 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,956 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,956 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,956 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:40,957 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,957 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,961 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,961 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,961 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,962 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:40,962 - DEBUG - vmin 1.187657289847266e-06 vmax 1.457935392556541
# 2026-06-11 19:45:40,962 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:40,966 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,967 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,967 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,967 - DEBUG - ticklocs array([2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03])
# 2026-06-11 19:45:40,968 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,968 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,974 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,974 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,974 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,975 - DEBUG - ticklocs array([2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03])
# 2026-06-11 19:45:40,975 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,975 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,977 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,977 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])
# 2026-06-11 19:45:40,978 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,978 - DEBUG - ticklocs array([2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03])
# 2026-06-11 19:45:40,978 - DEBUG - vmin 0.8 vmax 82.8
# 2026-06-11 19:45:40,979 - DEBUG - ticklocs array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])

# %% [markdown]
# ## Apples-to-apples: three ways to forecast the first event
#
# All three approaches target
#
# \[
# F(\Delta t) = P(\text{first event in California occurs by } T_h + \Delta t)
# \]
#
# where \(T_h\) is `history_event_time`. Plots use **CDF** \(F = 1 - S\), not survival `exp(log_rhs)`.
#
# | Method | Implementation | Model |
# |--------|----------------|-------|
# | **A. Analytical** | `1 - exp(log_rhs)` | One parent event; \(\lambda=\mu + a_h(x,y)\,g(t)\); degree² `A_h`; no branching |
# | **B. Grid point process** | `create_single_realization` → `min` over Voronoi cells | **Same model as A**; inverse transform per cell with random \(U_j\) |
# | **C. Classic ETAS** | `simulate_catalog_continuation` | Production simulator: haversine km, discrete aftershocks, magnitude sampling |
#
# ### A vs B — should match
#
# For B, the first event is \(T=\min_j T_j\) where each cell solves `log_rhs_j(T_j)=\log U_j`. Then
#
# \[
# P(T>\Delta t)=\prod_j \exp(\text{log\_rhs}_j)=\exp\Big(\sum_j \text{log\_rhs}_j\Big),
# \qquad
# F_B(\Delta t)=1-\exp\Big(\sum_j \text{log\_rhs}_j\Big).
# \]
#
# A single California integral `1 - exp(log_rhs)` is almost the same (partitioned `A_h` sums match), but the **exact** B counterpart is the product over cells. With enough Monte Carlo recreations, the B ECDF should sit on that curve (~median **0.03 days** here).
#
# **If A and B looked far apart**, the usual cause is evaluating A on a **coarse linear** \(\Delta t\) grid (`linspace(0,100,400)` → first step \(\approx 0.25\) days) while most probability arrives before **0.05 days**. The next cell uses log-spaced \(\Delta t\) and interpolation for medians.
#
# ### C vs A/B — not just distance, not fixed by “first event only”
#
# Keeping only the first simulated event removes later branching, but C still differs because:
#
# - **Spatial kernel**: haversine **km** offsets (`simulate_aftershock_radius`) vs degree² integral `A_h`
# - **Generative law**: Poisson **count** of aftershocks with random km locations vs continuous spatial intensity field
# - **Background**: Poisson count + uniform times in window (first arrival still ~exponential, but combined with discrete aftershocks)
# - **Area**: `polygon_surface` (projected km²) in simulation vs `Geod` + degree² distances in A/B
#
# So C’s median (~**0.006 days**) can be faster than A/B (~**0.03 days**) even for the same parameters.

# %%
def _ecdf_positive(samples):
    x = np.sort(np.asarray(samples, dtype=float))
    x = x[np.isfinite(x) & (x > 0)]
    if x.size == 0:
        return np.array([]), np.array([])
    return x, np.arange(1, x.size + 1, dtype=float) / x.size


def _analytical_median_dt(delta_t, cdf):
    cdf = np.asarray(cdf, dtype=float)
    delta_t = np.asarray(delta_t, dtype=float)
    if not np.any(cdf >= 0.5):
        return np.nan
    return float(np.interp(0.5, cdf, delta_t))


def _analytical_quantile_dt(delta_t, cdf, q):
    cdf = np.asarray(cdf, dtype=float)
    delta_t = np.asarray(delta_t, dtype=float)
    if not np.any(cdf >= q):
        return np.nan
    return float(np.interp(q, cdf, delta_t))


history_t_days = float(history_dict["t"])

# --- 1) Analytical CDFs (log-spaced Δt so the first ~0.01 days are resolved) ---
if "california_lonlat" not in globals():
    california_lonlat = transform(_swap_xy, polygon)

delta_t_analytical = np.geomspace(1e-5, 100.0, 400)
t_eval = delta_t_analytical + history_t_days

log_survival_ca = log_rhs(
    t_eval, history_t_days, california_lonlat, history_dict, THETA_0, A_H_RESOLUTION
)
cdf_ca = 1.0 - np.clip(np.exp(log_survival_ca), 0.0, 1.0)

# Exact B counterpart: product of per-cell survivals
log_survival_cells = np.zeros_like(delta_t_analytical, dtype=float)
for cell in ordered_cells:
    log_survival_cells += log_rhs(
        t_eval, history_t_days, cell, history_dict, THETA_0, A_H_RESOLUTION
    )
cdf_cells = 1.0 - np.clip(np.exp(log_survival_cells), 0.0, 1.0)


# --- 2) Grid point-process recreations (min over Voronoi cells) ---
eps_compare = float(epsilon_vec[0]) if "epsilon_vec" in globals() else 0.0
pp_events = recreations_epsilon[eps_compare]
delta_t_pp = pp_events["time"].to_numpy(dtype=float) - history_t_days
x_pp, y_pp = _ecdf_positive(delta_t_pp)

# --- 3) Classic ETAS catalog continuation ---
if "dt_to_first" not in globals():
    t0 = pd.to_datetime(FORECAST_START, utc=True)
    df_rec = forecast_recreations.loc[forecast_recreations["event_idx"] == 0].copy()
    df_rec["time"] = pd.to_datetime(df_rec["time"], utc=True)
    dt_to_first = (
        df_rec.loc[df_rec["time"] > t0, "time"] - t0
    ).dt.total_seconds().to_numpy() / 86400.0
x_etas, y_etas = _ecdf_positive(dt_to_first)

# --- Plot ---
fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(
    delta_t_analytical,
    cdf_ca,
    color="black",
    linewidth=2,
    label="A: California integral",
)
ax.plot(
    delta_t_analytical,
    cdf_cells,
    color="gray",
    linewidth=1.5,
    linestyle="--",
    label="A′: product over Voronoi cells (exact B target)",
)
if x_pp.size:
    ax.step(x_pp, y_pp, where="post", color="tab:blue", linewidth=1.5, label=f"Grid point process ECDF (ε={eps_compare:g}, n={x_pp.size})")
if x_etas.size:
    ax.step(x_etas, y_etas, where="post", color="tab:orange", linewidth=1.5, label=f"Classic ETAS ECDF (n={x_etas.size})")

ax.set_xscale("log")
ax.set_xlim(left=max(1e-4, np.min([delta_t_analytical[1], x_pp.min() if x_pp.size else 1e-3, x_etas.min() if x_etas.size else 1e-3]) * 0.5))
ax.set_ylim(0, 1.02)
ax.set_xlabel("Days since history event")
ax.set_ylabel("CDF  P(first event by Δt)")
ax.set_title("First-event waiting time: same CDF, three methods")
ax.grid(True, which="both", alpha=0.3)
ax.legend(loc="lower right")
fig.tight_layout()
plt.show()

# Summary stats for quick numeric comparison
def _quantile_row(name, x):
    if x.size == 0:
        return {"method": name, "n": 0}
    q = np.quantile(x, [0.05, 0.5, 0.95])
    return {
        "method": name,
        "n": int(x.size),
        "median_days": float(q[1]),
        "p05_days": float(q[0]),
        "p95_days": float(q[2]),
    }


summary = pd.DataFrame(
    [
        {
            "method": "A: California integral",
            "n": int(delta_t_analytical.size),
            "median_days": _analytical_median_dt(delta_t_analytical, cdf_ca),
            "p05_days": _analytical_quantile_dt(delta_t_analytical, cdf_ca, 0.05),
            "p95_days": _analytical_quantile_dt(delta_t_analytical, cdf_ca, 0.95),
        },
        {
            "method": "A′: product over cells",
            "n": int(delta_t_analytical.size),
            "median_days": _analytical_median_dt(delta_t_analytical, cdf_cells),
            "p05_days": _analytical_quantile_dt(delta_t_analytical, cdf_cells, 0.05),
            "p95_days": _analytical_quantile_dt(delta_t_analytical, cdf_cells, 0.95),
        },
        _quantile_row("B: grid point process", delta_t_pp[delta_t_pp > 0]),
        _quantile_row("C: classic ETAS", dt_to_first[dt_to_first > 0]),
    ]
)
summary
# Out:
# 2026-06-11 19:45:42,543 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,544 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
# 2026-06-11 19:45:42,549 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,549 - DEBUG - ticklocs array([2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03,
#        2.e+04, 3.e+04, 4.e+04, 5.e+04, 6.e+04, 7.e+04, 8.e+04, 9.e+04])
# 2026-06-11 19:45:42,550 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,550 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
# 2026-06-11 19:45:42,579 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,579 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
# 2026-06-11 19:45:42,580 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,580 - DEBUG - ticklocs array([2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03,
#        2.e+04, 3.e+04, 4.e+04, 5.e+04, 6.e+04, 7.e+04, 8.e+04, 9.e+04])
# 2026-06-11 19:45:42,580 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,581 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
# 2026-06-11 19:45:42,602 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,602 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
# 2026-06-11 19:45:42,603 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,603 - DEBUG - ticklocs array([2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03,
#        2.e+04, 3.e+04, 4.e+04, 5.e+04, 6.e+04, 7.e+04, 8.e+04, 9.e+04])
# 2026-06-11 19:45:42,604 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,604 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
# 2026-06-11 19:45:42,619 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,619 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
# 2026-06-11 19:45:42,620 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,620 - DEBUG - ticklocs array([2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03,
#        2.e+04, 3.e+04, 4.e+04, 5.e+04, 6.e+04, 7.e+04, 8.e+04, 9.e+04])
# 2026-06-11 19:45:42,621 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,621 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
# 2026-06-11 19:45:42,623 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,623 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
# 2026-06-11 19:45:42,623 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,623 - DEBUG - ticklocs array([2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03,
#        2.e+04, 3.e+04, 4.e+04, 5.e+04, 6.e+04, 7.e+04, 8.e+04, 9.e+04])
# 2026-06-11 19:45:42,624 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,624 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
# 2026-06-11 19:45:42,632 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,632 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
# 2026-06-11 19:45:42,633 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,633 - DEBUG - ticklocs array([2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03,
#        2.e+04, 3.e+04, 4.e+04, 5.e+04, 6.e+04, 7.e+04, 8.e+04, 9.e+04])
# 2026-06-11 19:45:42,634 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,634 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
# 2026-06-11 19:45:42,644 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,644 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
# 2026-06-11 19:45:42,645 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,645 - DEBUG - ticklocs array([2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03,
#        2.e+04, 3.e+04, 4.e+04, 5.e+04, 6.e+04, 7.e+04, 8.e+04, 9.e+04])
# 2026-06-11 19:45:42,646 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,646 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
# 2026-06-11 19:45:42,649 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,649 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
# 2026-06-11 19:45:42,650 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,650 - DEBUG - ticklocs array([2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03,
#        2.e+04, 3.e+04, 4.e+04, 5.e+04, 6.e+04, 7.e+04, 8.e+04, 9.e+04])
# 2026-06-11 19:45:42,650 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,651 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
# 2026-06-11 19:45:42,660 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,661 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
# 2026-06-11 19:45:42,661 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,661 - DEBUG - ticklocs array([2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03,
#        2.e+04, 3.e+04, 4.e+04, 5.e+04, 6.e+04, 7.e+04, 8.e+04, 9.e+04])
# 2026-06-11 19:45:42,662 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,662 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
# 2026-06-11 19:45:42,664 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,664 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
# 2026-06-11 19:45:42,664 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,664 - DEBUG - ticklocs array([2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03,
#        2.e+04, 3.e+04, 4.e+04, 5.e+04, 6.e+04, 7.e+04, 8.e+04, 9.e+04])
# 2026-06-11 19:45:42,665 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,665 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
# 2026-06-11 19:45:42,668 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,669 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
# 2026-06-11 19:45:42,669 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,669 - DEBUG - ticklocs array([2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03,
#        2.e+04, 3.e+04, 4.e+04, 5.e+04, 6.e+04, 7.e+04, 8.e+04, 9.e+04])
# 2026-06-11 19:45:42,670 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,670 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
# 2026-06-11 19:45:42,680 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,680 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
# 2026-06-11 19:45:42,681 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,681 - DEBUG - ticklocs array([2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03,
#        2.e+04, 3.e+04, 4.e+04, 5.e+04, 6.e+04, 7.e+04, 8.e+04, 9.e+04])
# 2026-06-11 19:45:42,681 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,682 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
# 2026-06-11 19:45:42,683 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,684 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
# 2026-06-11 19:45:42,684 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,684 - DEBUG - ticklocs array([2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03,
#        2.e+04, 3.e+04, 4.e+04, 5.e+04, 6.e+04, 7.e+04, 8.e+04, 9.e+04])
# 2026-06-11 19:45:42,685 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,685 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
# 2026-06-11 19:45:42,693 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,693 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
# 2026-06-11 19:45:42,694 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,694 - DEBUG - ticklocs array([2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03,
#        2.e+04, 3.e+04, 4.e+04, 5.e+04, 6.e+04, 7.e+04, 8.e+04, 9.e+04])
# 2026-06-11 19:45:42,695 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,695 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
# 2026-06-11 19:45:42,726 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,726 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
# 2026-06-11 19:45:42,727 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,727 - DEBUG - ticklocs array([2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03,
#        2.e+04, 3.e+04, 4.e+04, 5.e+04, 6.e+04, 7.e+04, 8.e+04, 9.e+04])
# 2026-06-11 19:45:42,728 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,728 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
# 2026-06-11 19:45:42,731 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,731 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
# 2026-06-11 19:45:42,732 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,732 - DEBUG - ticklocs array([2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03,
#        2.e+04, 3.e+04, 4.e+04, 5.e+04, 6.e+04, 7.e+04, 8.e+04, 9.e+04])
# 2026-06-11 19:45:42,733 - DEBUG - vmin 0.0001 vmax 240.55475352522498
# 2026-06-11 19:45:42,733 - DEBUG - ticklocs array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04])
#                    method     n  median_days  p05_days  p95_days
# 0  A: California integral   400     0.006907  0.000288  0.237022
# 1  A′: product over cells   400     0.009870  0.000358  0.394797
# 2   B: grid point process  1000     0.009499  0.000355  0.323453
# 3         C: classic ETAS  1000     0.005688  0.000303  0.173319

# %% [markdown]
# ### PDF check: histograms vs analytical \(dF/d\Delta t\)
#
# If B (and approximately C for the simplified model) is consistent with the analytical compensator, normalized histograms of \(\Delta t\) should follow the PDF obtained by differentiating the analytical CDF (here: **A′**, product over Voronoi cells).

# %%
# Requires the previous comparison cell (delta_t_analytical, cdf_cells, delta_t_pp, dt_to_first).
pdf_cells = np.gradient(cdf_cells, delta_t_analytical)
pdf_cells = np.clip(pdf_cells, 0.0, None)

pdf_ca = np.clip(np.gradient(cdf_ca, delta_t_analytical), 0.0, None)

samples_for_bins = []
if "delta_t_pp" in globals():
    samples_for_bins.append(np.asarray(delta_t_pp, dtype=float))
if "dt_to_first" in globals():
    samples_for_bins.append(np.asarray(dt_to_first, dtype=float))
positive_all = np.concatenate(
    [x[(x > 0) & np.isfinite(x)] for x in samples_for_bins if x.size]
) if samples_for_bins else np.array([])
if positive_all.size == 0:
    raise ValueError("Run grid recreations and/or catalog continuation first.")

xmin = max(1e-6, float(np.min(positive_all)) * 0.5)
xmax = max(xmin * 10, float(np.percentile(positive_all, 99.5)) * 1.1)
hist_bins = np.geomspace(xmin, xmax, 40)

fig, ax = plt.subplots(figsize=(8, 5))

delta_t_pos = delta_t_pp[(delta_t_pp > 0) & np.isfinite(delta_t_pp)]
if delta_t_pos.size:
    ax.hist(
        delta_t_pos,
        bins=hist_bins,
        density=True,
        alpha=0.45,
        color="tab:blue",
        edgecolor="black",
        linewidth=0.35,
        label=f"B: grid point process (n={delta_t_pos.size})",
    )

dt_pos = dt_to_first[(dt_to_first > 0) & np.isfinite(dt_to_first)]
if dt_pos.size:
    ax.hist(
        dt_pos,
        bins=hist_bins,
        density=True,
        alpha=0.35,
        color="tab:orange",
        edgecolor="black",
        linewidth=0.35,
        label=f"C: classic ETAS (n={dt_pos.size})",
    )

mask_pdf = (delta_t_analytical >= xmin) & (delta_t_analytical <= xmax) & np.isfinite(pdf_cells)
ax.plot(
    delta_t_analytical[mask_pdf],
    pdf_cells[mask_pdf],
    color="black",
    linewidth=2.0,
    label="A′: dF/dΔt (product over cells)",
)
ax.plot(
    delta_t_analytical[mask_pdf],
    pdf_ca[mask_pdf],
    color="gray",
    linewidth=1.2,
    linestyle="--",
    label="A: dF/dΔt (California integral)",
)

ax.set_xscale("log")
ax.set_xlim(xmin, xmax)
ax.set_xlabel("Days since history event")
ax.set_ylabel("Density  (normalized histogram / dF/dΔt)")
ax.set_title("First-event waiting time: PDF vs simulated histograms")
ax.grid(True, which="both", alpha=0.3)
ax.legend(loc="upper right")
fig.tight_layout()
plt.show()
# Out:
# 2026-06-11 19:45:43,102 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,103 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:43,107 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,107 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:43,108 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,108 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:43,137 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,138 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:43,138 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,138 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:43,139 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,139 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:43,158 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,159 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:43,159 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,159 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:43,160 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,160 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:43,178 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,179 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:43,179 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,179 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:43,180 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,180 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:43,182 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,182 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:43,182 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,182 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:43,183 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,183 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:43,195 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,196 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:43,196 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,196 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:43,197 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,197 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:43,208 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,208 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:43,209 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,209 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:43,209 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,210 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:43,213 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,213 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:43,213 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,214 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:43,214 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,214 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:43,225 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,225 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:43,225 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,226 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:43,226 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,226 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:43,228 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,228 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:43,228 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,228 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:43,229 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,229 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:43,233 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,233 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:43,233 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,233 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:43,234 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,234 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:43,246 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,246 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:43,246 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,247 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:43,247 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,247 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:43,249 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,249 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:43,250 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,250 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:43,250 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,251 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:43,267 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,267 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:43,267 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,267 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:43,268 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,268 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:43,296 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,297 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:43,297 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,297 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:43,298 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,298 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:43,301 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,302 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])
# 2026-06-11 19:45:43,302 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,302 - DEBUG - ticklocs array([2.e-07, 3.e-07, 4.e-07, 5.e-07, 6.e-07, 7.e-07, 8.e-07, 9.e-07,
#        2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02])
# 2026-06-11 19:45:43,303 - DEBUG - vmin 1.187657289847266e-06 vmax 1.2976652624393565
# 2026-06-11 19:45:43,303 - DEBUG - ticklocs array([1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00,
#        1.e+01, 1.e+02])

# %%
# shared_bins

# xmax = max(1e-3, float(np.percentile(positive_all, 99.5)) * 1.1)
# xmin = max(1e-6, float(np.min(positive_all)) * 0.5)
# n_log_bins = 40


shared_bins_linear = np.linspace(
        xmin,
        xmax,
        n_log_bins,
    )
    
hist, bins = np.histogram(
    positive,
    bins=shared_bins_linear,
)

# CDF
cdf = np.cumsum(hist)
cdf = cdf / cdf[-1]

fig_cdf, ax = plt.subplots(figsize=(6, 4.5))
ax.plot(bins[:-1], cdf, color="tab:orange", linewidth=2)
ax.set_xlabel("Time since forecast start (days)")
ax.set_ylabel("CDF")
ax.set_title("CDF of time to first event")
# Out:
# Text(0.5, 1.0, 'CDF of time to first event')
